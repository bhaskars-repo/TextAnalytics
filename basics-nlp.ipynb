# %% [markdown]
# # Basics of Natural Language Processing using NLTK

# %% [markdown]
# ### Python Imports

# %%
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from nltk.corpus import stopwords
from nltk.util import ngrams

# %%
# %reload_ext watermark

# %%
# %watermark -n -v -iv
# Out:
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.7.0
#
# nltk: 3.8.1

# %% [markdown]
# ### Set path to nltk data

# %%
nltk.data.path.append("./nltk_data")

# %% [markdown]
# ### Subset of Texts from 'Project GutenBerg' packaged in NLTK

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# ### Texts from 'Presedential Inaugural Speeches' packaged in NLTK

# %%
nltk.corpus.inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
#  '1957-Eisenhower.txt',
#  '1961-Kennedy.txt',
#  '1965-Johnson.txt',
#  '1969-Nixon.txt',
#  '1973-Nixon.txt',
#  '1977-Carter.txt',
#  '1981-Reagan.txt',
#  '1985-Reagan.txt',
#  '1989-Bush.txt',
#  '1993-Clinton.txt',
#  '1997-Clinton.txt',
#  '2001-Bush.txt',
#  '2005-Bush.txt',
#  '2009-Obama.txt',
#  '2013-Obama.txt',
#  '2017-Trump.txt',
#  '2021-Biden.txt']

# %% [markdown]
# ### Load and tokenize the Charles Dickens - The Christmas Carol

# %% [markdown]
# To load the 'Alice in the Wonderland' text from the NLTK Gutenberg corpus use the following code:
#
# md_words = nltk.corpus.gutenberg.words('carroll-alice.txt')

# %% [markdown]
# #### Read each line, convert to lowercase, and tokenize

# %%
with open ('txt_data/charles-christmas_carol.txt') as fcc:
    all_tokens = word_tokenize(fcc.read().lower())

# %% [markdown]
# #### Remove all punctuations

# %%
cc_tokens = [word for word in all_tokens if word.isalpha()]

# %% [markdown]
# #### Use the WordPunctTokenizer for NLTK

# %%
tokenizer = WordPunctTokenizer()
with open ('txt_data/charles-christmas_carol.txt') as fcc:
    all_tokens2 = tokenizer.tokenize(fcc.read().lower())
all_tokens2
# Out:
# ['title',
#  ':',
#  'a',
#  'christmas',
#  'carol',
#  'author',
#  ':',
#  'charles',
#  'dickens',
#  'illustrator',
#  ':',
#  'john',
#  'leech',
#  'release',
#  'date',
#  ':',
#  'october',
#  '30',
#  ',',
#  '2009',
#  'language',
#  ':',
#  'english',
#  'a',
#  'christmas',
#  'carol',
#  'by',
#  'charles',
#  'dickens',
#  'being',
#  'a',
#  'ghost',
#  'story',
#  'of',
#  'christmas',
#  'preface',
#  'i',
#  'have',
#  'endeavoured',
#  'in',
#  'this',
#  'ghostly',
#  'little',
#  'book',
#  ',',
#  'to',
#  'raise',
#  'the',
#  'ghost',
#  'of',
#  'an',
#  'idea',
#  ',',
#  'which',
#  'shall',
#  'not',
#  'put',
#  'my',
#  'readers',
#  'out',
#  'of',
#  'humour',
#  'with',
#  'themselves',
#  ',',
#  'with',
#  'each',
#  'other',
#  ',',
#  'with',
#  'the',
#  'season',
#  ',',
#  'or',
#  'with',
#  'me',
#  '.',
#  'may',
#  'it',
#  'haunt',
#  'their',
#  'houses',
#  'pleasantly',
#  ',',
#  'and',
#  'no',
#  'one',
#  'wish',
#  'to',
#  'lay',
#  'it',
#  '.',
#  'their',
#  'faithful',
#  'friend',
#  'and',
#  'servant',
#  ',',
#  'c',
#  '.',
#  'd',
#  '.',
#  'december',
#  ',',
#  '1843',
#  '.',
#  'stave',
#  'i',
#  '.',
#  'marley',
#  "'",
#  's',
#  'ghost',
#  '.',
#  'marley',
#  'was',
#  'dead',
#  ':',
#  'to',
#  'begin',
#  'with',
#  '.',
#  'there',
#  'is',
#  'no',
#  'doubt',
#  'whatever',
#  'about',
#  'that',
#  '.',
#  'the',
#  'register',
#  'of',
#  'his',
#  'burial',
#  'was',
#  'signed',
#  'by',
#  'the',
#  'clergyman',
#  ',',
#  'the',
#  'clerk',
#  ',',
#  'the',
#  'undertaker',
#  ',',
#  'and',
#  'the',
#  'chief',
#  'mourner',
#  '.',
#  'scrooge',
#  'signed',
#  'it',
#  ':',
#  'and',
#  'scrooge',
#  "'",
#  's',
#  'name',
#  'was',
#  'good',
#  'upon',
#  "'",
#  'change',
#  ',',
#  'for',
#  'anything',
#  'he',
#  'chose',
#  'to',
#  'put',
#  'his',
#  'hand',
#  'to',
#  '.',
#  'old',
#  'marley',
#  'was',
#  'as',
#  'dead',
#  'as',
#  'a',
#  'door',
#  '-',
#  'nail',
#  '.',
#  'mind',
#  '!',
#  'i',
#  'don',
#  "'",
#  't',
#  'mean',
#  'to',
#  'say',
#  'that',
#  'i',
#  'know',
#  ',',
#  'of',
#  'my',
#  'own',
#  'knowledge',
#  ',',
#  'what',
#  'there',
#  'is',
#  'particularly',
#  'dead',
#  'about',
#  'a',
#  'door',
#  '-',
#  'nail',
#  '.',
#  'i',
#  'might',
#  'have',
#  'been',
#  'inclined',
#  ',',
#  'myself',
#  ',',
#  'to',
#  'regard',
#  'a',
#  'coffin',
#  '-',
#  'nail',
#  'as',
#  'the',
#  'deadest',
#  'piece',
#  'of',
#  'ironmongery',
#  'in',
#  'the',
#  'trade',
#  '.',
#  'but',
#  'the',
#  'wisdom',
#  'of',
#  'our',
#  'ancestors',
#  'is',
#  'in',
#  'the',
#  'simile',
#  ';',
#  'and',
#  'my',
#  'unhallowed',
#  'hands',
#  'shall',
#  'not',
#  'disturb',
#  'it',
#  ',',
#  'or',
#  'the',
#  'country',
#  "'",
#  's',
#  'done',
#  'for',
#  '.',
#  'you',
#  'will',
#  'therefore',
#  'permit',
#  'me',
#  'to',
#  'repeat',
#  ',',
#  'emphatically',
#  ',',
#  'that',
#  'marley',
#  'was',
#  'as',
#  'dead',
#  'as',
#  'a',
#  'door',
#  '-',
#  'nail',
#  '.',
#  'scrooge',
#  'knew',
#  'he',
#  'was',
#  'dead',
#  '?',
#  'of',
#  'course',
#  'he',
#  'did',
#  '.',
#  'how',
#  'could',
#  'it',
#  'be',
#  'otherwise',
#  '?',
#  'scrooge',
#  'and',
#  'he',
#  'were',
#  'partners',
#  'for',
#  'i',
#  'don',
#  "'",
#  't',
#  'know',
#  'how',
#  'many',
#  'years',
#  '.',
#  'scrooge',
#  'was',
#  'his',
#  'sole',
#  'executor',
#  ',',
#  'his',
#  'sole',
#  'administrator',
#  ',',
#  'his',
#  'sole',
#  'assign',
#  ',',
#  'his',
#  'sole',
#  'residuary',
#  'legatee',
#  ',',
#  'his',
#  'sole',
#  'friend',
#  'and',
#  'sole',
#  'mourner',
#  '.',
#  'and',
#  'even',
#  'scrooge',
#  'was',
#  'not',
#  'so',
#  'dreadfully',
#  'cut',
#  'up',
#  'by',
#  'the',
#  'sad',
#  'event',
#  ',',
#  'but',
#  'that',
#  'he',
#  'was',
#  'an',
#  'excellent',
#  'man',
#  'of',
#  'business',
#  'on',
#  'the',
#  'very',
#  'day',
#  'of',
#  'the',
#  'funeral',
#  ',',
#  'and',
#  'solemnised',
#  'it',
#  'with',
#  'an',
#  'undoubted',
#  'bargain',
#  '.',
#  'the',
#  'mention',
#  'of',
#  'marley',
#  "'",
#  's',
#  'funeral',
#  'brings',
#  'me',
#  'back',
#  'to',
#  'the',
#  'point',
#  'i',
#  'started',
#  'from',
#  '.',
#  'there',
#  'is',
#  'no',
#  'doubt',
#  'that',
#  'marley',
#  'was',
#  'dead',
#  '.',
#  'this',
#  'must',
#  'be',
#  'distinctly',
#  'understood',
#  ',',
#  'or',
#  'nothing',
#  'wonderful',
#  'can',
#  'come',
#  'of',
#  'the',
#  'story',
#  'i',
#  'am',
#  'going',
#  'to',
#  'relate',
#  '.',
#  'if',
#  'we',
#  'were',
#  'not',
#  'perfectly',
#  'convinced',
#  'that',
#  'hamlet',
#  "'",
#  's',
#  'father',
#  'died',
#  'before',
#  'the',
#  'play',
#  'began',
#  ',',
#  'there',
#  'would',
#  'be',
#  'nothing',
#  'more',
#  'remarkable',
#  'in',
#  'his',
#  'taking',
#  'a',
#  'stroll',
#  'at',
#  'night',
#  ',',
#  'in',
#  'an',
#  'easterly',
#  'wind',
#  ',',
#  'upon',
#  'his',
#  'own',
#  'ramparts',
#  ',',
#  'than',
#  'there',
#  'would',
#  'be',
#  'in',
#  'any',
#  'other',
#  'middle',
#  '-',
#  'aged',
#  'gentleman',
#  'rashly',
#  'turning',
#  'out',
#  'after',
#  'dark',
#  'in',
#  'a',
#  'breezy',
#  'spot',
#  '--',
#  'say',
#  'saint',
#  'paul',
#  "'",
#  's',
#  'churchyard',
#  'for',
#  'instance',
#  '--',
#  'literally',
#  'to',
#  'astonish',
#  'his',
#  'son',
#  "'",
#  's',
#  'weak',
#  'mind',
#  '.',
#  'scrooge',
#  'never',
#  'painted',
#  'out',
#  'old',
#  'marley',
#  "'",
#  's',
#  'name',
#  '.',
#  'there',
#  'it',
#  'stood',
#  ',',
#  'years',
#  'afterwards',
#  ',',
#  'above',
#  'the',
#  'warehouse',
#  'door',
#  ':',
#  'scrooge',
#  'and',
#  'marley',
#  '.',
#  'the',
#  'firm',
#  'was',
#  'known',
#  'as',
#  'scrooge',
#  'and',
#  'marley',
#  '.',
#  'sometimes',
#  'people',
#  'new',
#  'to',
#  'the',
#  'business',
#  'called',
#  'scrooge',
#  'scrooge',
#  ',',
#  'and',
#  'sometimes',
#  'marley',
#  ',',
#  'but',
#  'he',
#  'answered',
#  'to',
#  'both',
#  'names',
#  ':',
#  'it',
#  'was',
#  'all',
#  'the',
#  'same',
#  'to',
#  'him',
#  '.',
#  'oh',
#  '!',
#  'but',
#  'he',
#  'was',
#  'a',
#  'tight',
#  '-',
#  'fisted',
#  'hand',
#  'at',
#  'the',
#  'grindstone',
#  ',',
#  'scrooge',
#  '!',
#  'a',
#  'squeezing',
#  ',',
#  'wrenching',
#  ',',
#  'grasping',
#  ',',
#  'scraping',
#  ',',
#  'clutching',
#  ',',
#  'covetous',
#  'old',
#  'sinner',
#  '!',
#  'hard',
#  'and',
#  'sharp',
#  'as',
#  'flint',
#  ',',
#  'from',
#  'which',
#  'no',
#  'steel',
#  'had',
#  'ever',
#  'struck',
#  'out',
#  'generous',
#  'fire',
#  ';',
#  'secret',
#  ',',
#  'and',
#  'self',
#  '-',
#  'contained',
#  ',',
#  'and',
#  'solitary',
#  'as',
#  'an',
#  'oyster',
#  '.',
#  'the',
#  'cold',
#  'within',
#  'him',
#  'froze',
#  'his',
#  'old',
#  'features',
#  ',',
#  'nipped',
#  'his',
#  'pointed',
#  'nose',
#  ',',
#  'shrivelled',
#  'his',
#  'cheek',
#  ',',
#  'stiffened',
#  'his',
#  'gait',
#  ';',
#  'made',
#  'his',
#  'eyes',
#  'red',
#  ',',
#  'his',
#  'thin',
#  'lips',
#  'blue',
#  ';',
#  'and',
#  'spoke',
#  'out',
#  'shrewdly',
#  'in',
#  'his',
#  'grating',
#  'voice',
#  '.',
#  'a',
#  'frosty',
#  'rime',
#  'was',
#  'on',
#  'his',
#  'head',
#  ',',
#  'and',
#  'on',
#  'his',
#  'eyebrows',
#  ',',
#  'and',
#  'his',
#  'wiry',
#  'chin',
#  '.',
#  'he',
#  'carried',
#  'his',
#  'own',
#  'low',
#  'temperature',
#  'always',
#  'about',
#  'with',
#  'him',
#  ';',
#  'he',
#  'iced',
#  'his',
#  'office',
#  'in',
#  'the',
#  'dog',
#  '-',
#  'days',
#  ';',
#  'and',
#  'didn',
#  "'",
#  't',
#  'thaw',
#  'it',
#  'one',
#  'degree',
#  'at',
#  'christmas',
#  '.',
#  'external',
#  'heat',
#  'and',
#  'cold',
#  'had',
#  'little',
#  'influence',
#  'on',
#  'scrooge',
#  '.',
#  'no',
#  'warmth',
#  'could',
#  'warm',
#  ',',
#  'nor',
#  'wintry',
#  'weather',
#  'chill',
#  'him',
#  '.',
#  'no',
#  'wind',
#  'that',
#  'blew',
#  'was',
#  'bitterer',
#  'than',
#  'he',
#  ',',
#  'no',
#  'falling',
#  'snow',
#  'was',
#  'more',
#  'intent',
#  'upon',
#  'its',
#  'purpose',
#  ',',
#  'no',
#  'pelting',
#  'rain',
#  'less',
#  'open',
#  'to',
#  'entreaty',
#  '.',
#  'foul',
#  'weather',
#  'didn',
#  "'",
#  't',
#  'know',
#  'where',
#  'to',
#  'have',
#  'him',
#  '.',
#  'the',
#  'heaviest',
#  'rain',
#  ',',
#  'and',
#  'snow',
#  ',',
#  'and',
#  'hail',
#  ',',
#  'and',
#  'sleet',
#  ',',
#  'could',
#  'boast',
#  'of',
#  'the',
#  'advantage',
#  'over',
#  'him',
#  'in',
#  'only',
#  'one',
#  'respect',
#  '.',
#  'they',
#  'often',
#  '"',
#  'came',
#  'down',
#  '"',
#  'handsomely',
#  ',',
#  'and',
#  'scrooge',
#  'never',
#  'did',
#  '.',
#  'nobody',
#  'ever',
#  'stopped',
#  'him',
#  'in',
#  'the',
#  'street',
#  'to',
#  'say',
#  ',',
#  'with',
#  'gladsome',
#  'looks',
#  ',',
#  '"',
#  'my',
#  'dear',
#  'scrooge',
#  ',',
#  'how',
#  'are',
#  'you',
#  '?',
#  'when',
#  'will',
#  'you',
#  'come',
#  'to',
#  'see',
#  'me',
#  '?"',
#  'no',
#  'beggars',
#  'implored',
#  'him',
#  'to',
#  'bestow',
#  'a',
#  'trifle',
#  ',',
#  'no',
#  'children',
#  'asked',
#  'him',
#  'what',
#  'it',
#  'was',
#  'o',
#  "'",
#  'clock',
#  ',',
#  'no',
#  'man',
#  'or',
#  'woman',
#  'ever',
#  'once',
#  'in',
#  'all',
#  'his',
#  'life',
#  'inquired',
#  'the',
#  'way',
#  'to',
#  'such',
#  'and',
#  'such',
#  'a',
#  'place',
#  ',',
#  'of',
#  'scrooge',
#  '.',
#  'even',
#  'the',
#  'blindmen',
#  "'",
#  's',
#  'dogs',
#  'appeared',
#  'to',
#  'know',
#  'him',
#  ';',
#  'and',
#  'when',
#  'they',
#  'saw',
#  'him',
#  'coming',
#  'on',
#  ',',
#  'would',
#  'tug',
#  'their',
#  'owners',
#  'into',
#  'doorways',
#  'and',
#  'up',
#  'courts',
#  ';',
#  'and',
#  'then',
#  'would',
#  'wag',
#  'their',
#  'tails',
#  'as',
#  'though',
#  'they',
#  'said',
#  ',',
#  '"',
#  'no',
#  'eye',
#  'at',
#  'all',
#  'is',
#  'better',
#  'than',
#  'an',
#  'evil',
#  'eye',
#  ',',
#  'dark',
#  'master',
#  '!"',
#  'but',
#  'what',
#  'did',
#  'scrooge',
#  'care',
#  '?',
#  'it',
#  'was',
#  'the',
#  'very',
#  'thing',
#  'he',
#  'liked',
#  '.',
#  'to',
#  'edge',
#  'his',
#  'way',
#  'along',
#  'the',
#  'crowded',
#  'paths',
#  'of',
#  'life',
#  ',',
#  'warning',
#  'all',
#  'human',
#  'sympathy',
#  'to',
#  'keep',
#  'its',
#  'distance',
#  ',',
#  'was',
#  'what',
#  'the',
#  'knowing',
#  'ones',
#  'call',
#  '"',
#  'nuts',
#  '"',
#  'to',
#  ...]

# %% [markdown]
# #### Remove all punctuations

# %%
cc_tokens2 = [word for word in all_tokens2 if not word in string.punctuation]
cc_tokens2
# Out:
# ['title',
#  'a',
#  'christmas',
#  'carol',
#  'author',
#  'charles',
#  'dickens',
#  'illustrator',
#  'john',
#  'leech',
#  'release',
#  'date',
#  'october',
#  '30',
#  '2009',
#  'language',
#  'english',
#  'a',
#  'christmas',
#  'carol',
#  'by',
#  'charles',
#  'dickens',
#  'being',
#  'a',
#  'ghost',
#  'story',
#  'of',
#  'christmas',
#  'preface',
#  'i',
#  'have',
#  'endeavoured',
#  'in',
#  'this',
#  'ghostly',
#  'little',
#  'book',
#  'to',
#  'raise',
#  'the',
#  'ghost',
#  'of',
#  'an',
#  'idea',
#  'which',
#  'shall',
#  'not',
#  'put',
#  'my',
#  'readers',
#  'out',
#  'of',
#  'humour',
#  'with',
#  'themselves',
#  'with',
#  'each',
#  'other',
#  'with',
#  'the',
#  'season',
#  'or',
#  'with',
#  'me',
#  'may',
#  'it',
#  'haunt',
#  'their',
#  'houses',
#  'pleasantly',
#  'and',
#  'no',
#  'one',
#  'wish',
#  'to',
#  'lay',
#  'it',
#  'their',
#  'faithful',
#  'friend',
#  'and',
#  'servant',
#  'c',
#  'd',
#  'december',
#  '1843',
#  'stave',
#  'i',
#  'marley',
#  's',
#  'ghost',
#  'marley',
#  'was',
#  'dead',
#  'to',
#  'begin',
#  'with',
#  'there',
#  'is',
#  'no',
#  'doubt',
#  'whatever',
#  'about',
#  'that',
#  'the',
#  'register',
#  'of',
#  'his',
#  'burial',
#  'was',
#  'signed',
#  'by',
#  'the',
#  'clergyman',
#  'the',
#  'clerk',
#  'the',
#  'undertaker',
#  'and',
#  'the',
#  'chief',
#  'mourner',
#  'scrooge',
#  'signed',
#  'it',
#  'and',
#  'scrooge',
#  's',
#  'name',
#  'was',
#  'good',
#  'upon',
#  'change',
#  'for',
#  'anything',
#  'he',
#  'chose',
#  'to',
#  'put',
#  'his',
#  'hand',
#  'to',
#  'old',
#  'marley',
#  'was',
#  'as',
#  'dead',
#  'as',
#  'a',
#  'door',
#  'nail',
#  'mind',
#  'i',
#  'don',
#  't',
#  'mean',
#  'to',
#  'say',
#  'that',
#  'i',
#  'know',
#  'of',
#  'my',
#  'own',
#  'knowledge',
#  'what',
#  'there',
#  'is',
#  'particularly',
#  'dead',
#  'about',
#  'a',
#  'door',
#  'nail',
#  'i',
#  'might',
#  'have',
#  'been',
#  'inclined',
#  'myself',
#  'to',
#  'regard',
#  'a',
#  'coffin',
#  'nail',
#  'as',
#  'the',
#  'deadest',
#  'piece',
#  'of',
#  'ironmongery',
#  'in',
#  'the',
#  'trade',
#  'but',
#  'the',
#  'wisdom',
#  'of',
#  'our',
#  'ancestors',
#  'is',
#  'in',
#  'the',
#  'simile',
#  'and',
#  'my',
#  'unhallowed',
#  'hands',
#  'shall',
#  'not',
#  'disturb',
#  'it',
#  'or',
#  'the',
#  'country',
#  's',
#  'done',
#  'for',
#  'you',
#  'will',
#  'therefore',
#  'permit',
#  'me',
#  'to',
#  'repeat',
#  'emphatically',
#  'that',
#  'marley',
#  'was',
#  'as',
#  'dead',
#  'as',
#  'a',
#  'door',
#  'nail',
#  'scrooge',
#  'knew',
#  'he',
#  'was',
#  'dead',
#  'of',
#  'course',
#  'he',
#  'did',
#  'how',
#  'could',
#  'it',
#  'be',
#  'otherwise',
#  'scrooge',
#  'and',
#  'he',
#  'were',
#  'partners',
#  'for',
#  'i',
#  'don',
#  't',
#  'know',
#  'how',
#  'many',
#  'years',
#  'scrooge',
#  'was',
#  'his',
#  'sole',
#  'executor',
#  'his',
#  'sole',
#  'administrator',
#  'his',
#  'sole',
#  'assign',
#  'his',
#  'sole',
#  'residuary',
#  'legatee',
#  'his',
#  'sole',
#  'friend',
#  'and',
#  'sole',
#  'mourner',
#  'and',
#  'even',
#  'scrooge',
#  'was',
#  'not',
#  'so',
#  'dreadfully',
#  'cut',
#  'up',
#  'by',
#  'the',
#  'sad',
#  'event',
#  'but',
#  'that',
#  'he',
#  'was',
#  'an',
#  'excellent',
#  'man',
#  'of',
#  'business',
#  'on',
#  'the',
#  'very',
#  'day',
#  'of',
#  'the',
#  'funeral',
#  'and',
#  'solemnised',
#  'it',
#  'with',
#  'an',
#  'undoubted',
#  'bargain',
#  'the',
#  'mention',
#  'of',
#  'marley',
#  's',
#  'funeral',
#  'brings',
#  'me',
#  'back',
#  'to',
#  'the',
#  'point',
#  'i',
#  'started',
#  'from',
#  'there',
#  'is',
#  'no',
#  'doubt',
#  'that',
#  'marley',
#  'was',
#  'dead',
#  'this',
#  'must',
#  'be',
#  'distinctly',
#  'understood',
#  'or',
#  'nothing',
#  'wonderful',
#  'can',
#  'come',
#  'of',
#  'the',
#  'story',
#  'i',
#  'am',
#  'going',
#  'to',
#  'relate',
#  'if',
#  'we',
#  'were',
#  'not',
#  'perfectly',
#  'convinced',
#  'that',
#  'hamlet',
#  's',
#  'father',
#  'died',
#  'before',
#  'the',
#  'play',
#  'began',
#  'there',
#  'would',
#  'be',
#  'nothing',
#  'more',
#  'remarkable',
#  'in',
#  'his',
#  'taking',
#  'a',
#  'stroll',
#  'at',
#  'night',
#  'in',
#  'an',
#  'easterly',
#  'wind',
#  'upon',
#  'his',
#  'own',
#  'ramparts',
#  'than',
#  'there',
#  'would',
#  'be',
#  'in',
#  'any',
#  'other',
#  'middle',
#  'aged',
#  'gentleman',
#  'rashly',
#  'turning',
#  'out',
#  'after',
#  'dark',
#  'in',
#  'a',
#  'breezy',
#  'spot',
#  '--',
#  'say',
#  'saint',
#  'paul',
#  's',
#  'churchyard',
#  'for',
#  'instance',
#  '--',
#  'literally',
#  'to',
#  'astonish',
#  'his',
#  'son',
#  's',
#  'weak',
#  'mind',
#  'scrooge',
#  'never',
#  'painted',
#  'out',
#  'old',
#  'marley',
#  's',
#  'name',
#  'there',
#  'it',
#  'stood',
#  'years',
#  'afterwards',
#  'above',
#  'the',
#  'warehouse',
#  'door',
#  'scrooge',
#  'and',
#  'marley',
#  'the',
#  'firm',
#  'was',
#  'known',
#  'as',
#  'scrooge',
#  'and',
#  'marley',
#  'sometimes',
#  'people',
#  'new',
#  'to',
#  'the',
#  'business',
#  'called',
#  'scrooge',
#  'scrooge',
#  'and',
#  'sometimes',
#  'marley',
#  'but',
#  'he',
#  'answered',
#  'to',
#  'both',
#  'names',
#  'it',
#  'was',
#  'all',
#  'the',
#  'same',
#  'to',
#  'him',
#  'oh',
#  'but',
#  'he',
#  'was',
#  'a',
#  'tight',
#  'fisted',
#  'hand',
#  'at',
#  'the',
#  'grindstone',
#  'scrooge',
#  'a',
#  'squeezing',
#  'wrenching',
#  'grasping',
#  'scraping',
#  'clutching',
#  'covetous',
#  'old',
#  'sinner',
#  'hard',
#  'and',
#  'sharp',
#  'as',
#  'flint',
#  'from',
#  'which',
#  'no',
#  'steel',
#  'had',
#  'ever',
#  'struck',
#  'out',
#  'generous',
#  'fire',
#  'secret',
#  'and',
#  'self',
#  'contained',
#  'and',
#  'solitary',
#  'as',
#  'an',
#  'oyster',
#  'the',
#  'cold',
#  'within',
#  'him',
#  'froze',
#  'his',
#  'old',
#  'features',
#  'nipped',
#  'his',
#  'pointed',
#  'nose',
#  'shrivelled',
#  'his',
#  'cheek',
#  'stiffened',
#  'his',
#  'gait',
#  'made',
#  'his',
#  'eyes',
#  'red',
#  'his',
#  'thin',
#  'lips',
#  'blue',
#  'and',
#  'spoke',
#  'out',
#  'shrewdly',
#  'in',
#  'his',
#  'grating',
#  'voice',
#  'a',
#  'frosty',
#  'rime',
#  'was',
#  'on',
#  'his',
#  'head',
#  'and',
#  'on',
#  'his',
#  'eyebrows',
#  'and',
#  'his',
#  'wiry',
#  'chin',
#  'he',
#  'carried',
#  'his',
#  'own',
#  'low',
#  'temperature',
#  'always',
#  'about',
#  'with',
#  'him',
#  'he',
#  'iced',
#  'his',
#  'office',
#  'in',
#  'the',
#  'dog',
#  'days',
#  'and',
#  'didn',
#  't',
#  'thaw',
#  'it',
#  'one',
#  'degree',
#  'at',
#  'christmas',
#  'external',
#  'heat',
#  'and',
#  'cold',
#  'had',
#  'little',
#  'influence',
#  'on',
#  'scrooge',
#  'no',
#  'warmth',
#  'could',
#  'warm',
#  'nor',
#  'wintry',
#  'weather',
#  'chill',
#  'him',
#  'no',
#  'wind',
#  'that',
#  'blew',
#  'was',
#  'bitterer',
#  'than',
#  'he',
#  'no',
#  'falling',
#  'snow',
#  'was',
#  'more',
#  'intent',
#  'upon',
#  'its',
#  'purpose',
#  'no',
#  'pelting',
#  'rain',
#  'less',
#  'open',
#  'to',
#  'entreaty',
#  'foul',
#  'weather',
#  'didn',
#  't',
#  'know',
#  'where',
#  'to',
#  'have',
#  'him',
#  'the',
#  'heaviest',
#  'rain',
#  'and',
#  'snow',
#  'and',
#  'hail',
#  'and',
#  'sleet',
#  'could',
#  'boast',
#  'of',
#  'the',
#  'advantage',
#  'over',
#  'him',
#  'in',
#  'only',
#  'one',
#  'respect',
#  'they',
#  'often',
#  'came',
#  'down',
#  'handsomely',
#  'and',
#  'scrooge',
#  'never',
#  'did',
#  'nobody',
#  'ever',
#  'stopped',
#  'him',
#  'in',
#  'the',
#  'street',
#  'to',
#  'say',
#  'with',
#  'gladsome',
#  'looks',
#  'my',
#  'dear',
#  'scrooge',
#  'how',
#  'are',
#  'you',
#  'when',
#  'will',
#  'you',
#  'come',
#  'to',
#  'see',
#  'me',
#  '?"',
#  'no',
#  'beggars',
#  'implored',
#  'him',
#  'to',
#  'bestow',
#  'a',
#  'trifle',
#  'no',
#  'children',
#  'asked',
#  'him',
#  'what',
#  'it',
#  'was',
#  'o',
#  'clock',
#  'no',
#  'man',
#  'or',
#  'woman',
#  'ever',
#  'once',
#  'in',
#  'all',
#  'his',
#  'life',
#  'inquired',
#  'the',
#  'way',
#  'to',
#  'such',
#  'and',
#  'such',
#  'a',
#  'place',
#  'of',
#  'scrooge',
#  'even',
#  'the',
#  'blindmen',
#  's',
#  'dogs',
#  'appeared',
#  'to',
#  'know',
#  'him',
#  'and',
#  'when',
#  'they',
#  'saw',
#  'him',
#  'coming',
#  'on',
#  'would',
#  'tug',
#  'their',
#  'owners',
#  'into',
#  'doorways',
#  'and',
#  'up',
#  'courts',
#  'and',
#  'then',
#  'would',
#  'wag',
#  'their',
#  'tails',
#  'as',
#  'though',
#  'they',
#  'said',
#  'no',
#  'eye',
#  'at',
#  'all',
#  'is',
#  'better',
#  'than',
#  'an',
#  'evil',
#  'eye',
#  'dark',
#  'master',
#  'but',
#  'what',
#  'did',
#  'scrooge',
#  'care',
#  'it',
#  'was',
#  'the',
#  'very',
#  'thing',
#  'he',
#  'liked',
#  'to',
#  'edge',
#  'his',
#  'way',
#  'along',
#  'the',
#  'crowded',
#  'paths',
#  'of',
#  'life',
#  'warning',
#  'all',
#  'human',
#  'sympathy',
#  'to',
#  'keep',
#  'its',
#  'distance',
#  'was',
#  'what',
#  'the',
#  'knowing',
#  'ones',
#  'call',
#  'nuts',
#  'to',
#  'scrooge',
#  'once',
#  'upon',
#  'a',
#  'time',
#  '--',
#  'of',
#  'all',
#  'the',
#  'good',
#  'days',
#  'in',
#  'the',
#  'year',
#  'on',
#  'christmas',
#  'eve',
#  '--',
#  'old',
#  'scrooge',
#  'sat',
#  'busy',
#  'in',
#  'his',
#  'counting',
#  'house',
#  'it',
#  'was',
#  'cold',
#  'bleak',
#  'biting',
#  'weather',
#  'foggy',
#  'withal',
#  'and',
#  'he',
#  'could',
#  'hear',
#  'the',
#  'people',
#  'in',
#  'the',
#  'court',
#  'outside',
#  'go',
#  'wheezing',
#  'up',
#  'and',
#  'down',
#  'beating',
#  'their',
#  'hands',
#  'upon',
#  'their',
#  'breasts',
#  'and',
#  'stamping',
#  'their',
#  'feet',
#  'upon',
#  'the',
#  'pavement',
#  'stones',
#  'to',
#  'warm',
#  'them',
#  'the',
#  'city',
#  'clocks',
#  'had',
#  'only',
#  'just',
#  'gone',
#  'three',
#  'but',
#  'it',
#  'was',
#  'quite',
#  'dark',
#  'already',
#  'it',
#  'had',
#  'not',
#  'been',
#  'light',
#  'all',
#  'day',
#  'and',
#  'candles',
#  'were',
#  'flaring',
#  'in',
#  'the',
#  'windows',
#  'of',
#  'the',
#  'neighbouring',
#  'offices',
#  'like',
#  'ruddy',
#  'smears',
#  'upon',
#  'the',
#  'palpable',
#  'brown',
#  'air',
#  'the',
#  'fog',
#  'came',
#  'pouring',
#  'in',
#  'at',
#  'every',
#  'chink',
#  'and',
#  'keyhole',
#  'and',
#  'was',
#  'so',
#  'dense',
#  'without',
#  'that',
#  'although',
#  'the',
#  'court',
#  'was',
#  'of',
#  'the',
#  'narrowest',
#  'the',
#  'houses',
#  'opposite',
#  'were',
#  'mere',
#  'phantoms',
#  'to',
#  'see',
#  'the',
#  'dingy',
#  'cloud',
#  'come',
#  'drooping',
#  'down',
#  'obscuring',
#  'everything',
#  'one',
#  'might',
#  'have',
#  'thought',
#  'that',
#  'nature',
#  'lived',
#  'hard',
#  'by',
#  'and',
#  'was',
#  'brewing',
#  'on',
#  'a',
#  'large',
#  'scale',
#  'the',
#  'door',
#  'of',
#  ...]

# %% [markdown]
# #### Display all the stop words

# %%
stop_words = stopwords.words('english')
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %% [markdown]
# #### Remove all the stop words

# %%
all_words = [word for word in cc_tokens if word not in stop_words]

# %% [markdown]
# #### Find the frequency of all of the words

# %%
all_fd = nltk.FreqDist(all_words)
all_fd
# Out:
# FreqDist({'scrooge': 357, 'said': 221, 'upon': 120, 'one': 111, 'ghost': 94, 'would': 94, 'spirit': 88, 'christmas': 86, 'man': 76, 'old': 69, ...})

# %% [markdown]
# #### Find the top 20 commonly used words

# %%
all_fd.most_common(20)
# Out:
# [('scrooge', 357),
#  ('said', 221),
#  ('upon', 120),
#  ('one', 111),
#  ('ghost', 94),
#  ('would', 94),
#  ('spirit', 88),
#  ('christmas', 86),
#  ('man', 76),
#  ('old', 69),
#  ('could', 69),
#  ('time', 66),
#  ('little', 64),
#  ('good', 63),
#  ('like', 60),
#  ('know', 59),
#  ('bob', 53),
#  ('cried', 52),
#  ('see', 47),
#  ('came', 46)]

# %% [markdown]
# #### Word(s) used only one are called Hapaxes

# %%
single_words = all_fd.hapaxes()
single_words
# Out:
# ['title',
#  'author',
#  'illustrator',
#  'john',
#  'leech',
#  'date',
#  'october',
#  'english',
#  'preface',
#  'readers',
#  'faithful',
#  'register',
#  'burial',
#  'clergyman',
#  'chief',
#  'particularly',
#  'regard',
#  'deadest',
#  'ironmongery',
#  'wisdom',
#  'ancestors',
#  'simile',
#  'unhallowed',
#  'disturb',
#  'permit',
#  'repeat',
#  'emphatically',
#  'executor',
#  'administrator',
#  'assign',
#  'residuary',
#  'legatee',
#  'dreadfully',
#  'sad',
#  'excellent',
#  'solemnised',
#  'undoubted',
#  'brings',
#  'distinctly',
#  'relate',
#  'hamlet',
#  'stroll',
#  'easterly',
#  'ramparts',
#  'rashly',
#  'breezy',
#  'spot',
#  'paul',
#  'instance',
#  'literally',
#  'astonish',
#  'painted',
#  'names',
#  'grindstone',
#  'squeezing',
#  'wrenching',
#  'covetous',
#  'sinner',
#  'flint',
#  'oyster',
#  'froze',
#  'stiffened',
#  'gait',
#  'thin',
#  'blue',
#  'shrewdly',
#  'grating',
#  'frosty',
#  'rime',
#  'wiry',
#  'temperature',
#  'iced',
#  'thaw',
#  'external',
#  'heat',
#  'chill',
#  'bitterer',
#  'pelting',
#  'heaviest',
#  'hail',
#  'sleet',
#  'boast',
#  'advantage',
#  'respect',
#  'handsomely',
#  'gladsome',
#  'implored',
#  'trifle',
#  'blindmen',
#  'tug',
#  'owners',
#  'doorways',
#  'courts',
#  'wag',
#  'tails',
#  'edge',
#  'crowded',
#  'paths',
#  'ones',
#  'withal',
#  'wheezing',
#  'beating',
#  'breasts',
#  'stamping',
#  'clocks',
#  'candles',
#  'smears',
#  'palpable',
#  'chink',
#  'narrowest',
#  'cloud',
#  'drooping',
#  'obscuring',
#  'brewing',
#  'scale',
#  'cell',
#  'copying',
#  'coal',
#  'replenish',
#  'kept',
#  'shovel',
#  'wherefore',
#  'imagination',
#  'failed',
#  'intimation',
#  'morose',
#  'spur',
#  'cross',
#  'fools',
#  'paying',
#  'bills',
#  'richer',
#  'balancing',
#  'item',
#  'months',
#  'idiot',
#  'stake',
#  'sternly',
#  'derived',
#  'profited',
#  'veneration',
#  'due',
#  'sacred',
#  'origin',
#  'forgiving',
#  'charitable',
#  'calendar',
#  'seem',
#  'freely',
#  'scrap',
#  'involuntarily',
#  'applauded',
#  'impropriety',
#  'poked',
#  'extinguished',
#  'frail',
#  'spark',
#  'losing',
#  'powerful',
#  'extremity',
#  'nay',
#  'resolute',
#  'trial',
#  'homage',
#  'greetings',
#  'warmer',
#  'cordially',
#  'overheard',
#  'talking',
#  'bedlam',
#  'lunatic',
#  'letting',
#  'hats',
#  'papers',
#  'bowed',
#  'referring',
#  'list',
#  'addressing',
#  'represented',
#  'surviving',
#  'presenting',
#  'kindred',
#  'ominous',
#  'frowned',
#  'handed',
#  'festive',
#  'desirable',
#  'provision',
#  'destitute',
#  'necessaries',
#  'comforts',
#  'union',
#  'operation',
#  'treadmill',
#  'law',
#  'occurred',
#  'useful',
#  'impression',
#  'furnish',
#  'multitude',
#  'fund',
#  'others',
#  'abundance',
#  'rejoices',
#  'anonymous',
#  'afford',
#  'support',
#  'establishments',
#  'badly',
#  'besides',
#  'occupies',
#  'constantly',
#  'useless',
#  'pursue',
#  'withdrew',
#  'labours',
#  'improved',
#  'meanwhile',
#  'thickened',
#  'links',
#  'proffering',
#  'services',
#  'horses',
#  'carriages',
#  'tower',
#  'gruff',
#  'slily',
#  'gothic',
#  'vibrations',
#  'intense',
#  'main',
#  'labourers',
#  'repairing',
#  'brazier',
#  'gathered',
#  'warming',
#  'rapture',
#  'waterplug',
#  'solitude',
#  'overflowings',
#  'sullenly',
#  'congealed',
#  'misanthropic',
#  'ice',
#  'sprigs',
#  'trades',
#  'pageant',
#  'principles',
#  'sale',
#  'mayor',
#  'stronghold',
#  'orders',
#  'cooks',
#  'butlers',
#  'household',
#  'tailor',
#  'fined',
#  'previous',
#  'monday',
#  'drunk',
#  'garret',
#  'lean',
#  'sallied',
#  'foggier',
#  'colder',
#  'piercing',
#  'searching',
#  'dunstan',
#  'weapons',
#  'lusty',
#  'scant',
#  'mumbled',
#  'stooped',
#  'regale',
#  'dismay',
#  'energy',
#  'singer',
#  'fled',
#  'congenial',
#  'arrived',
#  'dismounted',
#  'tacitly',
#  'admitted',
#  'expectant',
#  'snuffed',
#  'wages',
#  'picking',
#  'buttoning',
#  'earlier',
#  'twinkling',
#  'dangling',
#  'boasted',
#  'slide',
#  'cornhill',
#  'pelt',
#  'tavern',
#  'beguiled',
#  'belonged',
#  'deceased',
#  'suite',
#  'lowering',
#  'pile',
#  'fancying',
#  'run',
#  'playing',
#  'fain',
#  'grope',
#  'gateway',
#  'genius',
#  'meditation',
#  'residence',
#  'fancy',
#  'including',
#  'corporation',
#  'aldermen',
#  'livery',
#  'bestowed',
#  'explain',
#  'undergoing',
#  'intermediate',
#  'process',
#  'impenetrable',
#  'objects',
#  'lobster',
#  'spectacles',
#  'control',
#  'fixedly',
#  'stranger',
#  'infancy',
#  'untrue',
#  'relinquished',
#  'sturdily',
#  'irresolution',
#  'cautiously',
#  'terrified',
#  'sticking',
#  'screws',
#  'bang',
#  'resounded',
#  'thunder',
#  'cask',
#  'cellars',
#  'peal',
#  'trimming',
#  'vaguely',
#  'flight',
#  'staircase',
#  'broadwise',
#  'balustrades',
#  'width',
#  'spare',
#  'locomotive',
#  'entry',
#  'dip',
#  'button',
#  'grate',
#  'spoon',
#  'basin',
#  'suspicious',
#  'poker',
#  'custom',
#  'secured',
#  'bitter',
#  'extract',
#  'handful',
#  'merchant',
#  'paved',
#  'quaint',
#  'tiles',
#  'designed',
#  'illustrate',
#  'scriptures',
#  'cains',
#  'abels',
#  'pharaoh',
#  'queens',
#  'sheba',
#  'angelic',
#  'messengers',
#  'abrahams',
#  'belshazzars',
#  'apostles',
#  'attract',
#  'rod',
#  'tile',
#  'picture',
#  'surface',
#  'disjointed',
#  'copy',
#  'disused',
#  'communicated',
#  'highest',
#  'inexplicable',
#  'swing',
#  'swung',
#  'rang',
#  'lasted',
#  'clanking',
#  'casks',
#  'described',
#  'booming',
#  'louder',
#  'floors',
#  'flame',
#  'leaped',
#  'tights',
#  'bristling',
#  'cashboxes',
#  'padlocks',
#  'ledgers',
#  'purses',
#  'wrought',
#  'buttons',
#  'coat',
#  'chilling',
#  'marked',
#  'texture',
#  'folded',
#  'kerchief',
#  'incredulous',
#  'fought',
#  'caustic',
#  'substituted',
#  'appropriate',
#  'doubtfully',
#  'involve',
#  'necessity',
#  'embarrassing',
#  'evidence',
#  'reality',
#  'affects',
#  'disorder',
#  'stomach',
#  'cheats',
#  'undigested',
#  'blot',
#  'mustard',
#  'crumb',
#  'cheese',
#  'fragment',
#  'underdone',
#  'potato',
#  'cracking',
#  'jokes',
#  'waggish',
#  'distracting',
#  'marrow',
#  'glazed',
#  'deuce',
#  'infernal',
#  'vapour',
#  'toothpick',
#  'returning',
#  'assigned',
#  'wishing',
#  'divert',
#  'vision',
#  'stony',
#  'gaze',
#  'swallow',
#  'persecuted',
#  'legion',
#  'goblins',
#  'appalling',
#  'swoon',
#  'jaw',
#  'required',
#  'condemned',
#  'doomed',
#  'wander',
#  'woe',
#  'witness',
#  'share',
#  'wrung',
#  'fettered',
#  'forged',
#  'pattern',
#  'coil',
#  'eves',
#  'laboured',
#  'ponderous',
#  'sixty',
#  'fathoms',
#  'cable',
#  'imploringly',
#  'regions',
#  'ministers',
#  'permitted',
#  'linger',
#  'anywhere',
#  'roved',
#  'limits',
#  'weary',
#  'breeches',
#  'pondering',
#  'deference',
#  'mused',
#  'peace',
#  'remorse',
#  'wings',
#  'clanked',
#  'hideously',
#  'ward',
#  'indicting',
#  'nuisance',
#  'captive',
#  'ages',
#  'pass',
#  'eternity',
#  'susceptible',
#  'developed',
#  'sphere',
#  'usefulness',
#  'misused',
#  'wringing',
#  'mankind',
#  'charity',
#  'forbearance',
#  'dealings',
#  'ocean',
#  'unavailing',
#  'flung',
#  'crowds',
#  'star',
#  'abode',
#  'dismayed',
#  'quake',
#  'flowery',
#  'appear',
#  'agreeable',
#  'shivered',
#  'wiped',
#  'perspiration',
#  'penance',
#  'warn',
#  'escaping',
#  'procuring',
#  'countenance',
#  'faultering',
#  'visits',
#  'shun',
#  'tread',
#  'tolls',
#  'jaws',
#  'ventured',
#  'confronting',
#  'erect',
#  'backward',
#  'beckoned',
#  'paces',
#  'confused',
#  'noises',
#  'incoherent',
#  'lamentation',
#  'wailings',
#  'dirge',
#  'desperate',
#  'curiosity',
#  'hither',
#  'thither',
#  'haste',
#  'guilty',
#  'governments',
#  'linked',
#  'personally',
#  'safe',
#  'ancle',
#  'piteously',
#  'unable',
#  'infant',
#  'enshrouded',
#  'bolts',
#  'syllable',
#  'fatigues',
#  'glimpse',
#  'lateness',
#  'repose',
#  'undressing',
#  'ii',
#  'distinguish',
#  'opaque',
#  'pierce',
#  'ferret',
#  'regularly',
#  'icicle',
#  'works',
#  'repeater',
#  'preposterous',
#  'slept',
#  'noon',
#  'groped',
#  'rub',
#  'sleeve',
#  'stir',
#  'beaten',
#  'exchange',
#  'united',
#  'security',
#  'perplexed',
#  'bothered',
#  'mature',
#  'inquiry',
#  'position',
#  'problem',
#  'warned',
#  'visitation',
#  'tolled',
#  'awake',
#  'considering',
#  'wisest',
#  'resolution',
#  'sunk',
#  'doze',
#  'counting',
#  'triumphantly',
#  'flashed',
#  'unearthly',
#  'medium',
#  'receded',
#  'diminished',
#  'proportions',
#  'tenderest',
#  'bloom',
#  'skin',
#  'muscular',
#  'strength',
#  'delicately',
#  'formed',
#  'tunic',
#  'purest',
#  'lustrous',
#  'sheen',
#  'branch',
#  'singular',
#  'contradiction',
#  'emblem',
#  'flowers',
#  'crown',
#  'sprung',
#  'jet',
#  'doubtless',
#  'duller',
#  'increasing',
#  'glittered',
#  'fluctuated',
#  'distinctness',
#  'leg',
#  'dissolving',
#  'parts',
#  'outline',
#  'wherein',
#  'foretold',
#  'soft',
#  'singularly',
#  'observant',
#  'dwarfish',
#  'stature',
#  'special',
#  'passions',
#  'trains',
#  'disclaimed',
#  'intention',
#  'offend',
#  'wilfully',
#  'bonneted',
#  'inquire',
#  'conducive',
#  'reclamation',
#  'heed',
#  'rise',
#  'plead',
#  'adapted',
#  'pedestrian',
#  'thermometer',
#  'freezing',
#  'clad',
#  'nightcap',
#  'grasp',
#  'resisted',
#  'supplication',
#  'remonstrated',
#  'liable',
#  'upheld',
#  'entirely',
#  'vestige',
#  'clasping',
#  'gazed',
#  'instantaneous',
#  'odours',
#  'floating',
#  'joys',
#  'lip',
#  'unusual',
#  'pimple',
#  'fervour',
#  'blindfold',
#  'recognising',
#  'post',
#  'bridge',
#  'winding',
#  'river',
#  'shaggy',
#  'ponies',
#  'trotting',
#  'backs',
#  'gigs',
#  'driven',
#  'farmers',
#  'shouted',
#  'jocund',
#  'travellers',
#  'named',
#  'bounds',
#  'glisten',
#  'leap',
#  'gladness',
#  'deserted',
#  'sobbed',
#  'brick',
#  'cupola',
#  'fortunes',
#  'spacious',
#  'damp',
#  'gates',
#  'decayed',
#  'fowls',
#  'clucked',
#  'strutted',
#  'stables',
#  'sheds',
#  'retentive',
#  'glancing',
#  'furnished',
#  'earthy',
#  'savour',
#  'chilly',
#  'bareness',
#  'associated',
#  'barer',
#  'desks',
#  'feeble',
#  'wept',
#  'echo',
#  'squeak',
#  'scuffle',
#  'mice',
#  'panneling',
#  'drip',
#  'sigh',
#  'leafless',
#  'boughs',
#  'despondent',
#  'poplar',
#  'swinging',
#  'clicking',
#  'softening',
#  'freer',
#  'passage',
#  'suddenly',
#  'wonderfully',
#  'axe',
#  'leading',
#  'wood',
#  'bridle',
#  'valentine',
#  'orson',
#  'drawers',
#  'damascus',
#  'sultan',
#  'groom',
#  'genii',
#  'serve',
#  'princess',
#  'expending',
#  'heightened',
#  'lettuce',
#  'sailing',
#  'island',
#  'dreaming',
#  'friday',
#  'creek',
#  'halloa',
#  'hoop',
#  'halloo',
#  'rapidity',
#  'transition',
#  'character',
#  'drying',
#  'cuff',
#  'waved',
#  'larger',
#  'darker',
#  'dirty',
#  'panels',
#  'cracked',
#  'plaster',
#  'naked',
#  'laths',
#  'despairingly',
#  'anxiously',
#  'darting',
#  'bending',
#  'brimful',
#  'coach',
#  'merriest',
#  'tiptoe',
#  'embrace',
#  'drag',
#  'loth',
#  'box',
#  'condescension',
#  'veriest',
#  'shivering',
#  'maps',
#  'celestial',
#  'terrestrial',
#  'globes',
#  'waxy',
#  'decanter',
#  'block',
#  'administered',
#  'instalments',
#  'dainties',
#  'postboy',
#  'tap',
#  'trunk',
#  'tied',
#  'chaise',
#  'willingly',
#  'drove',
#  'dashing',
#  'evergreens',
#  'spray',
#  'delicate',
#  'gainsay',
#  'forbid',
#  'uneasy',
#  'briefly',
#  'thoroughfares',
#  'passengers',
#  'repassed',
#  'coaches',
#  'battled',
#  'strife',
#  'tumult',
#  'dressing',
#  'apprenticed',
#  'welch',
#  'wig',
#  'inches',
#  'taller',
#  'rubbed',
#  'organ',
#  'oily',
#  'wilkins',
#  'clap',
#  'jack',
#  'robinson',
#  'charged',
#  'pinned',
#  'panting',
#  'skipping',
#  'agility',
#  'lots',
#  'chirrup',
#  'movable',
#  'packed',
#  'dismissed',
#  'public',
#  'watered',
#  'orchestra',
#  'tuned',
#  'substantial',
#  'fezziwigs',
#  'loveable',
#  'followers',
#  'employed',
#  'housemaid',
#  'cousin',
#  'milkman',
#  'proved',
#  'shyly',
#  'boldly',
#  'awkwardly',
#  'pushing',
#  'pulling',
#  'anyhow',
#  'everyhow',
#  'various',
#  'stages',
#  'affectionate',
#  'grouping',
#  'couples',
#  'bottom',
#  'result',
#  'pot',
#  'scorning',
#  'reappearance',
#  'dancers',
#  'shutter',
#  'perish',
#  'negus',
#  'beer',
#  'roger',
#  'de',
#  'coverley',
#  'stiff',
#  'match',
#  'term',
#  'higher',
#  'positive',
#  'issue',
#  'calves',
#  'moons',
#  'advance',
#  'curtsey',
#  'corkscrew',
#  'deftly',
#  'wink',
#  'stagger',
#  'domestic',
#  'ball',
#  'individually',
#  'retired',
#  'acted',
#  'wits',
#  'corroborated',
#  'agitation',
#  'burnt',
#  'silly',
#  'folks',
#  'echoed',
#  'apprentices',
#  'spent',
#  'deserves',
#  'remark',
#  'speaking',
#  'burdensome',
#  'toil',
#  'insignificant',
#  'add',
#  'gives',
#  'insisted',
#  'utterance',
#  'grows',
#  'immediate',
#  'prime',
#  'harsh',
#  'greedy',
#  'root',
#  'grieve',
#  'rejoined',
#  'professes',
#  'condemn',
#  'severity',
#  'pursuit',
#  'merged',
#  'sordid',
#  'reproach',
#  'nobler',
#  'aspirations',
#  'engrosses',
#  'contract',
#  'improve',
#  'impatiently',
#  'tells',
#  'fraught',
#  'worth',
#  'win',
#  'justice',
#  'learned',
#  'dowerless',
#  'confidence',
#  'weigh',
#  'choosing',
#  'guiding',
#  'repentance',
#  'pain',
#  'unprofitable',
#  'chosen',
#  'relentless',
#  'pinioned',
#  'forced',
#  'comely',
#  'matron',
#  'tumultuous',
#  'celebrated',
#  'herd',
#  'poem',
#  'consequences',
#  'uproarious',
#  'belief',
#  'contrary',
#  'beginning',
#  'mingle',
#  'sports',
#  'pillaged',
#  'brigands',
#  'ruthlessly',
#  'crushed',
#  ...]

# %% [markdown]
# #### Remove all single words (hapaxes)

# %%
cc_words = [word for word in all_words if word not in single_words]

# %% [markdown]
# #### Number of words in The Christmas Carol

# %%
len(cc_words)
# Out:
# 11044

# %% [markdown]
# #### Number of unique words in The Christmas Carol

# %%
cc_fd = nltk.FreqDist(cc_words)
len(cc_fd)
# Out:
# 1697

# %% [markdown]
# #### Use Porter Stemmer to create the root words

# %%
porter = nltk.PorterStemmer()
cc_stems = [porter.stem(word) for word in cc_words]
cc_stems
# Out:
# ['christma',
#  'carol',
#  'charl',
#  'dicken',
#  'releas',
#  'languag',
#  'christma',
#  'carol',
#  'charl',
#  'dicken',
#  'ghost',
#  'stori',
#  'christma',
#  'endeavour',
#  'ghostli',
#  'littl',
#  'book',
#  'rais',
#  'ghost',
#  'idea',
#  'shall',
#  'put',
#  'humour',
#  'season',
#  'may',
#  'haunt',
#  'hous',
#  'pleasantli',
#  'one',
#  'wish',
#  'lay',
#  'friend',
#  'servant',
#  'decemb',
#  'stave',
#  'marley',
#  'ghost',
#  'marley',
#  'dead',
#  'begin',
#  'doubt',
#  'whatev',
#  'sign',
#  'clerk',
#  'undertak',
#  'mourner',
#  'scroog',
#  'sign',
#  'name',
#  'good',
#  'upon',
#  'anyth',
#  'chose',
#  'put',
#  'hand',
#  'old',
#  'marley',
#  'dead',
#  'mind',
#  'mean',
#  'say',
#  'know',
#  'knowledg',
#  'dead',
#  'might',
#  'inclin',
#  'piec',
#  'trade',
#  'hand',
#  'shall',
#  'countri',
#  'done',
#  'therefor',
#  'marley',
#  'dead',
#  'scroog',
#  'knew',
#  'dead',
#  'cours',
#  'could',
#  'otherwis',
#  'scroog',
#  'partner',
#  'know',
#  'mani',
#  'year',
#  'scroog',
#  'sole',
#  'sole',
#  'sole',
#  'sole',
#  'sole',
#  'friend',
#  'sole',
#  'mourner',
#  'even',
#  'scroog',
#  'cut',
#  'event',
#  'man',
#  'busi',
#  'day',
#  'funer',
#  'bargain',
#  'mention',
#  'marley',
#  'funer',
#  'back',
#  'point',
#  'start',
#  'doubt',
#  'marley',
#  'dead',
#  'must',
#  'understood',
#  'noth',
#  'wonder',
#  'come',
#  'stori',
#  'go',
#  'perfectli',
#  'convinc',
#  'father',
#  'die',
#  'play',
#  'began',
#  'would',
#  'noth',
#  'remark',
#  'take',
#  'night',
#  'wind',
#  'upon',
#  'would',
#  'gentleman',
#  'turn',
#  'dark',
#  'say',
#  'saint',
#  'churchyard',
#  'son',
#  'weak',
#  'mind',
#  'scroog',
#  'never',
#  'old',
#  'marley',
#  'name',
#  'stood',
#  'year',
#  'afterward',
#  'warehous',
#  'door',
#  'scroog',
#  'marley',
#  'firm',
#  'known',
#  'scroog',
#  'marley',
#  'sometim',
#  'peopl',
#  'new',
#  'busi',
#  'call',
#  'scroog',
#  'scroog',
#  'sometim',
#  'marley',
#  'answer',
#  'oh',
#  'hand',
#  'scroog',
#  'grasp',
#  'scrape',
#  'clutch',
#  'old',
#  'hard',
#  'sharp',
#  'steel',
#  'ever',
#  'struck',
#  'gener',
#  'fire',
#  'secret',
#  'solitari',
#  'cold',
#  'within',
#  'old',
#  'featur',
#  'nip',
#  'point',
#  'nose',
#  'shrivel',
#  'cheek',
#  'made',
#  'eye',
#  'red',
#  'lip',
#  'spoke',
#  'voic',
#  'head',
#  'eyebrow',
#  'chin',
#  'carri',
#  'low',
#  'alway',
#  'offic',
#  'one',
#  'degre',
#  'christma',
#  'cold',
#  'littl',
#  'influenc',
#  'scroog',
#  'warmth',
#  'could',
#  'warm',
#  'wintri',
#  'weather',
#  'wind',
#  'blew',
#  'fall',
#  'snow',
#  'intent',
#  'upon',
#  'purpos',
#  'rain',
#  'less',
#  'open',
#  'entreati',
#  'foul',
#  'weather',
#  'know',
#  'rain',
#  'snow',
#  'could',
#  'one',
#  'often',
#  'came',
#  'scroog',
#  'never',
#  'nobodi',
#  'ever',
#  'stop',
#  'street',
#  'say',
#  'look',
#  'dear',
#  'scroog',
#  'come',
#  'see',
#  'beggar',
#  'bestow',
#  'children',
#  'ask',
#  'man',
#  'woman',
#  'ever',
#  'life',
#  'inquir',
#  'way',
#  'place',
#  'scroog',
#  'even',
#  'dog',
#  'appear',
#  'know',
#  'saw',
#  'come',
#  'would',
#  'would',
#  'though',
#  'said',
#  'eye',
#  'better',
#  'evil',
#  'eye',
#  'dark',
#  'master',
#  'scroog',
#  'care',
#  'thing',
#  'like',
#  'way',
#  'along',
#  'life',
#  'warn',
#  'human',
#  'sympathi',
#  'keep',
#  'distanc',
#  'know',
#  'call',
#  'nut',
#  'scroog',
#  'upon',
#  'time',
#  'good',
#  'day',
#  'year',
#  'christma',
#  'eve',
#  'old',
#  'scroog',
#  'sat',
#  'busi',
#  'cold',
#  'bleak',
#  'bite',
#  'weather',
#  'foggi',
#  'could',
#  'hear',
#  'peopl',
#  'court',
#  'outsid',
#  'go',
#  'hand',
#  'upon',
#  'feet',
#  'upon',
#  'warm',
#  'citi',
#  'gone',
#  'three',
#  'quit',
#  'dark',
#  'alreadi',
#  'light',
#  'day',
#  'flare',
#  'window',
#  'neighbour',
#  'offic',
#  'like',
#  'ruddi',
#  'upon',
#  'brown',
#  'air',
#  'fog',
#  'came',
#  'pour',
#  'everi',
#  'keyhol',
#  'dens',
#  'without',
#  'although',
#  'court',
#  'hous',
#  'opposit',
#  'mere',
#  'phantom',
#  'see',
#  'dingi',
#  'come',
#  'everyth',
#  'one',
#  'might',
#  'thought',
#  'natur',
#  'live',
#  'hard',
#  'larg',
#  'door',
#  'scroog',
#  'open',
#  'might',
#  'keep',
#  'eye',
#  'upon',
#  'clerk',
#  'dismal',
#  'littl',
#  'beyond',
#  'sort',
#  'tank',
#  'letter',
#  'scroog',
#  'small',
#  'fire',
#  'clerk',
#  'fire',
#  'much',
#  'smaller',
#  'look',
#  'like',
#  'one',
#  'could',
#  'scroog',
#  'room',
#  'sure',
#  'clerk',
#  'came',
#  'master',
#  'predict',
#  'would',
#  'necessari',
#  'part',
#  'clerk',
#  'put',
#  'white',
#  'comfort',
#  'tri',
#  'warm',
#  'candl',
#  'effort',
#  'man',
#  'strong',
#  'merri',
#  'christma',
#  'uncl',
#  'god',
#  'save',
#  'cri',
#  'cheer',
#  'voic',
#  'voic',
#  'scroog',
#  'nephew',
#  'came',
#  'upon',
#  'quickli',
#  'first',
#  'approach',
#  'bah',
#  'said',
#  'scroog',
#  'humbug',
#  'heat',
#  'rapid',
#  'walk',
#  'fog',
#  'frost',
#  'nephew',
#  'scroog',
#  'glow',
#  'face',
#  'ruddi',
#  'handsom',
#  'eye',
#  'sparkl',
#  'breath',
#  'smoke',
#  'christma',
#  'humbug',
#  'uncl',
#  'said',
#  'scroog',
#  'nephew',
#  'mean',
#  'sure',
#  'said',
#  'scroog',
#  'merri',
#  'christma',
#  'right',
#  'merri',
#  'reason',
#  'merri',
#  'poor',
#  'enough',
#  'come',
#  'return',
#  'nephew',
#  'gaili',
#  'right',
#  'dismal',
#  'reason',
#  'rich',
#  'enough',
#  'scroog',
#  'better',
#  'answer',
#  'readi',
#  'moment',
#  'said',
#  'bah',
#  'follow',
#  'humbug',
#  'uncl',
#  'said',
#  'nephew',
#  'els',
#  'return',
#  'uncl',
#  'live',
#  'world',
#  'merri',
#  'christma',
#  'upon',
#  'merri',
#  'christma',
#  'christma',
#  'time',
#  'time',
#  'without',
#  'money',
#  'time',
#  'find',
#  'year',
#  'older',
#  'hour',
#  'time',
#  'book',
#  'everi',
#  'round',
#  'dozen',
#  'present',
#  'dead',
#  'could',
#  'work',
#  'said',
#  'scroog',
#  'indignantli',
#  'everi',
#  'goe',
#  'christma',
#  'lip',
#  'boil',
#  'pud',
#  'buri',
#  'holli',
#  'heart',
#  'uncl',
#  'plead',
#  'nephew',
#  'nephew',
#  'return',
#  'uncl',
#  'keep',
#  'christma',
#  'way',
#  'let',
#  'keep',
#  'mine',
#  'keep',
#  'repeat',
#  'scroog',
#  'nephew',
#  'keep',
#  'let',
#  'leav',
#  'alon',
#  'said',
#  'scroog',
#  'much',
#  'good',
#  'may',
#  'much',
#  'good',
#  'ever',
#  'done',
#  'mani',
#  'thing',
#  'might',
#  'good',
#  'dare',
#  'say',
#  'return',
#  'nephew',
#  'christma',
#  'among',
#  'rest',
#  'sure',
#  'alway',
#  'thought',
#  'christma',
#  'time',
#  'come',
#  'round',
#  'apart',
#  'name',
#  'anyth',
#  'belong',
#  'apart',
#  'good',
#  'time',
#  'kind',
#  'pleasant',
#  'time',
#  'time',
#  'know',
#  'long',
#  'year',
#  'men',
#  'women',
#  'one',
#  'consent',
#  'open',
#  'heart',
#  'think',
#  'peopl',
#  'realli',
#  'grave',
#  'anoth',
#  'race',
#  'creatur',
#  'bound',
#  'journey',
#  'therefor',
#  'uncl',
#  'though',
#  'never',
#  'put',
#  'gold',
#  'silver',
#  'pocket',
#  'believ',
#  'done',
#  'good',
#  'good',
#  'say',
#  'god',
#  'bless',
#  'clerk',
#  'tank',
#  'becom',
#  'immedi',
#  'sensibl',
#  'fire',
#  'last',
#  'ever',
#  'let',
#  'hear',
#  'anoth',
#  'sound',
#  'said',
#  'scroog',
#  'keep',
#  'christma',
#  'situat',
#  'quit',
#  'speaker',
#  'sir',
#  'ad',
#  'turn',
#  'nephew',
#  'wonder',
#  'go',
#  'parliament',
#  'angri',
#  'uncl',
#  'come',
#  'dine',
#  'us',
#  'scroog',
#  'said',
#  'would',
#  'see',
#  'ye',
#  'inde',
#  'went',
#  'whole',
#  'length',
#  'express',
#  'said',
#  'would',
#  'see',
#  'first',
#  'cri',
#  'scroog',
#  'nephew',
#  'get',
#  'marri',
#  'said',
#  'scroog',
#  'fell',
#  'love',
#  'fell',
#  'love',
#  'growl',
#  'scroog',
#  'one',
#  'thing',
#  'world',
#  'ridicul',
#  'merri',
#  'christma',
#  'good',
#  'afternoon',
#  'uncl',
#  'never',
#  'came',
#  'see',
#  'happen',
#  'give',
#  'reason',
#  'come',
#  'good',
#  'afternoon',
#  'said',
#  'scroog',
#  'want',
#  'noth',
#  'ask',
#  'noth',
#  'friend',
#  'good',
#  'afternoon',
#  'said',
#  'scroog',
#  'sorri',
#  'heart',
#  'find',
#  'never',
#  'quarrel',
#  'parti',
#  'made',
#  'christma',
#  'keep',
#  'christma',
#  'humour',
#  'last',
#  'merri',
#  'christma',
#  'uncl',
#  'good',
#  'afternoon',
#  'said',
#  'scroog',
#  'happi',
#  'new',
#  'year',
#  'good',
#  'afternoon',
#  'said',
#  'scroog',
#  'nephew',
#  'left',
#  'room',
#  'without',
#  'angri',
#  'word',
#  'notwithstand',
#  'stop',
#  'outer',
#  'door',
#  'bestow',
#  'season',
#  'clerk',
#  'cold',
#  'scroog',
#  'return',
#  'anoth',
#  'fellow',
#  'mutter',
#  'scroog',
#  'clerk',
#  'fifteen',
#  'shill',
#  'wife',
#  'famili',
#  'merri',
#  'christma',
#  'retir',
#  'scroog',
#  'nephew',
#  'let',
#  'two',
#  'peopl',
#  'portli',
#  'gentlemen',
#  'pleasant',
#  'behold',
#  'stood',
#  'scroog',
#  'offic',
#  'book',
#  'hand',
#  'scroog',
#  'marley',
#  'believ',
#  'said',
#  'one',
#  'gentlemen',
#  'pleasur',
#  'scroog',
#  'mr',
#  'marley',
#  'marley',
#  'dead',
#  'seven',
#  'year',
#  'scroog',
#  'repli',
#  'die',
#  'seven',
#  'year',
#  'ago',
#  'night',
#  'doubt',
#  'liber',
#  'well',
#  'partner',
#  'said',
#  'gentleman',
#  'credenti',
#  'certainli',
#  'two',
#  'spirit',
#  'word',
#  'liber',
#  'scroog',
#  'shook',
#  'head',
#  'credenti',
#  'back',
#  'season',
#  'year',
#  'scroog',
#  'said',
#  'gentleman',
#  'take',
#  'pen',
#  'usual',
#  'make',
#  'slight',
#  'poor',
#  'suffer',
#  'greatli',
#  'present',
#  'time',
#  'mani',
#  'thousand',
#  'want',
#  'common',
#  'hundr',
#  'thousand',
#  'want',
#  'common',
#  'sir',
#  'prison',
#  'ask',
#  'scroog',
#  'plenti',
#  'prison',
#  'said',
#  'gentleman',
#  'lay',
#  'pen',
#  'workhous',
#  'demand',
#  'scroog',
#  'still',
#  'still',
#  'return',
#  'gentleman',
#  'wish',
#  'could',
#  'say',
#  'poor',
#  'full',
#  'vigour',
#  'said',
#  'scroog',
#  'busi',
#  'sir',
#  'oh',
#  'afraid',
#  'said',
#  'first',
#  'someth',
#  'stop',
#  'cours',
#  'said',
#  'scroog',
#  'glad',
#  'hear',
#  'scarc',
#  'christian',
#  'cheer',
#  'mind',
#  'bodi',
#  'return',
#  'gentleman',
#  'us',
#  'endeavour',
#  'rais',
#  'buy',
#  'poor',
#  'meat',
#  'drink',
#  'mean',
#  'warmth',
#  'choos',
#  'time',
#  'time',
#  'want',
#  'keenli',
#  'felt',
#  'shall',
#  'put',
#  'noth',
#  'scroog',
#  'repli',
#  'wish',
#  'wish',
#  'left',
#  'alon',
#  'said',
#  'scroog',
#  'sinc',
#  'ask',
#  'wish',
#  'gentlemen',
#  'answer',
#  'make',
#  'merri',
#  'christma',
#  'ca',
#  'make',
#  'idl',
#  'peopl',
#  'merri',
#  'help',
#  'mention',
#  'cost',
#  'enough',
#  'must',
#  'go',
#  'mani',
#  'ca',
#  'go',
#  'mani',
#  'would',
#  'rather',
#  'die',
#  'would',
#  'rather',
#  'die',
#  'said',
#  'scroog',
#  'better',
#  'decreas',
#  'surplu',
#  'popul',
#  'excus',
#  'know',
#  'might',
#  'know',
#  'observ',
#  'gentleman',
#  'busi',
#  'scroog',
#  'return',
#  'enough',
#  'man',
#  'understand',
#  'busi',
#  'interfer',
#  'peopl',
#  'mine',
#  'good',
#  'afternoon',
#  'gentlemen',
#  'see',
#  'clearli',
#  'would',
#  'point',
#  'gentlemen',
#  'scroog',
#  'resum',
#  'opinion',
#  'faceti',
#  'temper',
#  'usual',
#  'fog',
#  'dark',
#  'peopl',
#  'ran',
#  'flare',
#  'go',
#  'conduct',
#  'way',
#  'ancient',
#  'church',
#  'whose',
#  'old',
#  'bell',
#  'alway',
#  'peep',
#  'scroog',
#  'window',
#  'wall',
#  'becam',
#  'invis',
#  'struck',
#  'hour',
#  'quarter',
#  'cloud',
#  'tremul',
#  'afterward',
#  'teeth',
#  'chatter',
#  'frozen',
#  'head',
#  'cold',
#  'becam',
#  'street',
#  'corner',
#  ...]

# %% [markdown]
# #### Unique words in The Christmas Carol (after Porter Stemming)

# %%
cc_stem_fd = nltk.FreqDist(cc_stems)
cc_stem_fd
# Out:
# FreqDist({'scroog': 357, 'said': 221, 'upon': 120, 'one': 111, 'spirit': 103, 'ghost': 96, 'would': 94, 'christma': 86, 'hand': 78, 'man': 76, ...})

# %% [markdown]
# #### Use Lancaster Stemmer to create the root words

# %%
lancaster = nltk.LancasterStemmer()
cc_stems = [lancaster.stem(word) for word in cc_words]
cc_stems
# Out:
# ['christmas',
#  'carol',
#  'charl',
#  'dick',
#  'releas',
#  'langu',
#  'christmas',
#  'carol',
#  'charl',
#  'dick',
#  'ghost',
#  'story',
#  'christmas',
#  'endeavo',
#  'ghost',
#  'littl',
#  'book',
#  'rais',
#  'ghost',
#  'ide',
#  'shal',
#  'put',
#  'humo',
#  'season',
#  'may',
#  'haunt',
#  'hous',
#  'pleas',
#  'on',
#  'wish',
#  'lay',
#  'friend',
#  'serv',
#  'decemb',
#  'stav',
#  'marley',
#  'ghost',
#  'marley',
#  'dead',
#  'begin',
#  'doubt',
#  'whatev',
#  'sign',
#  'clerk',
#  'undertak',
#  'mourn',
#  'scrooge',
#  'sign',
#  'nam',
#  'good',
#  'upon',
#  'anyth',
#  'chos',
#  'put',
#  'hand',
#  'old',
#  'marley',
#  'dead',
#  'mind',
#  'mean',
#  'say',
#  'know',
#  'knowledg',
#  'dead',
#  'might',
#  'inclin',
#  'piec',
#  'trad',
#  'hand',
#  'shal',
#  'country',
#  'don',
#  'theref',
#  'marley',
#  'dead',
#  'scrooge',
#  'knew',
#  'dead',
#  'cours',
#  'could',
#  'otherw',
#  'scrooge',
#  'partn',
#  'know',
#  'many',
#  'year',
#  'scrooge',
#  'sol',
#  'sol',
#  'sol',
#  'sol',
#  'sol',
#  'friend',
#  'sol',
#  'mourn',
#  'ev',
#  'scrooge',
#  'cut',
#  'ev',
#  'man',
#  'busy',
#  'day',
#  'fun',
#  'bargain',
#  'ment',
#  'marley',
#  'fun',
#  'back',
#  'point',
#  'start',
#  'doubt',
#  'marley',
#  'dead',
#  'must',
#  'understood',
#  'noth',
#  'wond',
#  'com',
#  'story',
#  'going',
#  'perfect',
#  'convint',
#  'fath',
#  'died',
#  'play',
#  'beg',
#  'would',
#  'noth',
#  'remark',
#  'tak',
#  'night',
#  'wind',
#  'upon',
#  'would',
#  'gentlem',
#  'turn',
#  'dark',
#  'say',
#  'saint',
#  'churchyard',
#  'son',
#  'weak',
#  'mind',
#  'scrooge',
#  'nev',
#  'old',
#  'marley',
#  'nam',
#  'stood',
#  'year',
#  'afterward',
#  'wareh',
#  'door',
#  'scrooge',
#  'marley',
#  'firm',
#  'known',
#  'scrooge',
#  'marley',
#  'sometim',
#  'peopl',
#  'new',
#  'busy',
#  'cal',
#  'scrooge',
#  'scrooge',
#  'sometim',
#  'marley',
#  'answ',
#  'oh',
#  'hand',
#  'scrooge',
#  'grasp',
#  'scraping',
#  'clutch',
#  'old',
#  'hard',
#  'sharp',
#  'steel',
#  'ev',
#  'struck',
#  'gen',
#  'fir',
#  'secret',
#  'solit',
#  'cold',
#  'within',
#  'old',
#  'feat',
#  'nip',
#  'point',
#  'nos',
#  'shrivelled',
#  'cheek',
#  'mad',
#  'ey',
#  'red',
#  'lip',
#  'spok',
#  'voic',
#  'head',
#  'eyebrow',
#  'chin',
#  'carry',
#  'low',
#  'alway',
#  'off',
#  'on',
#  'degr',
#  'christmas',
#  'cold',
#  'littl',
#  'influ',
#  'scrooge',
#  'warm',
#  'could',
#  'warm',
#  'wintry',
#  'weath',
#  'wind',
#  'blew',
#  'fal',
#  'snow',
#  'int',
#  'upon',
#  'purpos',
#  'rain',
#  'less',
#  'op',
#  'entreaty',
#  'foul',
#  'weath',
#  'know',
#  'rain',
#  'snow',
#  'could',
#  'on',
#  'oft',
#  'cam',
#  'scrooge',
#  'nev',
#  'nobody',
#  'ev',
#  'stop',
#  'street',
#  'say',
#  'look',
#  'dear',
#  'scrooge',
#  'com',
#  'see',
#  'begg',
#  'bestow',
#  'childr',
#  'ask',
#  'man',
#  'wom',
#  'ev',
#  'lif',
#  'inquir',
#  'way',
#  'plac',
#  'scrooge',
#  'ev',
#  'dog',
#  'appear',
#  'know',
#  'saw',
#  'com',
#  'would',
#  'would',
#  'though',
#  'said',
#  'ey',
#  'bet',
#  'evil',
#  'ey',
#  'dark',
#  'mast',
#  'scrooge',
#  'car',
#  'thing',
#  'lik',
#  'way',
#  'along',
#  'lif',
#  'warn',
#  'hum',
#  'sympathy',
#  'keep',
#  'dist',
#  'know',
#  'cal',
#  'nut',
#  'scrooge',
#  'upon',
#  'tim',
#  'good',
#  'day',
#  'year',
#  'christmas',
#  'ev',
#  'old',
#  'scrooge',
#  'sat',
#  'busy',
#  'cold',
#  'bleak',
#  'bit',
#  'weath',
#  'foggy',
#  'could',
#  'hear',
#  'peopl',
#  'court',
#  'outsid',
#  'go',
#  'hand',
#  'upon',
#  'feet',
#  'upon',
#  'warm',
#  'city',
#  'gon',
#  'three',
#  'quit',
#  'dark',
#  'already',
#  'light',
#  'day',
#  'flar',
#  'window',
#  'neighbo',
#  'off',
#  'lik',
#  'ruddy',
#  'upon',
#  'brown',
#  'air',
#  'fog',
#  'cam',
#  'pour',
#  'every',
#  'keyhol',
#  'dens',
#  'without',
#  'although',
#  'court',
#  'hous',
#  'opposit',
#  'mer',
#  'phantom',
#  'see',
#  'dingy',
#  'com',
#  'everyth',
#  'on',
#  'might',
#  'thought',
#  'nat',
#  'liv',
#  'hard',
#  'larg',
#  'door',
#  'scrooge',
#  'op',
#  'might',
#  'keep',
#  'ey',
#  'upon',
#  'clerk',
#  'dism',
#  'littl',
#  'beyond',
#  'sort',
#  'tank',
#  'let',
#  'scrooge',
#  'smal',
#  'fir',
#  'clerk',
#  'fir',
#  'much',
#  'smal',
#  'look',
#  'lik',
#  'on',
#  'could',
#  'scrooge',
#  'room',
#  'sur',
#  'clerk',
#  'cam',
#  'mast',
#  'predict',
#  'would',
#  'necess',
#  'part',
#  'clerk',
#  'put',
#  'whit',
#  'comfort',
#  'tri',
#  'warm',
#  'candl',
#  'effort',
#  'man',
#  'strong',
#  'merry',
#  'christmas',
#  'unc',
#  'god',
#  'sav',
#  'cri',
#  'che',
#  'voic',
#  'voic',
#  'scrooge',
#  'nephew',
#  'cam',
#  'upon',
#  'quick',
#  'first',
#  'approach',
#  'bah',
#  'said',
#  'scrooge',
#  'humbug',
#  'heat',
#  'rapid',
#  'walk',
#  'fog',
#  'frost',
#  'nephew',
#  'scrooge',
#  'glow',
#  'fac',
#  'ruddy',
#  'handsom',
#  'ey',
#  'sparkl',
#  'brea',
#  'smok',
#  'christmas',
#  'humbug',
#  'unc',
#  'said',
#  'scrooge',
#  'nephew',
#  'mean',
#  'sur',
#  'said',
#  'scrooge',
#  'merry',
#  'christmas',
#  'right',
#  'merry',
#  'reason',
#  'merry',
#  'poor',
#  'enough',
#  'com',
#  'return',
#  'nephew',
#  'gai',
#  'right',
#  'dism',
#  'reason',
#  'rich',
#  'enough',
#  'scrooge',
#  'bet',
#  'answ',
#  'ready',
#  'mom',
#  'said',
#  'bah',
#  'follow',
#  'humbug',
#  'unc',
#  'said',
#  'nephew',
#  'els',
#  'return',
#  'unc',
#  'liv',
#  'world',
#  'merry',
#  'christmas',
#  'upon',
#  'merry',
#  'christmas',
#  'christmas',
#  'tim',
#  'tim',
#  'without',
#  'money',
#  'tim',
#  'find',
#  'year',
#  'old',
#  'hour',
#  'tim',
#  'book',
#  'every',
#  'round',
#  'doz',
#  'pres',
#  'dead',
#  'could',
#  'work',
#  'said',
#  'scrooge',
#  'indign',
#  'every',
#  'goe',
#  'christmas',
#  'lip',
#  'boil',
#  'pud',
#  'bury',
#  'hol',
#  'heart',
#  'unc',
#  'plead',
#  'nephew',
#  'nephew',
#  'return',
#  'unc',
#  'keep',
#  'christmas',
#  'way',
#  'let',
#  'keep',
#  'min',
#  'keep',
#  'rep',
#  'scrooge',
#  'nephew',
#  'keep',
#  'let',
#  'leav',
#  'alon',
#  'said',
#  'scrooge',
#  'much',
#  'good',
#  'may',
#  'much',
#  'good',
#  'ev',
#  'don',
#  'many',
#  'thing',
#  'might',
#  'good',
#  'dar',
#  'say',
#  'return',
#  'nephew',
#  'christmas',
#  'among',
#  'rest',
#  'sur',
#  'alway',
#  'thought',
#  'christmas',
#  'tim',
#  'com',
#  'round',
#  'apart',
#  'nam',
#  'anyth',
#  'belong',
#  'apart',
#  'good',
#  'tim',
#  'kind',
#  'pleas',
#  'tim',
#  'tim',
#  'know',
#  'long',
#  'year',
#  'men',
#  'wom',
#  'on',
#  'cons',
#  'op',
#  'heart',
#  'think',
#  'peopl',
#  'real',
#  'grav',
#  'anoth',
#  'rac',
#  'cre',
#  'bound',
#  'journey',
#  'theref',
#  'unc',
#  'though',
#  'nev',
#  'put',
#  'gold',
#  'silv',
#  'pocket',
#  'believ',
#  'don',
#  'good',
#  'good',
#  'say',
#  'god',
#  'bless',
#  'clerk',
#  'tank',
#  'becom',
#  'immedy',
#  'sens',
#  'fir',
#  'last',
#  'ev',
#  'let',
#  'hear',
#  'anoth',
#  'sound',
#  'said',
#  'scrooge',
#  'keep',
#  'christmas',
#  'situ',
#  'quit',
#  'speak',
#  'sir',
#  'ad',
#  'turn',
#  'nephew',
#  'wond',
#  'go',
#  'parlia',
#  'angry',
#  'unc',
#  'com',
#  'din',
#  'us',
#  'scrooge',
#  'said',
#  'would',
#  'see',
#  'ye',
#  'indee',
#  'went',
#  'whol',
#  'leng',
#  'express',
#  'said',
#  'would',
#  'see',
#  'first',
#  'cri',
#  'scrooge',
#  'nephew',
#  'get',
#  'marry',
#  'said',
#  'scrooge',
#  'fel',
#  'lov',
#  'fel',
#  'lov',
#  'growl',
#  'scrooge',
#  'on',
#  'thing',
#  'world',
#  'ridic',
#  'merry',
#  'christmas',
#  'good',
#  'afternoon',
#  'unc',
#  'nev',
#  'cam',
#  'see',
#  'hap',
#  'giv',
#  'reason',
#  'com',
#  'good',
#  'afternoon',
#  'said',
#  'scrooge',
#  'want',
#  'noth',
#  'ask',
#  'noth',
#  'friend',
#  'good',
#  'afternoon',
#  'said',
#  'scrooge',
#  'sorry',
#  'heart',
#  'find',
#  'nev',
#  'quarrel',
#  'party',
#  'mad',
#  'christmas',
#  'keep',
#  'christmas',
#  'humo',
#  'last',
#  'merry',
#  'christmas',
#  'unc',
#  'good',
#  'afternoon',
#  'said',
#  'scrooge',
#  'happy',
#  'new',
#  'year',
#  'good',
#  'afternoon',
#  'said',
#  'scrooge',
#  'nephew',
#  'left',
#  'room',
#  'without',
#  'angry',
#  'word',
#  'notwithstand',
#  'stop',
#  'out',
#  'door',
#  'bestow',
#  'season',
#  'clerk',
#  'cold',
#  'scrooge',
#  'return',
#  'anoth',
#  'fellow',
#  'mut',
#  'scrooge',
#  'clerk',
#  'fifteen',
#  'shil',
#  'wif',
#  'famy',
#  'merry',
#  'christmas',
#  'retir',
#  'scrooge',
#  'nephew',
#  'let',
#  'two',
#  'peopl',
#  'port',
#  'gentlem',
#  'pleas',
#  'behold',
#  'stood',
#  'scrooge',
#  'off',
#  'book',
#  'hand',
#  'scrooge',
#  'marley',
#  'believ',
#  'said',
#  'on',
#  'gentlem',
#  'pleas',
#  'scrooge',
#  'mr',
#  'marley',
#  'marley',
#  'dead',
#  'sev',
#  'year',
#  'scrooge',
#  'reply',
#  'died',
#  'sev',
#  'year',
#  'ago',
#  'night',
#  'doubt',
#  'lib',
#  'wel',
#  'partn',
#  'said',
#  'gentlem',
#  'cred',
#  'certain',
#  'two',
#  'spirit',
#  'word',
#  'lib',
#  'scrooge',
#  'shook',
#  'head',
#  'cred',
#  'back',
#  'season',
#  'year',
#  'scrooge',
#  'said',
#  'gentlem',
#  'tak',
#  'pen',
#  'us',
#  'mak',
#  'slight',
#  'poor',
#  'suff',
#  'gre',
#  'pres',
#  'tim',
#  'many',
#  'thousand',
#  'want',
#  'common',
#  'hundr',
#  'thousand',
#  'want',
#  'common',
#  'sir',
#  'prison',
#  'ask',
#  'scrooge',
#  'plenty',
#  'prison',
#  'said',
#  'gentlem',
#  'lay',
#  'pen',
#  'workh',
#  'demand',
#  'scrooge',
#  'stil',
#  'stil',
#  'return',
#  'gentlem',
#  'wish',
#  'could',
#  'say',
#  'poor',
#  'ful',
#  'vigo',
#  'said',
#  'scrooge',
#  'busy',
#  'sir',
#  'oh',
#  'afraid',
#  'said',
#  'first',
#  'someth',
#  'stop',
#  'cours',
#  'said',
#  'scrooge',
#  'glad',
#  'hear',
#  'scarc',
#  'christian',
#  'che',
#  'mind',
#  'body',
#  'return',
#  'gentlem',
#  'us',
#  'endeavo',
#  'rais',
#  'buy',
#  'poor',
#  'meat',
#  'drink',
#  'mean',
#  'warm',
#  'choos',
#  'tim',
#  'tim',
#  'want',
#  'keen',
#  'felt',
#  'shal',
#  'put',
#  'noth',
#  'scrooge',
#  'reply',
#  'wish',
#  'wish',
#  'left',
#  'alon',
#  'said',
#  'scrooge',
#  'sint',
#  'ask',
#  'wish',
#  'gentlem',
#  'answ',
#  'mak',
#  'merry',
#  'christmas',
#  'ca',
#  'mak',
#  'idl',
#  'peopl',
#  'merry',
#  'help',
#  'ment',
#  'cost',
#  'enough',
#  'must',
#  'go',
#  'many',
#  'ca',
#  'go',
#  'many',
#  'would',
#  'rath',
#  'die',
#  'would',
#  'rath',
#  'die',
#  'said',
#  'scrooge',
#  'bet',
#  'decreas',
#  'surpl',
#  'pop',
#  'excus',
#  'know',
#  'might',
#  'know',
#  'observ',
#  'gentlem',
#  'busy',
#  'scrooge',
#  'return',
#  'enough',
#  'man',
#  'understand',
#  'busy',
#  'interf',
#  'peopl',
#  'min',
#  'good',
#  'afternoon',
#  'gentlem',
#  'see',
#  'clear',
#  'would',
#  'point',
#  'gentlem',
#  'scrooge',
#  'resum',
#  'opin',
#  'fac',
#  'temp',
#  'us',
#  'fog',
#  'dark',
#  'peopl',
#  'ran',
#  'flar',
#  'go',
#  'conduc',
#  'way',
#  'ant',
#  'church',
#  'whos',
#  'old',
#  'bel',
#  'alway',
#  'peep',
#  'scrooge',
#  'window',
#  'wal',
#  'becam',
#  'invis',
#  'struck',
#  'hour',
#  'quart',
#  'cloud',
#  'trem',
#  'afterward',
#  'tee',
#  'chat',
#  'froz',
#  'head',
#  'cold',
#  'becam',
#  'street',
#  'corn',
#  ...]

# %% [markdown]
# #### Unique words in The Christmas Carol (after Lancaster Stemming)

# %%
cc_stem_fd = nltk.FreqDist(cc_stems)
cc_stem_fd
# Out:
# FreqDist({'scrooge': 357, 'said': 221, 'upon': 120, 'on': 111, 'ghost': 103, 'spirit': 103, 'tim': 97, 'would': 94, 'christmas': 86, 'man': 79, ...})

# %% [markdown]
# #### Use Word Net Lemmatizer to create the root words

# %%
wordnet = nltk.WordNetLemmatizer()
cc_stems = [wordnet.lemmatize(word) for word in cc_words]
cc_stems
# Out:
# ['christmas',
#  'carol',
#  'charles',
#  'dickens',
#  'release',
#  'language',
#  'christmas',
#  'carol',
#  'charles',
#  'dickens',
#  'ghost',
#  'story',
#  'christmas',
#  'endeavoured',
#  'ghostly',
#  'little',
#  'book',
#  'raise',
#  'ghost',
#  'idea',
#  'shall',
#  'put',
#  'humour',
#  'season',
#  'may',
#  'haunt',
#  'house',
#  'pleasantly',
#  'one',
#  'wish',
#  'lay',
#  'friend',
#  'servant',
#  'december',
#  'stave',
#  'marley',
#  'ghost',
#  'marley',
#  'dead',
#  'begin',
#  'doubt',
#  'whatever',
#  'signed',
#  'clerk',
#  'undertaker',
#  'mourner',
#  'scrooge',
#  'signed',
#  'name',
#  'good',
#  'upon',
#  'anything',
#  'chose',
#  'put',
#  'hand',
#  'old',
#  'marley',
#  'dead',
#  'mind',
#  'mean',
#  'say',
#  'know',
#  'knowledge',
#  'dead',
#  'might',
#  'inclined',
#  'piece',
#  'trade',
#  'hand',
#  'shall',
#  'country',
#  'done',
#  'therefore',
#  'marley',
#  'dead',
#  'scrooge',
#  'knew',
#  'dead',
#  'course',
#  'could',
#  'otherwise',
#  'scrooge',
#  'partner',
#  'know',
#  'many',
#  'year',
#  'scrooge',
#  'sole',
#  'sole',
#  'sole',
#  'sole',
#  'sole',
#  'friend',
#  'sole',
#  'mourner',
#  'even',
#  'scrooge',
#  'cut',
#  'event',
#  'man',
#  'business',
#  'day',
#  'funeral',
#  'bargain',
#  'mention',
#  'marley',
#  'funeral',
#  'back',
#  'point',
#  'started',
#  'doubt',
#  'marley',
#  'dead',
#  'must',
#  'understood',
#  'nothing',
#  'wonderful',
#  'come',
#  'story',
#  'going',
#  'perfectly',
#  'convinced',
#  'father',
#  'died',
#  'play',
#  'began',
#  'would',
#  'nothing',
#  'remarkable',
#  'taking',
#  'night',
#  'wind',
#  'upon',
#  'would',
#  'gentleman',
#  'turning',
#  'dark',
#  'say',
#  'saint',
#  'churchyard',
#  'son',
#  'weak',
#  'mind',
#  'scrooge',
#  'never',
#  'old',
#  'marley',
#  'name',
#  'stood',
#  'year',
#  'afterwards',
#  'warehouse',
#  'door',
#  'scrooge',
#  'marley',
#  'firm',
#  'known',
#  'scrooge',
#  'marley',
#  'sometimes',
#  'people',
#  'new',
#  'business',
#  'called',
#  'scrooge',
#  'scrooge',
#  'sometimes',
#  'marley',
#  'answered',
#  'oh',
#  'hand',
#  'scrooge',
#  'grasping',
#  'scraping',
#  'clutching',
#  'old',
#  'hard',
#  'sharp',
#  'steel',
#  'ever',
#  'struck',
#  'generous',
#  'fire',
#  'secret',
#  'solitary',
#  'cold',
#  'within',
#  'old',
#  'feature',
#  'nipped',
#  'pointed',
#  'nose',
#  'shrivelled',
#  'cheek',
#  'made',
#  'eye',
#  'red',
#  'lip',
#  'spoke',
#  'voice',
#  'head',
#  'eyebrow',
#  'chin',
#  'carried',
#  'low',
#  'always',
#  'office',
#  'one',
#  'degree',
#  'christmas',
#  'cold',
#  'little',
#  'influence',
#  'scrooge',
#  'warmth',
#  'could',
#  'warm',
#  'wintry',
#  'weather',
#  'wind',
#  'blew',
#  'falling',
#  'snow',
#  'intent',
#  'upon',
#  'purpose',
#  'rain',
#  'le',
#  'open',
#  'entreaty',
#  'foul',
#  'weather',
#  'know',
#  'rain',
#  'snow',
#  'could',
#  'one',
#  'often',
#  'came',
#  'scrooge',
#  'never',
#  'nobody',
#  'ever',
#  'stopped',
#  'street',
#  'say',
#  'look',
#  'dear',
#  'scrooge',
#  'come',
#  'see',
#  'beggar',
#  'bestow',
#  'child',
#  'asked',
#  'man',
#  'woman',
#  'ever',
#  'life',
#  'inquired',
#  'way',
#  'place',
#  'scrooge',
#  'even',
#  'dog',
#  'appeared',
#  'know',
#  'saw',
#  'coming',
#  'would',
#  'would',
#  'though',
#  'said',
#  'eye',
#  'better',
#  'evil',
#  'eye',
#  'dark',
#  'master',
#  'scrooge',
#  'care',
#  'thing',
#  'liked',
#  'way',
#  'along',
#  'life',
#  'warning',
#  'human',
#  'sympathy',
#  'keep',
#  'distance',
#  'knowing',
#  'call',
#  'nut',
#  'scrooge',
#  'upon',
#  'time',
#  'good',
#  'day',
#  'year',
#  'christmas',
#  'eve',
#  'old',
#  'scrooge',
#  'sat',
#  'busy',
#  'cold',
#  'bleak',
#  'biting',
#  'weather',
#  'foggy',
#  'could',
#  'hear',
#  'people',
#  'court',
#  'outside',
#  'go',
#  'hand',
#  'upon',
#  'foot',
#  'upon',
#  'warm',
#  'city',
#  'gone',
#  'three',
#  'quite',
#  'dark',
#  'already',
#  'light',
#  'day',
#  'flaring',
#  'window',
#  'neighbouring',
#  'office',
#  'like',
#  'ruddy',
#  'upon',
#  'brown',
#  'air',
#  'fog',
#  'came',
#  'pouring',
#  'every',
#  'keyhole',
#  'dense',
#  'without',
#  'although',
#  'court',
#  'house',
#  'opposite',
#  'mere',
#  'phantom',
#  'see',
#  'dingy',
#  'come',
#  'everything',
#  'one',
#  'might',
#  'thought',
#  'nature',
#  'lived',
#  'hard',
#  'large',
#  'door',
#  'scrooge',
#  'open',
#  'might',
#  'keep',
#  'eye',
#  'upon',
#  'clerk',
#  'dismal',
#  'little',
#  'beyond',
#  'sort',
#  'tank',
#  'letter',
#  'scrooge',
#  'small',
#  'fire',
#  'clerk',
#  'fire',
#  'much',
#  'smaller',
#  'looked',
#  'like',
#  'one',
#  'could',
#  'scrooge',
#  'room',
#  'surely',
#  'clerk',
#  'came',
#  'master',
#  'predicted',
#  'would',
#  'necessary',
#  'part',
#  'clerk',
#  'put',
#  'white',
#  'comforter',
#  'tried',
#  'warm',
#  'candle',
#  'effort',
#  'man',
#  'strong',
#  'merry',
#  'christmas',
#  'uncle',
#  'god',
#  'save',
#  'cried',
#  'cheerful',
#  'voice',
#  'voice',
#  'scrooge',
#  'nephew',
#  'came',
#  'upon',
#  'quickly',
#  'first',
#  'approach',
#  'bah',
#  'said',
#  'scrooge',
#  'humbug',
#  'heated',
#  'rapid',
#  'walking',
#  'fog',
#  'frost',
#  'nephew',
#  'scrooge',
#  'glow',
#  'face',
#  'ruddy',
#  'handsome',
#  'eye',
#  'sparkled',
#  'breath',
#  'smoked',
#  'christmas',
#  'humbug',
#  'uncle',
#  'said',
#  'scrooge',
#  'nephew',
#  'mean',
#  'sure',
#  'said',
#  'scrooge',
#  'merry',
#  'christmas',
#  'right',
#  'merry',
#  'reason',
#  'merry',
#  'poor',
#  'enough',
#  'come',
#  'returned',
#  'nephew',
#  'gaily',
#  'right',
#  'dismal',
#  'reason',
#  'rich',
#  'enough',
#  'scrooge',
#  'better',
#  'answer',
#  'ready',
#  'moment',
#  'said',
#  'bah',
#  'followed',
#  'humbug',
#  'uncle',
#  'said',
#  'nephew',
#  'else',
#  'returned',
#  'uncle',
#  'live',
#  'world',
#  'merry',
#  'christmas',
#  'upon',
#  'merry',
#  'christmas',
#  'christmas',
#  'time',
#  'time',
#  'without',
#  'money',
#  'time',
#  'finding',
#  'year',
#  'older',
#  'hour',
#  'time',
#  'book',
#  'every',
#  'round',
#  'dozen',
#  'presented',
#  'dead',
#  'could',
#  'work',
#  'said',
#  'scrooge',
#  'indignantly',
#  'every',
#  'go',
#  'christmas',
#  'lip',
#  'boiled',
#  'pudding',
#  'buried',
#  'holly',
#  'heart',
#  'uncle',
#  'pleaded',
#  'nephew',
#  'nephew',
#  'returned',
#  'uncle',
#  'keep',
#  'christmas',
#  'way',
#  'let',
#  'keep',
#  'mine',
#  'keep',
#  'repeated',
#  'scrooge',
#  'nephew',
#  'keep',
#  'let',
#  'leave',
#  'alone',
#  'said',
#  'scrooge',
#  'much',
#  'good',
#  'may',
#  'much',
#  'good',
#  'ever',
#  'done',
#  'many',
#  'thing',
#  'might',
#  'good',
#  'dare',
#  'say',
#  'returned',
#  'nephew',
#  'christmas',
#  'among',
#  'rest',
#  'sure',
#  'always',
#  'thought',
#  'christmas',
#  'time',
#  'come',
#  'round',
#  'apart',
#  'name',
#  'anything',
#  'belonging',
#  'apart',
#  'good',
#  'time',
#  'kind',
#  'pleasant',
#  'time',
#  'time',
#  'know',
#  'long',
#  'year',
#  'men',
#  'woman',
#  'one',
#  'consent',
#  'open',
#  'heart',
#  'think',
#  'people',
#  'really',
#  'grave',
#  'another',
#  'race',
#  'creature',
#  'bound',
#  'journey',
#  'therefore',
#  'uncle',
#  'though',
#  'never',
#  'put',
#  'gold',
#  'silver',
#  'pocket',
#  'believe',
#  'done',
#  'good',
#  'good',
#  'say',
#  'god',
#  'bless',
#  'clerk',
#  'tank',
#  'becoming',
#  'immediately',
#  'sensible',
#  'fire',
#  'last',
#  'ever',
#  'let',
#  'hear',
#  'another',
#  'sound',
#  'said',
#  'scrooge',
#  'keep',
#  'christmas',
#  'situation',
#  'quite',
#  'speaker',
#  'sir',
#  'added',
#  'turning',
#  'nephew',
#  'wonder',
#  'go',
#  'parliament',
#  'angry',
#  'uncle',
#  'come',
#  'dine',
#  'u',
#  'scrooge',
#  'said',
#  'would',
#  'see',
#  'yes',
#  'indeed',
#  'went',
#  'whole',
#  'length',
#  'expression',
#  'said',
#  'would',
#  'see',
#  'first',
#  'cried',
#  'scrooge',
#  'nephew',
#  'get',
#  'married',
#  'said',
#  'scrooge',
#  'fell',
#  'love',
#  'fell',
#  'love',
#  'growled',
#  'scrooge',
#  'one',
#  'thing',
#  'world',
#  'ridiculous',
#  'merry',
#  'christmas',
#  'good',
#  'afternoon',
#  'uncle',
#  'never',
#  'came',
#  'see',
#  'happened',
#  'give',
#  'reason',
#  'coming',
#  'good',
#  'afternoon',
#  'said',
#  'scrooge',
#  'want',
#  'nothing',
#  'ask',
#  'nothing',
#  'friend',
#  'good',
#  'afternoon',
#  'said',
#  'scrooge',
#  'sorry',
#  'heart',
#  'find',
#  'never',
#  'quarrel',
#  'party',
#  'made',
#  'christmas',
#  'keep',
#  'christmas',
#  'humour',
#  'last',
#  'merry',
#  'christmas',
#  'uncle',
#  'good',
#  'afternoon',
#  'said',
#  'scrooge',
#  'happy',
#  'new',
#  'year',
#  'good',
#  'afternoon',
#  'said',
#  'scrooge',
#  'nephew',
#  'left',
#  'room',
#  'without',
#  'angry',
#  'word',
#  'notwithstanding',
#  'stopped',
#  'outer',
#  'door',
#  'bestow',
#  'season',
#  'clerk',
#  'cold',
#  'scrooge',
#  'returned',
#  'another',
#  'fellow',
#  'muttered',
#  'scrooge',
#  'clerk',
#  'fifteen',
#  'shilling',
#  'wife',
#  'family',
#  'merry',
#  'christmas',
#  'retire',
#  'scrooge',
#  'nephew',
#  'let',
#  'two',
#  'people',
#  'portly',
#  'gentleman',
#  'pleasant',
#  'behold',
#  'stood',
#  'scrooge',
#  'office',
#  'book',
#  'hand',
#  'scrooge',
#  'marley',
#  'believe',
#  'said',
#  'one',
#  'gentleman',
#  'pleasure',
#  'scrooge',
#  'mr',
#  'marley',
#  'marley',
#  'dead',
#  'seven',
#  'year',
#  'scrooge',
#  'replied',
#  'died',
#  'seven',
#  'year',
#  'ago',
#  'night',
#  'doubt',
#  'liberality',
#  'well',
#  'partner',
#  'said',
#  'gentleman',
#  'credential',
#  'certainly',
#  'two',
#  'spirit',
#  'word',
#  'liberality',
#  'scrooge',
#  'shook',
#  'head',
#  'credential',
#  'back',
#  'season',
#  'year',
#  'scrooge',
#  'said',
#  'gentleman',
#  'taking',
#  'pen',
#  'usually',
#  'make',
#  'slight',
#  'poor',
#  'suffer',
#  'greatly',
#  'present',
#  'time',
#  'many',
#  'thousand',
#  'want',
#  'common',
#  'hundred',
#  'thousand',
#  'want',
#  'common',
#  'sir',
#  'prison',
#  'asked',
#  'scrooge',
#  'plenty',
#  'prison',
#  'said',
#  'gentleman',
#  'laying',
#  'pen',
#  'workhouse',
#  'demanded',
#  'scrooge',
#  'still',
#  'still',
#  'returned',
#  'gentleman',
#  'wish',
#  'could',
#  'say',
#  'poor',
#  'full',
#  'vigour',
#  'said',
#  'scrooge',
#  'busy',
#  'sir',
#  'oh',
#  'afraid',
#  'said',
#  'first',
#  'something',
#  'stop',
#  'course',
#  'said',
#  'scrooge',
#  'glad',
#  'hear',
#  'scarcely',
#  'christian',
#  'cheer',
#  'mind',
#  'body',
#  'returned',
#  'gentleman',
#  'u',
#  'endeavouring',
#  'raise',
#  'buy',
#  'poor',
#  'meat',
#  'drink',
#  'mean',
#  'warmth',
#  'choose',
#  'time',
#  'time',
#  'want',
#  'keenly',
#  'felt',
#  'shall',
#  'put',
#  'nothing',
#  'scrooge',
#  'replied',
#  'wish',
#  'wish',
#  'left',
#  'alone',
#  'said',
#  'scrooge',
#  'since',
#  'ask',
#  'wish',
#  'gentleman',
#  'answer',
#  'make',
#  'merry',
#  'christmas',
#  'ca',
#  'make',
#  'idle',
#  'people',
#  'merry',
#  'help',
#  'mentioned',
#  'cost',
#  'enough',
#  'must',
#  'go',
#  'many',
#  'ca',
#  'go',
#  'many',
#  'would',
#  'rather',
#  'die',
#  'would',
#  'rather',
#  'die',
#  'said',
#  'scrooge',
#  'better',
#  'decrease',
#  'surplus',
#  'population',
#  'excuse',
#  'know',
#  'might',
#  'know',
#  'observed',
#  'gentleman',
#  'business',
#  'scrooge',
#  'returned',
#  'enough',
#  'man',
#  'understand',
#  'business',
#  'interfere',
#  'people',
#  'mine',
#  'good',
#  'afternoon',
#  'gentleman',
#  'seeing',
#  'clearly',
#  'would',
#  'point',
#  'gentleman',
#  'scrooge',
#  'resumed',
#  'opinion',
#  'facetious',
#  'temper',
#  'usual',
#  'fog',
#  'darkness',
#  'people',
#  'ran',
#  'flaring',
#  'go',
#  'conduct',
#  'way',
#  'ancient',
#  'church',
#  'whose',
#  'old',
#  'bell',
#  'always',
#  'peeping',
#  'scrooge',
#  'window',
#  'wall',
#  'became',
#  'invisible',
#  'struck',
#  'hour',
#  'quarter',
#  'cloud',
#  'tremulous',
#  'afterwards',
#  'teeth',
#  'chattering',
#  'frozen',
#  'head',
#  'cold',
#  'became',
#  'street',
#  'corner',
#  ...]

# %% [markdown]
# #### Unique words in The Christmas Carol (after Word Net Lemmatization)

# %%
cc_stem_fd = nltk.FreqDist(cc_stems)
cc_stem_fd
# Out:
# FreqDist({'scrooge': 357, 'said': 221, 'upon': 120, 'one': 111, 'spirit': 103, 'ghost': 96, 'would': 94, 'christmas': 86, 'hand': 78, 'man': 76, ...})

# %% [markdown]
# #### Display the abbreviations (along with their meaning) for the various Parts of Speech tags

# %%
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# LS: list item marker
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# PDT: pre-determiner
#     all both half many quite such sure this
# POS: genitive marker
#     ' 's
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# SYM: symbol
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
# TO: "to" as preposition or infinitive marker
#     to
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# WDT: WH-determiner
#     that what whatever which whichever
# WP: WH-pronoun
#     that what whatever whatsoever which who whom whosoever
# WP$: WH-pronoun, possessive
#     whose
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# ``: opening quotation mark
#     ` ``

# %% [markdown]
# #### Determine the Parts of Speech tag for the words in The Christmas Carol

# %%
cc_pos = nltk.pos_tag(cc_words)
cc_pos
# Out:
# [('christmas', 'NNS'),
#  ('carol', 'VBP'),
#  ('charles', 'NNS'),
#  ('dickens', 'NNS'),
#  ('release', 'VBP'),
#  ('language', 'NN'),
#  ('christmas', 'NN'),
#  ('carol', 'NN'),
#  ('charles', 'VBZ'),
#  ('dickens', 'VBZ'),
#  ('ghost', 'NN'),
#  ('story', 'NN'),
#  ('christmas', 'NN'),
#  ('endeavoured', 'VBD'),
#  ('ghostly', 'RB'),
#  ('little', 'JJ'),
#  ('book', 'NN'),
#  ('raise', 'NN'),
#  ('ghost', 'NN'),
#  ('idea', 'NN'),
#  ('shall', 'MD'),
#  ('put', 'VB'),
#  ('humour', 'CD'),
#  ('season', 'NN'),
#  ('may', 'MD'),
#  ('haunt', 'VB'),
#  ('houses', 'NNS'),
#  ('pleasantly', 'RB'),
#  ('one', 'CD'),
#  ('wish', 'JJ'),
#  ('lay', 'NN'),
#  ('friend', 'NN'),
#  ('servant', 'JJ'),
#  ('december', 'NN'),
#  ('stave', 'VBP'),
#  ('marley', 'NN'),
#  ('ghost', 'NN'),
#  ('marley', 'NN'),
#  ('dead', 'JJ'),
#  ('begin', 'NN'),
#  ('doubt', 'NN'),
#  ('whatever', 'WDT'),
#  ('signed', 'VBD'),
#  ('clerk', 'NN'),
#  ('undertaker', 'NN'),
#  ('mourner', 'NN'),
#  ('scrooge', 'NN'),
#  ('signed', 'VBD'),
#  ('name', 'RB'),
#  ('good', 'JJ'),
#  ('upon', 'IN'),
#  ('anything', 'NN'),
#  ('chose', 'JJ'),
#  ('put', 'VBD'),
#  ('hand', 'NN'),
#  ('old', 'JJ'),
#  ('marley', 'NN'),
#  ('dead', 'JJ'),
#  ('mind', 'NN'),
#  ('mean', 'JJ'),
#  ('say', 'VBP'),
#  ('know', 'VBP'),
#  ('knowledge', 'VBP'),
#  ('dead', 'JJ'),
#  ('might', 'MD'),
#  ('inclined', 'VBN'),
#  ('piece', 'RB'),
#  ('trade', 'NN'),
#  ('hands', 'NNS'),
#  ('shall', 'MD'),
#  ('country', 'NN'),
#  ('done', 'VBN'),
#  ('therefore', 'RB'),
#  ('marley', 'JJ'),
#  ('dead', 'JJ'),
#  ('scrooge', 'NN'),
#  ('knew', 'VBD'),
#  ('dead', 'JJ'),
#  ('course', 'NN'),
#  ('could', 'MD'),
#  ('otherwise', 'VB'),
#  ('scrooge', 'JJ'),
#  ('partners', 'NNS'),
#  ('know', 'VBP'),
#  ('many', 'JJ'),
#  ('years', 'NNS'),
#  ('scrooge', 'VBP'),
#  ('sole', 'JJ'),
#  ('sole', 'JJ'),
#  ('sole', 'JJ'),
#  ('sole', 'JJ'),
#  ('sole', 'NN'),
#  ('friend', 'NN'),
#  ('sole', 'NN'),
#  ('mourner', 'NN'),
#  ('even', 'RB'),
#  ('scrooge', 'VBD'),
#  ('cut', 'JJ'),
#  ('event', 'NN'),
#  ('man', 'NN'),
#  ('business', 'NN'),
#  ('day', 'NN'),
#  ('funeral', 'JJ'),
#  ('bargain', 'NN'),
#  ('mention', 'NN'),
#  ('marley', 'FW'),
#  ('funeral', 'JJ'),
#  ('back', 'RB'),
#  ('point', 'NN'),
#  ('started', 'VBD'),
#  ('doubt', 'NN'),
#  ('marley', 'NN'),
#  ('dead', 'JJ'),
#  ('must', 'MD'),
#  ('understood', 'VB'),
#  ('nothing', 'NN'),
#  ('wonderful', 'JJ'),
#  ('come', 'JJ'),
#  ('story', 'NN'),
#  ('going', 'VBG'),
#  ('perfectly', 'RB'),
#  ('convinced', 'VBN'),
#  ('father', 'NN'),
#  ('died', 'VBD'),
#  ('play', 'NN'),
#  ('began', 'VBD'),
#  ('would', 'MD'),
#  ('nothing', 'NN'),
#  ('remarkable', 'VB'),
#  ('taking', 'VBG'),
#  ('night', 'NN'),
#  ('wind', 'NN'),
#  ('upon', 'NN'),
#  ('would', 'MD'),
#  ('gentleman', 'VB'),
#  ('turning', 'VBG'),
#  ('dark', 'JJ'),
#  ('say', 'VBP'),
#  ('saint', 'JJ'),
#  ('churchyard', 'NN'),
#  ('son', 'NN'),
#  ('weak', 'JJ'),
#  ('mind', 'NN'),
#  ('scrooge', 'NN'),
#  ('never', 'RB'),
#  ('old', 'JJ'),
#  ('marley', 'NN'),
#  ('name', 'NN'),
#  ('stood', 'VBD'),
#  ('years', 'NNS'),
#  ('afterwards', 'NNS'),
#  ('warehouse', 'VBP'),
#  ('door', 'JJ'),
#  ('scrooge', 'NN'),
#  ('marley', 'NN'),
#  ('firm', 'NN'),
#  ('known', 'VBN'),
#  ('scrooge', 'JJ'),
#  ('marley', 'NN'),
#  ('sometimes', 'RB'),
#  ('people', 'NNS'),
#  ('new', 'JJ'),
#  ('business', 'NN'),
#  ('called', 'VBN'),
#  ('scrooge', 'NN'),
#  ('scrooge', 'NN'),
#  ('sometimes', 'RB'),
#  ('marley', 'RB'),
#  ('answered', 'JJ'),
#  ('oh', 'JJ'),
#  ('hand', 'NN'),
#  ('scrooge', 'NN'),
#  ('grasping', 'VBG'),
#  ('scraping', 'VBG'),
#  ('clutching', 'VBG'),
#  ('old', 'JJ'),
#  ('hard', 'JJ'),
#  ('sharp', 'JJ'),
#  ('steel', 'NN'),
#  ('ever', 'RB'),
#  ('struck', 'VBD'),
#  ('generous', 'JJ'),
#  ('fire', 'NN'),
#  ('secret', 'JJ'),
#  ('solitary', 'JJ'),
#  ('cold', 'NN'),
#  ('within', 'IN'),
#  ('old', 'JJ'),
#  ('features', 'NNS'),
#  ('nipped', 'VBD'),
#  ('pointed', 'VBD'),
#  ('nose', 'RB'),
#  ('shrivelled', 'VBN'),
#  ('cheek', 'NN'),
#  ('made', 'VBN'),
#  ('eyes', 'NNS'),
#  ('red', 'JJ'),
#  ('lips', 'NNS'),
#  ('spoke', 'VBD'),
#  ('voice', 'JJ'),
#  ('head', 'NN'),
#  ('eyebrows', 'NNS'),
#  ('chin', 'VBP'),
#  ('carried', 'VBD'),
#  ('low', 'JJ'),
#  ('always', 'RB'),
#  ('office', 'NN'),
#  ('one', 'CD'),
#  ('degree', 'NN'),
#  ('christmas', 'NN'),
#  ('cold', 'VBD'),
#  ('little', 'JJ'),
#  ('influence', 'NN'),
#  ('scrooge', 'NN'),
#  ('warmth', 'NN'),
#  ('could', 'MD'),
#  ('warm', 'VB'),
#  ('wintry', 'NN'),
#  ('weather', 'NN'),
#  ('wind', 'NN'),
#  ('blew', 'VBD'),
#  ('falling', 'VBG'),
#  ('snow', 'JJ'),
#  ('intent', 'NN'),
#  ('upon', 'IN'),
#  ('purpose', 'JJ'),
#  ('rain', 'NN'),
#  ('less', 'RBR'),
#  ('open', 'JJ'),
#  ('entreaty', 'NN'),
#  ('foul', 'NN'),
#  ('weather', 'NN'),
#  ('know', 'VBP'),
#  ('rain', 'NN'),
#  ('snow', 'NN'),
#  ('could', 'MD'),
#  ('one', 'CD'),
#  ('often', 'RB'),
#  ('came', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('never', 'RB'),
#  ('nobody', 'NN'),
#  ('ever', 'RB'),
#  ('stopped', 'VBD'),
#  ('street', 'NNS'),
#  ('say', 'VBP'),
#  ('looks', 'NNS'),
#  ('dear', 'JJ'),
#  ('scrooge', 'JJ'),
#  ('come', 'VBN'),
#  ('see', 'VBP'),
#  ('beggars', 'NNS'),
#  ('bestow', 'VB'),
#  ('children', 'NNS'),
#  ('asked', 'VBN'),
#  ('man', 'NN'),
#  ('woman', 'NN'),
#  ('ever', 'RB'),
#  ('life', 'NN'),
#  ('inquired', 'JJ'),
#  ('way', 'NN'),
#  ('place', 'NN'),
#  ('scrooge', 'VBD'),
#  ('even', 'RB'),
#  ('dogs', 'NNS'),
#  ('appeared', 'VBD'),
#  ('know', 'JJ'),
#  ('saw', 'NN'),
#  ('coming', 'VBG'),
#  ('would', 'MD'),
#  ('would', 'MD'),
#  ('though', 'VB'),
#  ('said', 'VBD'),
#  ('eye', 'NN'),
#  ('better', 'RBR'),
#  ('evil', 'JJ'),
#  ('eye', 'NN'),
#  ('dark', 'NN'),
#  ('master', 'NN'),
#  ('scrooge', 'NN'),
#  ('care', 'NN'),
#  ('thing', 'NN'),
#  ('liked', 'VBD'),
#  ('way', 'NN'),
#  ('along', 'IN'),
#  ('life', 'NN'),
#  ('warning', 'VBG'),
#  ('human', 'JJ'),
#  ('sympathy', 'JJ'),
#  ('keep', 'NN'),
#  ('distance', 'NN'),
#  ('knowing', 'VBG'),
#  ('call', 'NN'),
#  ('nuts', 'NNS'),
#  ('scrooge', 'VBP'),
#  ('upon', 'IN'),
#  ('time', 'NN'),
#  ('good', 'JJ'),
#  ('days', 'NNS'),
#  ('year', 'NN'),
#  ('christmas', 'VBP'),
#  ('eve', 'VBP'),
#  ('old', 'JJ'),
#  ('scrooge', 'NN'),
#  ('sat', 'VBD'),
#  ('busy', 'JJ'),
#  ('cold', 'JJ'),
#  ('bleak', 'NN'),
#  ('biting', 'VBG'),
#  ('weather', 'JJR'),
#  ('foggy', 'NN'),
#  ('could', 'MD'),
#  ('hear', 'VB'),
#  ('people', 'NNS'),
#  ('court', 'NN'),
#  ('outside', 'IN'),
#  ('go', 'VB'),
#  ('hands', 'NNS'),
#  ('upon', 'IN'),
#  ('feet', 'NNS'),
#  ('upon', 'IN'),
#  ('warm', 'JJ'),
#  ('city', 'NN'),
#  ('gone', 'VBN'),
#  ('three', 'CD'),
#  ('quite', 'RB'),
#  ('dark', 'JJ'),
#  ('already', 'RB'),
#  ('light', 'JJ'),
#  ('day', 'NN'),
#  ('flaring', 'VBG'),
#  ('windows', 'NNS'),
#  ('neighbouring', 'VBG'),
#  ('offices', 'NNS'),
#  ('like', 'IN'),
#  ('ruddy', 'VBP'),
#  ('upon', 'IN'),
#  ('brown', 'JJ'),
#  ('air', 'NN'),
#  ('fog', 'NNS'),
#  ('came', 'VBD'),
#  ('pouring', 'VBG'),
#  ('every', 'DT'),
#  ('keyhole', 'NN'),
#  ('dense', 'NN'),
#  ('without', 'IN'),
#  ('although', 'IN'),
#  ('court', 'NN'),
#  ('houses', 'NNS'),
#  ('opposite', 'VBP'),
#  ('mere', 'JJ'),
#  ('phantoms', 'NNS'),
#  ('see', 'VBP'),
#  ('dingy', 'JJ'),
#  ('come', 'VB'),
#  ('everything', 'NN'),
#  ('one', 'CD'),
#  ('might', 'MD'),
#  ('thought', 'VB'),
#  ('nature', 'RB'),
#  ('lived', 'VBN'),
#  ('hard', 'RB'),
#  ('large', 'JJ'),
#  ('door', 'NN'),
#  ('scrooge', 'NN'),
#  ('open', 'JJ'),
#  ('might', 'MD'),
#  ('keep', 'VB'),
#  ('eye', 'NN'),
#  ('upon', 'IN'),
#  ('clerk', 'NN'),
#  ('dismal', 'JJ'),
#  ('little', 'JJ'),
#  ('beyond', 'IN'),
#  ('sort', 'NN'),
#  ('tank', 'NN'),
#  ('letters', 'NNS'),
#  ('scrooge', 'VBP'),
#  ('small', 'JJ'),
#  ('fire', 'NN'),
#  ('clerk', 'NN'),
#  ('fire', 'NN'),
#  ('much', 'JJ'),
#  ('smaller', 'JJR'),
#  ('looked', 'VBD'),
#  ('like', 'IN'),
#  ('one', 'CD'),
#  ('could', 'MD'),
#  ('scrooge', 'VB'),
#  ('room', 'NN'),
#  ('surely', 'RB'),
#  ('clerk', 'JJ'),
#  ('came', 'VBD'),
#  ('master', 'NN'),
#  ('predicted', 'VBN'),
#  ('would', 'MD'),
#  ('necessary', 'JJ'),
#  ('part', 'NN'),
#  ('clerk', 'NN'),
#  ('put', 'VBD'),
#  ('white', 'JJ'),
#  ('comforter', 'NN'),
#  ('tried', 'VBD'),
#  ('warm', 'JJ'),
#  ('candle', 'NN'),
#  ('effort', 'NN'),
#  ('man', 'NN'),
#  ('strong', 'JJ'),
#  ('merry', 'NN'),
#  ('christmas', 'NN'),
#  ('uncle', 'NN'),
#  ('god', 'NN'),
#  ('save', 'VBP'),
#  ('cried', 'VBN'),
#  ('cheerful', 'JJ'),
#  ('voice', 'NN'),
#  ('voice', 'NN'),
#  ('scrooge', 'NN'),
#  ('nephew', 'NN'),
#  ('came', 'VBD'),
#  ('upon', 'IN'),
#  ('quickly', 'RB'),
#  ('first', 'JJ'),
#  ('approach', 'NN'),
#  ('bah', 'NN'),
#  ('said', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('humbug', 'NN'),
#  ('heated', 'VBN'),
#  ('rapid', 'JJ'),
#  ('walking', 'VBG'),
#  ('fog', 'NN'),
#  ('frost', 'NN'),
#  ('nephew', 'JJ'),
#  ('scrooge', 'NN'),
#  ('glow', 'JJ'),
#  ('face', 'NN'),
#  ('ruddy', 'VBP'),
#  ('handsome', 'JJ'),
#  ('eyes', 'NNS'),
#  ('sparkled', 'VBD'),
#  ('breath', 'NN'),
#  ('smoked', 'VBD'),
#  ('christmas', 'JJ'),
#  ('humbug', 'NN'),
#  ('uncle', 'NN'),
#  ('said', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('nephew', 'JJ'),
#  ('mean', 'NN'),
#  ('sure', 'NN'),
#  ('said', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('merry', 'NN'),
#  ('christmas', 'NN'),
#  ('right', 'NN'),
#  ('merry', 'NN'),
#  ('reason', 'NN'),
#  ('merry', 'NN'),
#  ('poor', 'JJ'),
#  ('enough', 'RB'),
#  ('come', 'VBP'),
#  ('returned', 'VBN'),
#  ('nephew', 'IN'),
#  ('gaily', 'RB'),
#  ('right', 'JJ'),
#  ('dismal', 'JJ'),
#  ('reason', 'NN'),
#  ('rich', 'JJ'),
#  ('enough', 'RB'),
#  ('scrooge', 'VBP'),
#  ('better', 'JJR'),
#  ('answer', 'NN'),
#  ('ready', 'JJ'),
#  ('moment', 'NN'),
#  ('said', 'VBD'),
#  ('bah', 'NN'),
#  ('followed', 'VBD'),
#  ('humbug', 'JJ'),
#  ('uncle', 'NN'),
#  ('said', 'VBD'),
#  ('nephew', 'JJ'),
#  ('else', 'RB'),
#  ('returned', 'VBD'),
#  ('uncle', 'JJ'),
#  ('live', 'JJ'),
#  ('world', 'NN'),
#  ('merry', 'NN'),
#  ('christmas', 'VBP'),
#  ('upon', 'IN'),
#  ('merry', 'NN'),
#  ('christmas', 'NN'),
#  ('christmas', 'NN'),
#  ('time', 'NN'),
#  ('time', 'NN'),
#  ('without', 'IN'),
#  ('money', 'NN'),
#  ('time', 'NN'),
#  ('finding', 'VBG'),
#  ('year', 'NN'),
#  ('older', 'IN'),
#  ('hour', 'NN'),
#  ('time', 'NN'),
#  ('books', 'NNS'),
#  ('every', 'DT'),
#  ('round', 'NN'),
#  ('dozen', 'NN'),
#  ('presented', 'VBN'),
#  ('dead', 'JJ'),
#  ('could', 'MD'),
#  ('work', 'VB'),
#  ('said', 'VBD'),
#  ('scrooge', 'NNS'),
#  ('indignantly', 'RB'),
#  ('every', 'DT'),
#  ('goes', 'VBZ'),
#  ('christmas', 'JJ'),
#  ('lips', 'NNS'),
#  ('boiled', 'VBD'),
#  ('pudding', 'VBG'),
#  ('buried', 'VBN'),
#  ('holly', 'RB'),
#  ('heart', 'NN'),
#  ('uncle', 'NN'),
#  ('pleaded', 'VBD'),
#  ('nephew', 'JJ'),
#  ('nephew', 'NN'),
#  ('returned', 'VBD'),
#  ('uncle', 'JJ'),
#  ('keep', 'NN'),
#  ('christmas', 'NN'),
#  ('way', 'NN'),
#  ('let', 'NN'),
#  ('keep', 'VB'),
#  ('mine', 'JJ'),
#  ('keep', 'NN'),
#  ('repeated', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('nephew', 'JJ'),
#  ('keep', 'VB'),
#  ('let', 'NN'),
#  ('leave', 'VB'),
#  ('alone', 'RB'),
#  ('said', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('much', 'RB'),
#  ('good', 'JJ'),
#  ('may', 'MD'),
#  ('much', 'RB'),
#  ('good', 'VB'),
#  ('ever', 'RB'),
#  ('done', 'VBN'),
#  ('many', 'JJ'),
#  ('things', 'NNS'),
#  ('might', 'MD'),
#  ('good', 'JJ'),
#  ('dare', 'NN'),
#  ('say', 'VBP'),
#  ('returned', 'VBN'),
#  ('nephew', 'JJ'),
#  ('christmas', 'NN'),
#  ('among', 'IN'),
#  ('rest', 'JJ'),
#  ('sure', 'NN'),
#  ('always', 'RB'),
#  ('thought', 'VBD'),
#  ('christmas', 'JJ'),
#  ('time', 'NN'),
#  ('come', 'VBN'),
#  ('round', 'IN'),
#  ('apart', 'RB'),
#  ('name', 'NN'),
#  ('anything', 'NN'),
#  ('belonging', 'VBG'),
#  ('apart', 'RB'),
#  ('good', 'JJ'),
#  ('time', 'NN'),
#  ('kind', 'NN'),
#  ('pleasant', 'JJ'),
#  ('time', 'NN'),
#  ('time', 'NN'),
#  ('know', 'VB'),
#  ('long', 'JJ'),
#  ('year', 'NN'),
#  ('men', 'NNS'),
#  ('women', 'NNS'),
#  ('one', 'CD'),
#  ('consent', 'NN'),
#  ('open', 'JJ'),
#  ('hearts', 'NNS'),
#  ('think', 'VBP'),
#  ('people', 'NNS'),
#  ('really', 'RB'),
#  ('grave', 'VBP'),
#  ('another', 'DT'),
#  ('race', 'NN'),
#  ('creatures', 'VBZ'),
#  ('bound', 'RP'),
#  ('journeys', 'NNS'),
#  ('therefore', 'RB'),
#  ('uncle', 'JJ'),
#  ('though', 'IN'),
#  ('never', 'RB'),
#  ('put', 'VBN'),
#  ('gold', 'NN'),
#  ('silver', 'NN'),
#  ('pocket', 'NN'),
#  ('believe', 'VBP'),
#  ('done', 'VBN'),
#  ('good', 'JJ'),
#  ('good', 'JJ'),
#  ('say', 'VBP'),
#  ('god', 'JJ'),
#  ('bless', 'NN'),
#  ('clerk', 'NN'),
#  ('tank', 'NN'),
#  ('becoming', 'VBG'),
#  ('immediately', 'RB'),
#  ('sensible', 'JJ'),
#  ('fire', 'NN'),
#  ('last', 'JJ'),
#  ('ever', 'RB'),
#  ('let', 'VBD'),
#  ('hear', 'VB'),
#  ('another', 'DT'),
#  ('sound', 'NN'),
#  ('said', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('keep', 'VB'),
#  ('christmas', 'NN'),
#  ('situation', 'NN'),
#  ('quite', 'RB'),
#  ('speaker', 'NN'),
#  ('sir', 'NN'),
#  ('added', 'VBD'),
#  ('turning', 'VBG'),
#  ('nephew', 'JJ'),
#  ('wonder', 'NN'),
#  ('go', 'VBP'),
#  ('parliament', 'JJ'),
#  ('angry', 'JJ'),
#  ('uncle', 'NN'),
#  ('come', 'VBP'),
#  ('dine', 'NN'),
#  ('us', 'PRP'),
#  ('scrooge', 'NN'),
#  ('said', 'VBD'),
#  ('would', 'MD'),
#  ('see', 'VB'),
#  ('yes', 'RB'),
#  ('indeed', 'RB'),
#  ('went', 'VBD'),
#  ('whole', 'JJ'),
#  ('length', 'NN'),
#  ('expression', 'NN'),
#  ('said', 'VBD'),
#  ('would', 'MD'),
#  ('see', 'VB'),
#  ('first', 'RB'),
#  ('cried', 'VBN'),
#  ('scrooge', 'NN'),
#  ('nephew', 'NN'),
#  ('get', 'NN'),
#  ('married', 'VBN'),
#  ('said', 'VBD'),
#  ('scrooge', 'NN'),
#  ('fell', 'VBD'),
#  ('love', 'RB'),
#  ('fell', 'VBD'),
#  ('love', 'VB'),
#  ('growled', 'VBN'),
#  ('scrooge', 'RB'),
#  ('one', 'CD'),
#  ('thing', 'NN'),
#  ('world', 'NN'),
#  ('ridiculous', 'JJ'),
#  ('merry', 'NN'),
#  ('christmas', 'RB'),
#  ('good', 'JJ'),
#  ('afternoon', 'NN'),
#  ('uncle', 'NN'),
#  ('never', 'RB'),
#  ('came', 'VBD'),
#  ('see', 'NN'),
#  ('happened', 'VBD'),
#  ('give', 'JJ'),
#  ('reason', 'NN'),
#  ('coming', 'VBG'),
#  ('good', 'JJ'),
#  ('afternoon', 'NN'),
#  ('said', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('want', 'VBP'),
#  ('nothing', 'NN'),
#  ('ask', 'NN'),
#  ('nothing', 'NN'),
#  ('friends', 'NNS'),
#  ('good', 'JJ'),
#  ('afternoon', 'NN'),
#  ('said', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('sorry', 'JJ'),
#  ('heart', 'NN'),
#  ('find', 'VB'),
#  ('never', 'RB'),
#  ('quarrel', 'NNP'),
#  ('party', 'NN'),
#  ('made', 'VBD'),
#  ('christmas', 'JJ'),
#  ('keep', 'VB'),
#  ('christmas', 'NN'),
#  ('humour', 'NN'),
#  ('last', 'JJ'),
#  ('merry', 'NN'),
#  ('christmas', 'VBD'),
#  ('uncle', 'RB'),
#  ('good', 'JJ'),
#  ('afternoon', 'NN'),
#  ('said', 'VBD'),
#  ('scrooge', 'RB'),
#  ('happy', 'JJ'),
#  ('new', 'JJ'),
#  ('year', 'NN'),
#  ('good', 'JJ'),
#  ('afternoon', 'NN'),
#  ('said', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('nephew', 'NN'),
#  ('left', 'VBD'),
#  ('room', 'NN'),
#  ('without', 'IN'),
#  ('angry', 'JJ'),
#  ('word', 'NN'),
#  ('notwithstanding', 'NN'),
#  ('stopped', 'VBD'),
#  ('outer', 'JJR'),
#  ('door', 'NN'),
#  ('bestow', 'NN'),
#  ('season', 'NN'),
#  ('clerk', 'NN'),
#  ('cold', 'VBD'),
#  ('scrooge', 'NN'),
#  ('returned', 'VBD'),
#  ('another', 'DT'),
#  ('fellow', 'NN'),
#  ('muttered', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('clerk', 'NN'),
#  ('fifteen', 'JJ'),
#  ('shillings', 'NNS'),
#  ('wife', 'NN'),
#  ('family', 'NN'),
#  ('merry', 'NN'),
#  ('christmas', 'NN'),
#  ('retire', 'NN'),
#  ('scrooge', 'NN'),
#  ('nephew', 'JJ'),
#  ('let', 'VB'),
#  ('two', 'CD'),
#  ('people', 'NNS'),
#  ('portly', 'RB'),
#  ('gentlemen', 'VBP'),
#  ('pleasant', 'JJ'),
#  ('behold', 'NN'),
#  ('stood', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('office', 'NN'),
#  ('books', 'NNS'),
#  ('hands', 'VBZ'),
#  ('scrooge', 'JJ'),
#  ('marley', 'NN'),
#  ('believe', 'VBP'),
#  ('said', 'VBD'),
#  ('one', 'CD'),
#  ('gentlemen', 'NNS'),
#  ('pleasure', 'NN'),
#  ('scrooge', 'VBP'),
#  ('mr', 'NN'),
#  ('marley', 'NN'),
#  ('marley', 'NN'),
#  ('dead', 'JJ'),
#  ('seven', 'CD'),
#  ('years', 'NNS'),
#  ('scrooge', 'RB'),
#  ('replied', 'VBD'),
#  ('died', 'JJ'),
#  ('seven', 'CD'),
#  ('years', 'NNS'),
#  ('ago', 'RB'),
#  ('night', 'NN'),
#  ('doubt', 'NN'),
#  ('liberality', 'NN'),
#  ('well', 'RB'),
#  ('partner', 'NN'),
#  ('said', 'VBD'),
#  ('gentleman', 'JJ'),
#  ('credentials', 'NNS'),
#  ('certainly', 'RB'),
#  ('two', 'CD'),
#  ('spirits', 'NNS'),
#  ('word', 'NN'),
#  ('liberality', 'NN'),
#  ('scrooge', 'VBP'),
#  ('shook', 'NN'),
#  ('head', 'NN'),
#  ('credentials', 'NNS'),
#  ('back', 'RP'),
#  ('season', 'NN'),
#  ('year', 'NN'),
#  ('scrooge', 'NN'),
#  ('said', 'VBD'),
#  ('gentleman', 'JJ'),
#  ('taking', 'VBG'),
#  ('pen', 'JJ'),
#  ('usually', 'RB'),
#  ('make', 'VBP'),
#  ('slight', 'JJ'),
#  ('poor', 'JJ'),
#  ('suffer', 'NN'),
#  ('greatly', 'RB'),
#  ('present', 'JJ'),
#  ('time', 'NN'),
#  ('many', 'JJ'),
#  ('thousands', 'NNS'),
#  ('want', 'VBP'),
#  ('common', 'JJ'),
#  ('hundreds', 'NNS'),
#  ('thousands', 'NNS'),
#  ('want', 'VBP'),
#  ('common', 'JJ'),
#  ('sir', 'NN'),
#  ('prisons', 'NNS'),
#  ('asked', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('plenty', 'NN'),
#  ('prisons', 'NNS'),
#  ('said', 'VBD'),
#  ('gentleman', 'JJ'),
#  ('laying', 'VBG'),
#  ('pen', 'JJ'),
#  ('workhouses', 'NNS'),
#  ('demanded', 'VBD'),
#  ('scrooge', 'NN'),
#  ('still', 'RB'),
#  ('still', 'RB'),
#  ('returned', 'VBN'),
#  ('gentleman', 'JJ'),
#  ('wish', 'NN'),
#  ('could', 'MD'),
#  ('say', 'VB'),
#  ('poor', 'JJ'),
#  ('full', 'JJ'),
#  ('vigour', 'NN'),
#  ('said', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('busy', 'JJ'),
#  ('sir', 'NN'),
#  ('oh', 'NN'),
#  ('afraid', 'NN'),
#  ('said', 'VBD'),
#  ('first', 'JJ'),
#  ('something', 'NN'),
#  ('stop', 'JJ'),
#  ('course', 'NN'),
#  ('said', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('glad', 'JJ'),
#  ('hear', 'NN'),
#  ('scarcely', 'RB'),
#  ('christian', 'JJ'),
#  ('cheer', 'NN'),
#  ('mind', 'NN'),
#  ('body', 'NN'),
#  ('returned', 'VBD'),
#  ('gentleman', 'JJ'),
#  ('us', 'PRP'),
#  ('endeavouring', 'VBG'),
#  ('raise', 'VB'),
#  ('buy', 'NN'),
#  ('poor', 'JJ'),
#  ('meat', 'NN'),
#  ('drink', 'NN'),
#  ('means', 'VBZ'),
#  ('warmth', 'IN'),
#  ('choose', 'JJ'),
#  ('time', 'NN'),
#  ('time', 'NN'),
#  ('want', 'VBP'),
#  ('keenly', 'RB'),
#  ('felt', 'VBP'),
#  ('shall', 'MD'),
#  ('put', 'VB'),
#  ('nothing', 'NN'),
#  ('scrooge', 'NN'),
#  ('replied', 'VBD'),
#  ('wish', 'JJ'),
#  ('wish', 'JJ'),
#  ('left', 'VBD'),
#  ('alone', 'RB'),
#  ('said', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('since', 'IN'),
#  ('ask', 'NN'),
#  ('wish', 'JJ'),
#  ('gentlemen', 'NNS'),
#  ('answer', 'VBP'),
#  ('make', 'VBP'),
#  ('merry', 'NN'),
#  ('christmas', 'NN'),
#  ('ca', 'MD'),
#  ('make', 'VB'),
#  ('idle', 'JJ'),
#  ('people', 'NNS'),
#  ('merry', 'VBP'),
#  ('help', 'NN'),
#  ('mentioned', 'VBD'),
#  ('cost', 'NN'),
#  ('enough', 'NN'),
#  ('must', 'MD'),
#  ('go', 'VB'),
#  ('many', 'JJ'),
#  ('ca', 'MD'),
#  ('go', 'VB'),
#  ('many', 'JJ'),
#  ('would', 'MD'),
#  ('rather', 'RB'),
#  ('die', 'VB'),
#  ('would', 'MD'),
#  ('rather', 'RB'),
#  ('die', 'VB'),
#  ('said', 'VBD'),
#  ('scrooge', 'JJ'),
#  ('better', 'JJR'),
#  ('decrease', 'NN'),
#  ('surplus', 'NN'),
#  ('population', 'NN'),
#  ('excuse', 'NN'),
#  ('know', 'VBP'),
#  ('might', 'MD'),
#  ('know', 'VB'),
#  ('observed', 'JJ'),
#  ('gentleman', 'NN'),
#  ('business', 'NN'),
#  ('scrooge', 'NN'),
#  ('returned', 'VBD'),
#  ('enough', 'JJ'),
#  ('man', 'NN'),
#  ('understand', 'NN'),
#  ('business', 'NN'),
#  ('interfere', 'RB'),
#  ('people', 'NNS'),
#  ('mine', 'VBP'),
#  ('good', 'JJ'),
#  ('afternoon', 'NN'),
#  ('gentlemen', 'NNS'),
#  ('seeing', 'VBG'),
#  ('clearly', 'RB'),
#  ('would', 'MD'),
#  ('point', 'VB'),
#  ('gentlemen', 'NNS'),
#  ('scrooge', 'VB'),
#  ('resumed', 'VBN'),
#  ('opinion', 'NN'),
#  ('facetious', 'JJ'),
#  ('temper', 'JJ'),
#  ('usual', 'JJ'),
#  ('fog', 'NN'),
#  ('darkness', 'NN'),
#  ('people', 'NNS'),
#  ('ran', 'VBD'),
#  ('flaring', 'VBG'),
#  ('go', 'VB'),
#  ('conduct', 'JJ'),
#  ('way', 'NN'),
#  ('ancient', 'JJ'),
#  ('church', 'NN'),
#  ('whose', 'WP$'),
#  ('old', 'JJ'),
#  ('bell', 'NN'),
#  ('always', 'RB'),
#  ('peeping', 'VBG'),
#  ('scrooge', 'NN'),
#  ('window', 'NN'),
#  ('wall', 'NN'),
#  ('became', 'VBD'),
#  ('invisible', 'JJ'),
#  ('struck', 'JJ'),
#  ('hours', 'NNS'),
#  ('quarters', 'NNS'),
#  ('clouds', 'VBP'),
#  ('tremulous', 'JJ'),
#  ('afterwards', 'NNS'),
#  ('teeth', 'IN'),
#  ('chattering', 'VBG'),
#  ('frozen', 'JJ'),
#  ('head', 'NN'),
#  ('cold', 'NN'),
#  ('became', 'VBD'),
#  ('street', 'JJ'),
#  ('corner', 'JJ'),
#  ...]

# %% [markdown]
# #### Tag the Parts of Speech without granularity (like past tense, present, etc)

# %%
cc_pos2 = nltk.pos_tag(cc_words, tagset='universal')
cc_pos2
# Out:
# [('christmas', 'NOUN'),
#  ('carol', 'VERB'),
#  ('charles', 'NOUN'),
#  ('dickens', 'NOUN'),
#  ('release', 'VERB'),
#  ('language', 'NOUN'),
#  ('christmas', 'NOUN'),
#  ('carol', 'NOUN'),
#  ('charles', 'VERB'),
#  ('dickens', 'VERB'),
#  ('ghost', 'NOUN'),
#  ('story', 'NOUN'),
#  ('christmas', 'NOUN'),
#  ('endeavoured', 'VERB'),
#  ('ghostly', 'ADV'),
#  ('little', 'ADJ'),
#  ('book', 'NOUN'),
#  ('raise', 'NOUN'),
#  ('ghost', 'NOUN'),
#  ('idea', 'NOUN'),
#  ('shall', 'VERB'),
#  ('put', 'VERB'),
#  ('humour', 'NUM'),
#  ('season', 'NOUN'),
#  ('may', 'VERB'),
#  ('haunt', 'VERB'),
#  ('houses', 'NOUN'),
#  ('pleasantly', 'ADV'),
#  ('one', 'NUM'),
#  ('wish', 'ADJ'),
#  ('lay', 'NOUN'),
#  ('friend', 'NOUN'),
#  ('servant', 'ADJ'),
#  ('december', 'NOUN'),
#  ('stave', 'VERB'),
#  ('marley', 'NOUN'),
#  ('ghost', 'NOUN'),
#  ('marley', 'NOUN'),
#  ('dead', 'ADJ'),
#  ('begin', 'NOUN'),
#  ('doubt', 'NOUN'),
#  ('whatever', 'DET'),
#  ('signed', 'VERB'),
#  ('clerk', 'NOUN'),
#  ('undertaker', 'NOUN'),
#  ('mourner', 'NOUN'),
#  ('scrooge', 'NOUN'),
#  ('signed', 'VERB'),
#  ('name', 'ADV'),
#  ('good', 'ADJ'),
#  ('upon', 'ADP'),
#  ('anything', 'NOUN'),
#  ('chose', 'ADJ'),
#  ('put', 'VERB'),
#  ('hand', 'NOUN'),
#  ('old', 'ADJ'),
#  ('marley', 'NOUN'),
#  ('dead', 'ADJ'),
#  ('mind', 'NOUN'),
#  ('mean', 'ADJ'),
#  ('say', 'VERB'),
#  ('know', 'VERB'),
#  ('knowledge', 'VERB'),
#  ('dead', 'ADJ'),
#  ('might', 'VERB'),
#  ('inclined', 'VERB'),
#  ('piece', 'ADV'),
#  ('trade', 'NOUN'),
#  ('hands', 'NOUN'),
#  ('shall', 'VERB'),
#  ('country', 'NOUN'),
#  ('done', 'VERB'),
#  ('therefore', 'ADV'),
#  ('marley', 'ADJ'),
#  ('dead', 'ADJ'),
#  ('scrooge', 'NOUN'),
#  ('knew', 'VERB'),
#  ('dead', 'ADJ'),
#  ('course', 'NOUN'),
#  ('could', 'VERB'),
#  ('otherwise', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('partners', 'NOUN'),
#  ('know', 'VERB'),
#  ('many', 'ADJ'),
#  ('years', 'NOUN'),
#  ('scrooge', 'VERB'),
#  ('sole', 'ADJ'),
#  ('sole', 'ADJ'),
#  ('sole', 'ADJ'),
#  ('sole', 'ADJ'),
#  ('sole', 'NOUN'),
#  ('friend', 'NOUN'),
#  ('sole', 'NOUN'),
#  ('mourner', 'NOUN'),
#  ('even', 'ADV'),
#  ('scrooge', 'VERB'),
#  ('cut', 'ADJ'),
#  ('event', 'NOUN'),
#  ('man', 'NOUN'),
#  ('business', 'NOUN'),
#  ('day', 'NOUN'),
#  ('funeral', 'ADJ'),
#  ('bargain', 'NOUN'),
#  ('mention', 'NOUN'),
#  ('marley', 'X'),
#  ('funeral', 'ADJ'),
#  ('back', 'ADV'),
#  ('point', 'NOUN'),
#  ('started', 'VERB'),
#  ('doubt', 'NOUN'),
#  ('marley', 'NOUN'),
#  ('dead', 'ADJ'),
#  ('must', 'VERB'),
#  ('understood', 'VERB'),
#  ('nothing', 'NOUN'),
#  ('wonderful', 'ADJ'),
#  ('come', 'ADJ'),
#  ('story', 'NOUN'),
#  ('going', 'VERB'),
#  ('perfectly', 'ADV'),
#  ('convinced', 'VERB'),
#  ('father', 'NOUN'),
#  ('died', 'VERB'),
#  ('play', 'NOUN'),
#  ('began', 'VERB'),
#  ('would', 'VERB'),
#  ('nothing', 'NOUN'),
#  ('remarkable', 'VERB'),
#  ('taking', 'VERB'),
#  ('night', 'NOUN'),
#  ('wind', 'NOUN'),
#  ('upon', 'NOUN'),
#  ('would', 'VERB'),
#  ('gentleman', 'VERB'),
#  ('turning', 'VERB'),
#  ('dark', 'ADJ'),
#  ('say', 'VERB'),
#  ('saint', 'ADJ'),
#  ('churchyard', 'NOUN'),
#  ('son', 'NOUN'),
#  ('weak', 'ADJ'),
#  ('mind', 'NOUN'),
#  ('scrooge', 'NOUN'),
#  ('never', 'ADV'),
#  ('old', 'ADJ'),
#  ('marley', 'NOUN'),
#  ('name', 'NOUN'),
#  ('stood', 'VERB'),
#  ('years', 'NOUN'),
#  ('afterwards', 'NOUN'),
#  ('warehouse', 'VERB'),
#  ('door', 'ADJ'),
#  ('scrooge', 'NOUN'),
#  ('marley', 'NOUN'),
#  ('firm', 'NOUN'),
#  ('known', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('marley', 'NOUN'),
#  ('sometimes', 'ADV'),
#  ('people', 'NOUN'),
#  ('new', 'ADJ'),
#  ('business', 'NOUN'),
#  ('called', 'VERB'),
#  ('scrooge', 'NOUN'),
#  ('scrooge', 'NOUN'),
#  ('sometimes', 'ADV'),
#  ('marley', 'ADV'),
#  ('answered', 'ADJ'),
#  ('oh', 'ADJ'),
#  ('hand', 'NOUN'),
#  ('scrooge', 'NOUN'),
#  ('grasping', 'VERB'),
#  ('scraping', 'VERB'),
#  ('clutching', 'VERB'),
#  ('old', 'ADJ'),
#  ('hard', 'ADJ'),
#  ('sharp', 'ADJ'),
#  ('steel', 'NOUN'),
#  ('ever', 'ADV'),
#  ('struck', 'VERB'),
#  ('generous', 'ADJ'),
#  ('fire', 'NOUN'),
#  ('secret', 'ADJ'),
#  ('solitary', 'ADJ'),
#  ('cold', 'NOUN'),
#  ('within', 'ADP'),
#  ('old', 'ADJ'),
#  ('features', 'NOUN'),
#  ('nipped', 'VERB'),
#  ('pointed', 'VERB'),
#  ('nose', 'ADV'),
#  ('shrivelled', 'VERB'),
#  ('cheek', 'NOUN'),
#  ('made', 'VERB'),
#  ('eyes', 'NOUN'),
#  ('red', 'ADJ'),
#  ('lips', 'NOUN'),
#  ('spoke', 'VERB'),
#  ('voice', 'ADJ'),
#  ('head', 'NOUN'),
#  ('eyebrows', 'NOUN'),
#  ('chin', 'VERB'),
#  ('carried', 'VERB'),
#  ('low', 'ADJ'),
#  ('always', 'ADV'),
#  ('office', 'NOUN'),
#  ('one', 'NUM'),
#  ('degree', 'NOUN'),
#  ('christmas', 'NOUN'),
#  ('cold', 'VERB'),
#  ('little', 'ADJ'),
#  ('influence', 'NOUN'),
#  ('scrooge', 'NOUN'),
#  ('warmth', 'NOUN'),
#  ('could', 'VERB'),
#  ('warm', 'VERB'),
#  ('wintry', 'NOUN'),
#  ('weather', 'NOUN'),
#  ('wind', 'NOUN'),
#  ('blew', 'VERB'),
#  ('falling', 'VERB'),
#  ('snow', 'ADJ'),
#  ('intent', 'NOUN'),
#  ('upon', 'ADP'),
#  ('purpose', 'ADJ'),
#  ('rain', 'NOUN'),
#  ('less', 'ADV'),
#  ('open', 'ADJ'),
#  ('entreaty', 'NOUN'),
#  ('foul', 'NOUN'),
#  ('weather', 'NOUN'),
#  ('know', 'VERB'),
#  ('rain', 'NOUN'),
#  ('snow', 'NOUN'),
#  ('could', 'VERB'),
#  ('one', 'NUM'),
#  ('often', 'ADV'),
#  ('came', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('never', 'ADV'),
#  ('nobody', 'NOUN'),
#  ('ever', 'ADV'),
#  ('stopped', 'VERB'),
#  ('street', 'NOUN'),
#  ('say', 'VERB'),
#  ('looks', 'NOUN'),
#  ('dear', 'ADJ'),
#  ('scrooge', 'ADJ'),
#  ('come', 'VERB'),
#  ('see', 'VERB'),
#  ('beggars', 'NOUN'),
#  ('bestow', 'VERB'),
#  ('children', 'NOUN'),
#  ('asked', 'VERB'),
#  ('man', 'NOUN'),
#  ('woman', 'NOUN'),
#  ('ever', 'ADV'),
#  ('life', 'NOUN'),
#  ('inquired', 'ADJ'),
#  ('way', 'NOUN'),
#  ('place', 'NOUN'),
#  ('scrooge', 'VERB'),
#  ('even', 'ADV'),
#  ('dogs', 'NOUN'),
#  ('appeared', 'VERB'),
#  ('know', 'ADJ'),
#  ('saw', 'NOUN'),
#  ('coming', 'VERB'),
#  ('would', 'VERB'),
#  ('would', 'VERB'),
#  ('though', 'VERB'),
#  ('said', 'VERB'),
#  ('eye', 'NOUN'),
#  ('better', 'ADV'),
#  ('evil', 'ADJ'),
#  ('eye', 'NOUN'),
#  ('dark', 'NOUN'),
#  ('master', 'NOUN'),
#  ('scrooge', 'NOUN'),
#  ('care', 'NOUN'),
#  ('thing', 'NOUN'),
#  ('liked', 'VERB'),
#  ('way', 'NOUN'),
#  ('along', 'ADP'),
#  ('life', 'NOUN'),
#  ('warning', 'VERB'),
#  ('human', 'ADJ'),
#  ('sympathy', 'ADJ'),
#  ('keep', 'NOUN'),
#  ('distance', 'NOUN'),
#  ('knowing', 'VERB'),
#  ('call', 'NOUN'),
#  ('nuts', 'NOUN'),
#  ('scrooge', 'VERB'),
#  ('upon', 'ADP'),
#  ('time', 'NOUN'),
#  ('good', 'ADJ'),
#  ('days', 'NOUN'),
#  ('year', 'NOUN'),
#  ('christmas', 'VERB'),
#  ('eve', 'VERB'),
#  ('old', 'ADJ'),
#  ('scrooge', 'NOUN'),
#  ('sat', 'VERB'),
#  ('busy', 'ADJ'),
#  ('cold', 'ADJ'),
#  ('bleak', 'NOUN'),
#  ('biting', 'VERB'),
#  ('weather', 'ADJ'),
#  ('foggy', 'NOUN'),
#  ('could', 'VERB'),
#  ('hear', 'VERB'),
#  ('people', 'NOUN'),
#  ('court', 'NOUN'),
#  ('outside', 'ADP'),
#  ('go', 'VERB'),
#  ('hands', 'NOUN'),
#  ('upon', 'ADP'),
#  ('feet', 'NOUN'),
#  ('upon', 'ADP'),
#  ('warm', 'ADJ'),
#  ('city', 'NOUN'),
#  ('gone', 'VERB'),
#  ('three', 'NUM'),
#  ('quite', 'ADV'),
#  ('dark', 'ADJ'),
#  ('already', 'ADV'),
#  ('light', 'ADJ'),
#  ('day', 'NOUN'),
#  ('flaring', 'VERB'),
#  ('windows', 'NOUN'),
#  ('neighbouring', 'VERB'),
#  ('offices', 'NOUN'),
#  ('like', 'ADP'),
#  ('ruddy', 'VERB'),
#  ('upon', 'ADP'),
#  ('brown', 'ADJ'),
#  ('air', 'NOUN'),
#  ('fog', 'NOUN'),
#  ('came', 'VERB'),
#  ('pouring', 'VERB'),
#  ('every', 'DET'),
#  ('keyhole', 'NOUN'),
#  ('dense', 'NOUN'),
#  ('without', 'ADP'),
#  ('although', 'ADP'),
#  ('court', 'NOUN'),
#  ('houses', 'NOUN'),
#  ('opposite', 'VERB'),
#  ('mere', 'ADJ'),
#  ('phantoms', 'NOUN'),
#  ('see', 'VERB'),
#  ('dingy', 'ADJ'),
#  ('come', 'VERB'),
#  ('everything', 'NOUN'),
#  ('one', 'NUM'),
#  ('might', 'VERB'),
#  ('thought', 'VERB'),
#  ('nature', 'ADV'),
#  ('lived', 'VERB'),
#  ('hard', 'ADV'),
#  ('large', 'ADJ'),
#  ('door', 'NOUN'),
#  ('scrooge', 'NOUN'),
#  ('open', 'ADJ'),
#  ('might', 'VERB'),
#  ('keep', 'VERB'),
#  ('eye', 'NOUN'),
#  ('upon', 'ADP'),
#  ('clerk', 'NOUN'),
#  ('dismal', 'ADJ'),
#  ('little', 'ADJ'),
#  ('beyond', 'ADP'),
#  ('sort', 'NOUN'),
#  ('tank', 'NOUN'),
#  ('letters', 'NOUN'),
#  ('scrooge', 'VERB'),
#  ('small', 'ADJ'),
#  ('fire', 'NOUN'),
#  ('clerk', 'NOUN'),
#  ('fire', 'NOUN'),
#  ('much', 'ADJ'),
#  ('smaller', 'ADJ'),
#  ('looked', 'VERB'),
#  ('like', 'ADP'),
#  ('one', 'NUM'),
#  ('could', 'VERB'),
#  ('scrooge', 'VERB'),
#  ('room', 'NOUN'),
#  ('surely', 'ADV'),
#  ('clerk', 'ADJ'),
#  ('came', 'VERB'),
#  ('master', 'NOUN'),
#  ('predicted', 'VERB'),
#  ('would', 'VERB'),
#  ('necessary', 'ADJ'),
#  ('part', 'NOUN'),
#  ('clerk', 'NOUN'),
#  ('put', 'VERB'),
#  ('white', 'ADJ'),
#  ('comforter', 'NOUN'),
#  ('tried', 'VERB'),
#  ('warm', 'ADJ'),
#  ('candle', 'NOUN'),
#  ('effort', 'NOUN'),
#  ('man', 'NOUN'),
#  ('strong', 'ADJ'),
#  ('merry', 'NOUN'),
#  ('christmas', 'NOUN'),
#  ('uncle', 'NOUN'),
#  ('god', 'NOUN'),
#  ('save', 'VERB'),
#  ('cried', 'VERB'),
#  ('cheerful', 'ADJ'),
#  ('voice', 'NOUN'),
#  ('voice', 'NOUN'),
#  ('scrooge', 'NOUN'),
#  ('nephew', 'NOUN'),
#  ('came', 'VERB'),
#  ('upon', 'ADP'),
#  ('quickly', 'ADV'),
#  ('first', 'ADJ'),
#  ('approach', 'NOUN'),
#  ('bah', 'NOUN'),
#  ('said', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('humbug', 'NOUN'),
#  ('heated', 'VERB'),
#  ('rapid', 'ADJ'),
#  ('walking', 'VERB'),
#  ('fog', 'NOUN'),
#  ('frost', 'NOUN'),
#  ('nephew', 'ADJ'),
#  ('scrooge', 'NOUN'),
#  ('glow', 'ADJ'),
#  ('face', 'NOUN'),
#  ('ruddy', 'VERB'),
#  ('handsome', 'ADJ'),
#  ('eyes', 'NOUN'),
#  ('sparkled', 'VERB'),
#  ('breath', 'NOUN'),
#  ('smoked', 'VERB'),
#  ('christmas', 'ADJ'),
#  ('humbug', 'NOUN'),
#  ('uncle', 'NOUN'),
#  ('said', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('nephew', 'ADJ'),
#  ('mean', 'NOUN'),
#  ('sure', 'NOUN'),
#  ('said', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('merry', 'NOUN'),
#  ('christmas', 'NOUN'),
#  ('right', 'NOUN'),
#  ('merry', 'NOUN'),
#  ('reason', 'NOUN'),
#  ('merry', 'NOUN'),
#  ('poor', 'ADJ'),
#  ('enough', 'ADV'),
#  ('come', 'VERB'),
#  ('returned', 'VERB'),
#  ('nephew', 'ADP'),
#  ('gaily', 'ADV'),
#  ('right', 'ADJ'),
#  ('dismal', 'ADJ'),
#  ('reason', 'NOUN'),
#  ('rich', 'ADJ'),
#  ('enough', 'ADV'),
#  ('scrooge', 'VERB'),
#  ('better', 'ADJ'),
#  ('answer', 'NOUN'),
#  ('ready', 'ADJ'),
#  ('moment', 'NOUN'),
#  ('said', 'VERB'),
#  ('bah', 'NOUN'),
#  ('followed', 'VERB'),
#  ('humbug', 'ADJ'),
#  ('uncle', 'NOUN'),
#  ('said', 'VERB'),
#  ('nephew', 'ADJ'),
#  ('else', 'ADV'),
#  ('returned', 'VERB'),
#  ('uncle', 'ADJ'),
#  ('live', 'ADJ'),
#  ('world', 'NOUN'),
#  ('merry', 'NOUN'),
#  ('christmas', 'VERB'),
#  ('upon', 'ADP'),
#  ('merry', 'NOUN'),
#  ('christmas', 'NOUN'),
#  ('christmas', 'NOUN'),
#  ('time', 'NOUN'),
#  ('time', 'NOUN'),
#  ('without', 'ADP'),
#  ('money', 'NOUN'),
#  ('time', 'NOUN'),
#  ('finding', 'VERB'),
#  ('year', 'NOUN'),
#  ('older', 'ADP'),
#  ('hour', 'NOUN'),
#  ('time', 'NOUN'),
#  ('books', 'NOUN'),
#  ('every', 'DET'),
#  ('round', 'NOUN'),
#  ('dozen', 'NOUN'),
#  ('presented', 'VERB'),
#  ('dead', 'ADJ'),
#  ('could', 'VERB'),
#  ('work', 'VERB'),
#  ('said', 'VERB'),
#  ('scrooge', 'NOUN'),
#  ('indignantly', 'ADV'),
#  ('every', 'DET'),
#  ('goes', 'VERB'),
#  ('christmas', 'ADJ'),
#  ('lips', 'NOUN'),
#  ('boiled', 'VERB'),
#  ('pudding', 'VERB'),
#  ('buried', 'VERB'),
#  ('holly', 'ADV'),
#  ('heart', 'NOUN'),
#  ('uncle', 'NOUN'),
#  ('pleaded', 'VERB'),
#  ('nephew', 'ADJ'),
#  ('nephew', 'NOUN'),
#  ('returned', 'VERB'),
#  ('uncle', 'ADJ'),
#  ('keep', 'NOUN'),
#  ('christmas', 'NOUN'),
#  ('way', 'NOUN'),
#  ('let', 'NOUN'),
#  ('keep', 'VERB'),
#  ('mine', 'ADJ'),
#  ('keep', 'NOUN'),
#  ('repeated', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('nephew', 'ADJ'),
#  ('keep', 'VERB'),
#  ('let', 'NOUN'),
#  ('leave', 'VERB'),
#  ('alone', 'ADV'),
#  ('said', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('much', 'ADV'),
#  ('good', 'ADJ'),
#  ('may', 'VERB'),
#  ('much', 'ADV'),
#  ('good', 'VERB'),
#  ('ever', 'ADV'),
#  ('done', 'VERB'),
#  ('many', 'ADJ'),
#  ('things', 'NOUN'),
#  ('might', 'VERB'),
#  ('good', 'ADJ'),
#  ('dare', 'NOUN'),
#  ('say', 'VERB'),
#  ('returned', 'VERB'),
#  ('nephew', 'ADJ'),
#  ('christmas', 'NOUN'),
#  ('among', 'ADP'),
#  ('rest', 'ADJ'),
#  ('sure', 'NOUN'),
#  ('always', 'ADV'),
#  ('thought', 'VERB'),
#  ('christmas', 'ADJ'),
#  ('time', 'NOUN'),
#  ('come', 'VERB'),
#  ('round', 'ADP'),
#  ('apart', 'ADV'),
#  ('name', 'NOUN'),
#  ('anything', 'NOUN'),
#  ('belonging', 'VERB'),
#  ('apart', 'ADV'),
#  ('good', 'ADJ'),
#  ('time', 'NOUN'),
#  ('kind', 'NOUN'),
#  ('pleasant', 'ADJ'),
#  ('time', 'NOUN'),
#  ('time', 'NOUN'),
#  ('know', 'VERB'),
#  ('long', 'ADJ'),
#  ('year', 'NOUN'),
#  ('men', 'NOUN'),
#  ('women', 'NOUN'),
#  ('one', 'NUM'),
#  ('consent', 'NOUN'),
#  ('open', 'ADJ'),
#  ('hearts', 'NOUN'),
#  ('think', 'VERB'),
#  ('people', 'NOUN'),
#  ('really', 'ADV'),
#  ('grave', 'VERB'),
#  ('another', 'DET'),
#  ('race', 'NOUN'),
#  ('creatures', 'VERB'),
#  ('bound', 'PRT'),
#  ('journeys', 'NOUN'),
#  ('therefore', 'ADV'),
#  ('uncle', 'ADJ'),
#  ('though', 'ADP'),
#  ('never', 'ADV'),
#  ('put', 'VERB'),
#  ('gold', 'NOUN'),
#  ('silver', 'NOUN'),
#  ('pocket', 'NOUN'),
#  ('believe', 'VERB'),
#  ('done', 'VERB'),
#  ('good', 'ADJ'),
#  ('good', 'ADJ'),
#  ('say', 'VERB'),
#  ('god', 'ADJ'),
#  ('bless', 'NOUN'),
#  ('clerk', 'NOUN'),
#  ('tank', 'NOUN'),
#  ('becoming', 'VERB'),
#  ('immediately', 'ADV'),
#  ('sensible', 'ADJ'),
#  ('fire', 'NOUN'),
#  ('last', 'ADJ'),
#  ('ever', 'ADV'),
#  ('let', 'VERB'),
#  ('hear', 'VERB'),
#  ('another', 'DET'),
#  ('sound', 'NOUN'),
#  ('said', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('keep', 'VERB'),
#  ('christmas', 'NOUN'),
#  ('situation', 'NOUN'),
#  ('quite', 'ADV'),
#  ('speaker', 'NOUN'),
#  ('sir', 'NOUN'),
#  ('added', 'VERB'),
#  ('turning', 'VERB'),
#  ('nephew', 'ADJ'),
#  ('wonder', 'NOUN'),
#  ('go', 'VERB'),
#  ('parliament', 'ADJ'),
#  ('angry', 'ADJ'),
#  ('uncle', 'NOUN'),
#  ('come', 'VERB'),
#  ('dine', 'NOUN'),
#  ('us', 'PRON'),
#  ('scrooge', 'NOUN'),
#  ('said', 'VERB'),
#  ('would', 'VERB'),
#  ('see', 'VERB'),
#  ('yes', 'ADV'),
#  ('indeed', 'ADV'),
#  ('went', 'VERB'),
#  ('whole', 'ADJ'),
#  ('length', 'NOUN'),
#  ('expression', 'NOUN'),
#  ('said', 'VERB'),
#  ('would', 'VERB'),
#  ('see', 'VERB'),
#  ('first', 'ADV'),
#  ('cried', 'VERB'),
#  ('scrooge', 'NOUN'),
#  ('nephew', 'NOUN'),
#  ('get', 'NOUN'),
#  ('married', 'VERB'),
#  ('said', 'VERB'),
#  ('scrooge', 'NOUN'),
#  ('fell', 'VERB'),
#  ('love', 'ADV'),
#  ('fell', 'VERB'),
#  ('love', 'VERB'),
#  ('growled', 'VERB'),
#  ('scrooge', 'ADV'),
#  ('one', 'NUM'),
#  ('thing', 'NOUN'),
#  ('world', 'NOUN'),
#  ('ridiculous', 'ADJ'),
#  ('merry', 'NOUN'),
#  ('christmas', 'ADV'),
#  ('good', 'ADJ'),
#  ('afternoon', 'NOUN'),
#  ('uncle', 'NOUN'),
#  ('never', 'ADV'),
#  ('came', 'VERB'),
#  ('see', 'NOUN'),
#  ('happened', 'VERB'),
#  ('give', 'ADJ'),
#  ('reason', 'NOUN'),
#  ('coming', 'VERB'),
#  ('good', 'ADJ'),
#  ('afternoon', 'NOUN'),
#  ('said', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('want', 'VERB'),
#  ('nothing', 'NOUN'),
#  ('ask', 'NOUN'),
#  ('nothing', 'NOUN'),
#  ('friends', 'NOUN'),
#  ('good', 'ADJ'),
#  ('afternoon', 'NOUN'),
#  ('said', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('sorry', 'ADJ'),
#  ('heart', 'NOUN'),
#  ('find', 'VERB'),
#  ('never', 'ADV'),
#  ('quarrel', 'NOUN'),
#  ('party', 'NOUN'),
#  ('made', 'VERB'),
#  ('christmas', 'ADJ'),
#  ('keep', 'VERB'),
#  ('christmas', 'NOUN'),
#  ('humour', 'NOUN'),
#  ('last', 'ADJ'),
#  ('merry', 'NOUN'),
#  ('christmas', 'VERB'),
#  ('uncle', 'ADV'),
#  ('good', 'ADJ'),
#  ('afternoon', 'NOUN'),
#  ('said', 'VERB'),
#  ('scrooge', 'ADV'),
#  ('happy', 'ADJ'),
#  ('new', 'ADJ'),
#  ('year', 'NOUN'),
#  ('good', 'ADJ'),
#  ('afternoon', 'NOUN'),
#  ('said', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('nephew', 'NOUN'),
#  ('left', 'VERB'),
#  ('room', 'NOUN'),
#  ('without', 'ADP'),
#  ('angry', 'ADJ'),
#  ('word', 'NOUN'),
#  ('notwithstanding', 'NOUN'),
#  ('stopped', 'VERB'),
#  ('outer', 'ADJ'),
#  ('door', 'NOUN'),
#  ('bestow', 'NOUN'),
#  ('season', 'NOUN'),
#  ('clerk', 'NOUN'),
#  ('cold', 'VERB'),
#  ('scrooge', 'NOUN'),
#  ('returned', 'VERB'),
#  ('another', 'DET'),
#  ('fellow', 'NOUN'),
#  ('muttered', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('clerk', 'NOUN'),
#  ('fifteen', 'ADJ'),
#  ('shillings', 'NOUN'),
#  ('wife', 'NOUN'),
#  ('family', 'NOUN'),
#  ('merry', 'NOUN'),
#  ('christmas', 'NOUN'),
#  ('retire', 'NOUN'),
#  ('scrooge', 'NOUN'),
#  ('nephew', 'ADJ'),
#  ('let', 'VERB'),
#  ('two', 'NUM'),
#  ('people', 'NOUN'),
#  ('portly', 'ADV'),
#  ('gentlemen', 'VERB'),
#  ('pleasant', 'ADJ'),
#  ('behold', 'NOUN'),
#  ('stood', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('office', 'NOUN'),
#  ('books', 'NOUN'),
#  ('hands', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('marley', 'NOUN'),
#  ('believe', 'VERB'),
#  ('said', 'VERB'),
#  ('one', 'NUM'),
#  ('gentlemen', 'NOUN'),
#  ('pleasure', 'NOUN'),
#  ('scrooge', 'VERB'),
#  ('mr', 'NOUN'),
#  ('marley', 'NOUN'),
#  ('marley', 'NOUN'),
#  ('dead', 'ADJ'),
#  ('seven', 'NUM'),
#  ('years', 'NOUN'),
#  ('scrooge', 'ADV'),
#  ('replied', 'VERB'),
#  ('died', 'ADJ'),
#  ('seven', 'NUM'),
#  ('years', 'NOUN'),
#  ('ago', 'ADV'),
#  ('night', 'NOUN'),
#  ('doubt', 'NOUN'),
#  ('liberality', 'NOUN'),
#  ('well', 'ADV'),
#  ('partner', 'NOUN'),
#  ('said', 'VERB'),
#  ('gentleman', 'ADJ'),
#  ('credentials', 'NOUN'),
#  ('certainly', 'ADV'),
#  ('two', 'NUM'),
#  ('spirits', 'NOUN'),
#  ('word', 'NOUN'),
#  ('liberality', 'NOUN'),
#  ('scrooge', 'VERB'),
#  ('shook', 'NOUN'),
#  ('head', 'NOUN'),
#  ('credentials', 'NOUN'),
#  ('back', 'PRT'),
#  ('season', 'NOUN'),
#  ('year', 'NOUN'),
#  ('scrooge', 'NOUN'),
#  ('said', 'VERB'),
#  ('gentleman', 'ADJ'),
#  ('taking', 'VERB'),
#  ('pen', 'ADJ'),
#  ('usually', 'ADV'),
#  ('make', 'VERB'),
#  ('slight', 'ADJ'),
#  ('poor', 'ADJ'),
#  ('suffer', 'NOUN'),
#  ('greatly', 'ADV'),
#  ('present', 'ADJ'),
#  ('time', 'NOUN'),
#  ('many', 'ADJ'),
#  ('thousands', 'NOUN'),
#  ('want', 'VERB'),
#  ('common', 'ADJ'),
#  ('hundreds', 'NOUN'),
#  ('thousands', 'NOUN'),
#  ('want', 'VERB'),
#  ('common', 'ADJ'),
#  ('sir', 'NOUN'),
#  ('prisons', 'NOUN'),
#  ('asked', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('plenty', 'NOUN'),
#  ('prisons', 'NOUN'),
#  ('said', 'VERB'),
#  ('gentleman', 'ADJ'),
#  ('laying', 'VERB'),
#  ('pen', 'ADJ'),
#  ('workhouses', 'NOUN'),
#  ('demanded', 'VERB'),
#  ('scrooge', 'NOUN'),
#  ('still', 'ADV'),
#  ('still', 'ADV'),
#  ('returned', 'VERB'),
#  ('gentleman', 'ADJ'),
#  ('wish', 'NOUN'),
#  ('could', 'VERB'),
#  ('say', 'VERB'),
#  ('poor', 'ADJ'),
#  ('full', 'ADJ'),
#  ('vigour', 'NOUN'),
#  ('said', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('busy', 'ADJ'),
#  ('sir', 'NOUN'),
#  ('oh', 'NOUN'),
#  ('afraid', 'NOUN'),
#  ('said', 'VERB'),
#  ('first', 'ADJ'),
#  ('something', 'NOUN'),
#  ('stop', 'ADJ'),
#  ('course', 'NOUN'),
#  ('said', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('glad', 'ADJ'),
#  ('hear', 'NOUN'),
#  ('scarcely', 'ADV'),
#  ('christian', 'ADJ'),
#  ('cheer', 'NOUN'),
#  ('mind', 'NOUN'),
#  ('body', 'NOUN'),
#  ('returned', 'VERB'),
#  ('gentleman', 'ADJ'),
#  ('us', 'PRON'),
#  ('endeavouring', 'VERB'),
#  ('raise', 'VERB'),
#  ('buy', 'NOUN'),
#  ('poor', 'ADJ'),
#  ('meat', 'NOUN'),
#  ('drink', 'NOUN'),
#  ('means', 'VERB'),
#  ('warmth', 'ADP'),
#  ('choose', 'ADJ'),
#  ('time', 'NOUN'),
#  ('time', 'NOUN'),
#  ('want', 'VERB'),
#  ('keenly', 'ADV'),
#  ('felt', 'VERB'),
#  ('shall', 'VERB'),
#  ('put', 'VERB'),
#  ('nothing', 'NOUN'),
#  ('scrooge', 'NOUN'),
#  ('replied', 'VERB'),
#  ('wish', 'ADJ'),
#  ('wish', 'ADJ'),
#  ('left', 'VERB'),
#  ('alone', 'ADV'),
#  ('said', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('since', 'ADP'),
#  ('ask', 'NOUN'),
#  ('wish', 'ADJ'),
#  ('gentlemen', 'NOUN'),
#  ('answer', 'VERB'),
#  ('make', 'VERB'),
#  ('merry', 'NOUN'),
#  ('christmas', 'NOUN'),
#  ('ca', 'VERB'),
#  ('make', 'VERB'),
#  ('idle', 'ADJ'),
#  ('people', 'NOUN'),
#  ('merry', 'VERB'),
#  ('help', 'NOUN'),
#  ('mentioned', 'VERB'),
#  ('cost', 'NOUN'),
#  ('enough', 'NOUN'),
#  ('must', 'VERB'),
#  ('go', 'VERB'),
#  ('many', 'ADJ'),
#  ('ca', 'VERB'),
#  ('go', 'VERB'),
#  ('many', 'ADJ'),
#  ('would', 'VERB'),
#  ('rather', 'ADV'),
#  ('die', 'VERB'),
#  ('would', 'VERB'),
#  ('rather', 'ADV'),
#  ('die', 'VERB'),
#  ('said', 'VERB'),
#  ('scrooge', 'ADJ'),
#  ('better', 'ADJ'),
#  ('decrease', 'NOUN'),
#  ('surplus', 'NOUN'),
#  ('population', 'NOUN'),
#  ('excuse', 'NOUN'),
#  ('know', 'VERB'),
#  ('might', 'VERB'),
#  ('know', 'VERB'),
#  ('observed', 'ADJ'),
#  ('gentleman', 'NOUN'),
#  ('business', 'NOUN'),
#  ('scrooge', 'NOUN'),
#  ('returned', 'VERB'),
#  ('enough', 'ADJ'),
#  ('man', 'NOUN'),
#  ('understand', 'NOUN'),
#  ('business', 'NOUN'),
#  ('interfere', 'ADV'),
#  ('people', 'NOUN'),
#  ('mine', 'VERB'),
#  ('good', 'ADJ'),
#  ('afternoon', 'NOUN'),
#  ('gentlemen', 'NOUN'),
#  ('seeing', 'VERB'),
#  ('clearly', 'ADV'),
#  ('would', 'VERB'),
#  ('point', 'VERB'),
#  ('gentlemen', 'NOUN'),
#  ('scrooge', 'VERB'),
#  ('resumed', 'VERB'),
#  ('opinion', 'NOUN'),
#  ('facetious', 'ADJ'),
#  ('temper', 'ADJ'),
#  ('usual', 'ADJ'),
#  ('fog', 'NOUN'),
#  ('darkness', 'NOUN'),
#  ('people', 'NOUN'),
#  ('ran', 'VERB'),
#  ('flaring', 'VERB'),
#  ('go', 'VERB'),
#  ('conduct', 'ADJ'),
#  ('way', 'NOUN'),
#  ('ancient', 'ADJ'),
#  ('church', 'NOUN'),
#  ('whose', 'PRON'),
#  ('old', 'ADJ'),
#  ('bell', 'NOUN'),
#  ('always', 'ADV'),
#  ('peeping', 'VERB'),
#  ('scrooge', 'NOUN'),
#  ('window', 'NOUN'),
#  ('wall', 'NOUN'),
#  ('became', 'VERB'),
#  ('invisible', 'ADJ'),
#  ('struck', 'ADJ'),
#  ('hours', 'NOUN'),
#  ('quarters', 'NOUN'),
#  ('clouds', 'VERB'),
#  ('tremulous', 'ADJ'),
#  ('afterwards', 'NOUN'),
#  ('teeth', 'ADP'),
#  ('chattering', 'VERB'),
#  ('frozen', 'ADJ'),
#  ('head', 'NOUN'),
#  ('cold', 'NOUN'),
#  ('became', 'VERB'),
#  ('street', 'ADJ'),
#  ('corner', 'ADJ'),
#  ...]

# %% [markdown]
# #### Use Chunking to find Noun Phrases

# %%
parser = nltk.RegexpParser(r'NOUN_PHRASE: {<ADJ>*<NOUN>+}')
cc_chunks = parser.parse(cc_pos2)
print(cc_chunks)
# Out:
# (S
#   (NOUN_PHRASE christmas/NOUN)
#   carol/VERB
#   (NOUN_PHRASE charles/NOUN dickens/NOUN)
#   release/VERB
#   (NOUN_PHRASE language/NOUN christmas/NOUN carol/NOUN)
#   charles/VERB
#   dickens/VERB
#   (NOUN_PHRASE ghost/NOUN story/NOUN christmas/NOUN)
#   endeavoured/VERB
#   ghostly/ADV
#   (NOUN_PHRASE little/ADJ book/NOUN raise/NOUN ghost/NOUN idea/NOUN)
#   shall/VERB
#   put/VERB
#   humour/NUM
#   (NOUN_PHRASE season/NOUN)
#   may/VERB
#   haunt/VERB
#   (NOUN_PHRASE houses/NOUN)
#   pleasantly/ADV
#   one/NUM
#   (NOUN_PHRASE wish/ADJ lay/NOUN friend/NOUN)
#   (NOUN_PHRASE servant/ADJ december/NOUN)
#   stave/VERB
#   (NOUN_PHRASE marley/NOUN ghost/NOUN marley/NOUN)
#   (NOUN_PHRASE dead/ADJ begin/NOUN doubt/NOUN)
#   whatever/DET
#   signed/VERB
#   (NOUN_PHRASE clerk/NOUN undertaker/NOUN mourner/NOUN scrooge/NOUN)
#   signed/VERB
#   name/ADV
#   good/ADJ
#   upon/ADP
#   (NOUN_PHRASE anything/NOUN)
#   chose/ADJ
#   put/VERB
#   (NOUN_PHRASE hand/NOUN)
#   (NOUN_PHRASE old/ADJ marley/NOUN)
#   (NOUN_PHRASE dead/ADJ mind/NOUN)
#   mean/ADJ
#   say/VERB
#   know/VERB
#   knowledge/VERB
#   dead/ADJ
#   might/VERB
#   inclined/VERB
#   piece/ADV
#   (NOUN_PHRASE trade/NOUN hands/NOUN)
#   shall/VERB
#   (NOUN_PHRASE country/NOUN)
#   done/VERB
#   therefore/ADV
#   (NOUN_PHRASE marley/ADJ dead/ADJ scrooge/NOUN)
#   knew/VERB
#   (NOUN_PHRASE dead/ADJ course/NOUN)
#   could/VERB
#   otherwise/VERB
#   (NOUN_PHRASE scrooge/ADJ partners/NOUN)
#   know/VERB
#   (NOUN_PHRASE many/ADJ years/NOUN)
#   scrooge/VERB
#   (NOUN_PHRASE
#     sole/ADJ
#     sole/ADJ
#     sole/ADJ
#     sole/ADJ
#     sole/NOUN
#     friend/NOUN
#     sole/NOUN
#     mourner/NOUN)
#   even/ADV
#   scrooge/VERB
#   (NOUN_PHRASE cut/ADJ event/NOUN man/NOUN business/NOUN day/NOUN)
#   (NOUN_PHRASE funeral/ADJ bargain/NOUN mention/NOUN)
#   marley/X
#   funeral/ADJ
#   back/ADV
#   (NOUN_PHRASE point/NOUN)
#   started/VERB
#   (NOUN_PHRASE doubt/NOUN marley/NOUN)
#   dead/ADJ
#   must/VERB
#   understood/VERB
#   (NOUN_PHRASE nothing/NOUN)
#   (NOUN_PHRASE wonderful/ADJ come/ADJ story/NOUN)
#   going/VERB
#   perfectly/ADV
#   convinced/VERB
#   (NOUN_PHRASE father/NOUN)
#   died/VERB
#   (NOUN_PHRASE play/NOUN)
#   began/VERB
#   would/VERB
#   (NOUN_PHRASE nothing/NOUN)
#   remarkable/VERB
#   taking/VERB
#   (NOUN_PHRASE night/NOUN wind/NOUN upon/NOUN)
#   would/VERB
#   gentleman/VERB
#   turning/VERB
#   dark/ADJ
#   say/VERB
#   (NOUN_PHRASE saint/ADJ churchyard/NOUN son/NOUN)
#   (NOUN_PHRASE weak/ADJ mind/NOUN scrooge/NOUN)
#   never/ADV
#   (NOUN_PHRASE old/ADJ marley/NOUN name/NOUN)
#   stood/VERB
#   (NOUN_PHRASE years/NOUN afterwards/NOUN)
#   warehouse/VERB
#   (NOUN_PHRASE door/ADJ scrooge/NOUN marley/NOUN firm/NOUN)
#   known/VERB
#   (NOUN_PHRASE scrooge/ADJ marley/NOUN)
#   sometimes/ADV
#   (NOUN_PHRASE people/NOUN)
#   (NOUN_PHRASE new/ADJ business/NOUN)
#   called/VERB
#   (NOUN_PHRASE scrooge/NOUN scrooge/NOUN)
#   sometimes/ADV
#   marley/ADV
#   (NOUN_PHRASE answered/ADJ oh/ADJ hand/NOUN scrooge/NOUN)
#   grasping/VERB
#   scraping/VERB
#   clutching/VERB
#   (NOUN_PHRASE old/ADJ hard/ADJ sharp/ADJ steel/NOUN)
#   ever/ADV
#   struck/VERB
#   (NOUN_PHRASE generous/ADJ fire/NOUN)
#   (NOUN_PHRASE secret/ADJ solitary/ADJ cold/NOUN)
#   within/ADP
#   (NOUN_PHRASE old/ADJ features/NOUN)
#   nipped/VERB
#   pointed/VERB
#   nose/ADV
#   shrivelled/VERB
#   (NOUN_PHRASE cheek/NOUN)
#   made/VERB
#   (NOUN_PHRASE eyes/NOUN)
#   (NOUN_PHRASE red/ADJ lips/NOUN)
#   spoke/VERB
#   (NOUN_PHRASE voice/ADJ head/NOUN eyebrows/NOUN)
#   chin/VERB
#   carried/VERB
#   low/ADJ
#   always/ADV
#   (NOUN_PHRASE office/NOUN)
#   one/NUM
#   (NOUN_PHRASE degree/NOUN christmas/NOUN)
#   cold/VERB
#   (NOUN_PHRASE little/ADJ influence/NOUN scrooge/NOUN warmth/NOUN)
#   could/VERB
#   warm/VERB
#   (NOUN_PHRASE wintry/NOUN weather/NOUN wind/NOUN)
#   blew/VERB
#   falling/VERB
#   (NOUN_PHRASE snow/ADJ intent/NOUN)
#   upon/ADP
#   (NOUN_PHRASE purpose/ADJ rain/NOUN)
#   less/ADV
#   (NOUN_PHRASE open/ADJ entreaty/NOUN foul/NOUN weather/NOUN)
#   know/VERB
#   (NOUN_PHRASE rain/NOUN snow/NOUN)
#   could/VERB
#   one/NUM
#   often/ADV
#   came/VERB
#   scrooge/ADJ
#   never/ADV
#   (NOUN_PHRASE nobody/NOUN)
#   ever/ADV
#   stopped/VERB
#   (NOUN_PHRASE street/NOUN)
#   say/VERB
#   (NOUN_PHRASE looks/NOUN)
#   dear/ADJ
#   scrooge/ADJ
#   come/VERB
#   see/VERB
#   (NOUN_PHRASE beggars/NOUN)
#   bestow/VERB
#   (NOUN_PHRASE children/NOUN)
#   asked/VERB
#   (NOUN_PHRASE man/NOUN woman/NOUN)
#   ever/ADV
#   (NOUN_PHRASE life/NOUN)
#   (NOUN_PHRASE inquired/ADJ way/NOUN place/NOUN)
#   scrooge/VERB
#   even/ADV
#   (NOUN_PHRASE dogs/NOUN)
#   appeared/VERB
#   (NOUN_PHRASE know/ADJ saw/NOUN)
#   coming/VERB
#   would/VERB
#   would/VERB
#   though/VERB
#   said/VERB
#   (NOUN_PHRASE eye/NOUN)
#   better/ADV
#   (NOUN_PHRASE
#     evil/ADJ
#     eye/NOUN
#     dark/NOUN
#     master/NOUN
#     scrooge/NOUN
#     care/NOUN
#     thing/NOUN)
#   liked/VERB
#   (NOUN_PHRASE way/NOUN)
#   along/ADP
#   (NOUN_PHRASE life/NOUN)
#   warning/VERB
#   (NOUN_PHRASE human/ADJ sympathy/ADJ keep/NOUN distance/NOUN)
#   knowing/VERB
#   (NOUN_PHRASE call/NOUN nuts/NOUN)
#   scrooge/VERB
#   upon/ADP
#   (NOUN_PHRASE time/NOUN)
#   (NOUN_PHRASE good/ADJ days/NOUN year/NOUN)
#   christmas/VERB
#   eve/VERB
#   (NOUN_PHRASE old/ADJ scrooge/NOUN)
#   sat/VERB
#   (NOUN_PHRASE busy/ADJ cold/ADJ bleak/NOUN)
#   biting/VERB
#   (NOUN_PHRASE weather/ADJ foggy/NOUN)
#   could/VERB
#   hear/VERB
#   (NOUN_PHRASE people/NOUN court/NOUN)
#   outside/ADP
#   go/VERB
#   (NOUN_PHRASE hands/NOUN)
#   upon/ADP
#   (NOUN_PHRASE feet/NOUN)
#   upon/ADP
#   (NOUN_PHRASE warm/ADJ city/NOUN)
#   gone/VERB
#   three/NUM
#   quite/ADV
#   dark/ADJ
#   already/ADV
#   (NOUN_PHRASE light/ADJ day/NOUN)
#   flaring/VERB
#   (NOUN_PHRASE windows/NOUN)
#   neighbouring/VERB
#   (NOUN_PHRASE offices/NOUN)
#   like/ADP
#   ruddy/VERB
#   upon/ADP
#   (NOUN_PHRASE brown/ADJ air/NOUN fog/NOUN)
#   came/VERB
#   pouring/VERB
#   every/DET
#   (NOUN_PHRASE keyhole/NOUN dense/NOUN)
#   without/ADP
#   although/ADP
#   (NOUN_PHRASE court/NOUN houses/NOUN)
#   opposite/VERB
#   (NOUN_PHRASE mere/ADJ phantoms/NOUN)
#   see/VERB
#   dingy/ADJ
#   come/VERB
#   (NOUN_PHRASE everything/NOUN)
#   one/NUM
#   might/VERB
#   thought/VERB
#   nature/ADV
#   lived/VERB
#   hard/ADV
#   (NOUN_PHRASE large/ADJ door/NOUN scrooge/NOUN)
#   open/ADJ
#   might/VERB
#   keep/VERB
#   (NOUN_PHRASE eye/NOUN)
#   upon/ADP
#   (NOUN_PHRASE clerk/NOUN)
#   dismal/ADJ
#   little/ADJ
#   beyond/ADP
#   (NOUN_PHRASE sort/NOUN tank/NOUN letters/NOUN)
#   scrooge/VERB
#   (NOUN_PHRASE small/ADJ fire/NOUN clerk/NOUN fire/NOUN)
#   much/ADJ
#   smaller/ADJ
#   looked/VERB
#   like/ADP
#   one/NUM
#   could/VERB
#   scrooge/VERB
#   (NOUN_PHRASE room/NOUN)
#   surely/ADV
#   clerk/ADJ
#   came/VERB
#   (NOUN_PHRASE master/NOUN)
#   predicted/VERB
#   would/VERB
#   (NOUN_PHRASE necessary/ADJ part/NOUN clerk/NOUN)
#   put/VERB
#   (NOUN_PHRASE white/ADJ comforter/NOUN)
#   tried/VERB
#   (NOUN_PHRASE warm/ADJ candle/NOUN effort/NOUN man/NOUN)
#   (NOUN_PHRASE
#     strong/ADJ
#     merry/NOUN
#     christmas/NOUN
#     uncle/NOUN
#     god/NOUN)
#   save/VERB
#   cried/VERB
#   (NOUN_PHRASE
#     cheerful/ADJ
#     voice/NOUN
#     voice/NOUN
#     scrooge/NOUN
#     nephew/NOUN)
#   came/VERB
#   upon/ADP
#   quickly/ADV
#   (NOUN_PHRASE first/ADJ approach/NOUN bah/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ humbug/NOUN)
#   heated/VERB
#   rapid/ADJ
#   walking/VERB
#   (NOUN_PHRASE fog/NOUN frost/NOUN)
#   (NOUN_PHRASE nephew/ADJ scrooge/NOUN)
#   (NOUN_PHRASE glow/ADJ face/NOUN)
#   ruddy/VERB
#   (NOUN_PHRASE handsome/ADJ eyes/NOUN)
#   sparkled/VERB
#   (NOUN_PHRASE breath/NOUN)
#   smoked/VERB
#   (NOUN_PHRASE christmas/ADJ humbug/NOUN uncle/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ nephew/ADJ mean/NOUN sure/NOUN)
#   said/VERB
#   (NOUN_PHRASE
#     scrooge/ADJ
#     merry/NOUN
#     christmas/NOUN
#     right/NOUN
#     merry/NOUN
#     reason/NOUN
#     merry/NOUN)
#   poor/ADJ
#   enough/ADV
#   come/VERB
#   returned/VERB
#   nephew/ADP
#   gaily/ADV
#   (NOUN_PHRASE right/ADJ dismal/ADJ reason/NOUN)
#   rich/ADJ
#   enough/ADV
#   scrooge/VERB
#   (NOUN_PHRASE better/ADJ answer/NOUN)
#   (NOUN_PHRASE ready/ADJ moment/NOUN)
#   said/VERB
#   (NOUN_PHRASE bah/NOUN)
#   followed/VERB
#   (NOUN_PHRASE humbug/ADJ uncle/NOUN)
#   said/VERB
#   nephew/ADJ
#   else/ADV
#   returned/VERB
#   (NOUN_PHRASE uncle/ADJ live/ADJ world/NOUN merry/NOUN)
#   christmas/VERB
#   upon/ADP
#   (NOUN_PHRASE
#     merry/NOUN
#     christmas/NOUN
#     christmas/NOUN
#     time/NOUN
#     time/NOUN)
#   without/ADP
#   (NOUN_PHRASE money/NOUN time/NOUN)
#   finding/VERB
#   (NOUN_PHRASE year/NOUN)
#   older/ADP
#   (NOUN_PHRASE hour/NOUN time/NOUN books/NOUN)
#   every/DET
#   (NOUN_PHRASE round/NOUN dozen/NOUN)
#   presented/VERB
#   dead/ADJ
#   could/VERB
#   work/VERB
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   indignantly/ADV
#   every/DET
#   goes/VERB
#   (NOUN_PHRASE christmas/ADJ lips/NOUN)
#   boiled/VERB
#   pudding/VERB
#   buried/VERB
#   holly/ADV
#   (NOUN_PHRASE heart/NOUN uncle/NOUN)
#   pleaded/VERB
#   (NOUN_PHRASE nephew/ADJ nephew/NOUN)
#   returned/VERB
#   (NOUN_PHRASE uncle/ADJ keep/NOUN christmas/NOUN way/NOUN let/NOUN)
#   keep/VERB
#   (NOUN_PHRASE mine/ADJ keep/NOUN)
#   repeated/VERB
#   scrooge/ADJ
#   nephew/ADJ
#   keep/VERB
#   (NOUN_PHRASE let/NOUN)
#   leave/VERB
#   alone/ADV
#   said/VERB
#   scrooge/ADJ
#   much/ADV
#   good/ADJ
#   may/VERB
#   much/ADV
#   good/VERB
#   ever/ADV
#   done/VERB
#   (NOUN_PHRASE many/ADJ things/NOUN)
#   might/VERB
#   (NOUN_PHRASE good/ADJ dare/NOUN)
#   say/VERB
#   returned/VERB
#   (NOUN_PHRASE nephew/ADJ christmas/NOUN)
#   among/ADP
#   (NOUN_PHRASE rest/ADJ sure/NOUN)
#   always/ADV
#   thought/VERB
#   (NOUN_PHRASE christmas/ADJ time/NOUN)
#   come/VERB
#   round/ADP
#   apart/ADV
#   (NOUN_PHRASE name/NOUN anything/NOUN)
#   belonging/VERB
#   apart/ADV
#   (NOUN_PHRASE good/ADJ time/NOUN kind/NOUN)
#   (NOUN_PHRASE pleasant/ADJ time/NOUN time/NOUN)
#   know/VERB
#   (NOUN_PHRASE long/ADJ year/NOUN men/NOUN women/NOUN)
#   one/NUM
#   (NOUN_PHRASE consent/NOUN)
#   (NOUN_PHRASE open/ADJ hearts/NOUN)
#   think/VERB
#   (NOUN_PHRASE people/NOUN)
#   really/ADV
#   grave/VERB
#   another/DET
#   (NOUN_PHRASE race/NOUN)
#   creatures/VERB
#   bound/PRT
#   (NOUN_PHRASE journeys/NOUN)
#   therefore/ADV
#   uncle/ADJ
#   though/ADP
#   never/ADV
#   put/VERB
#   (NOUN_PHRASE gold/NOUN silver/NOUN pocket/NOUN)
#   believe/VERB
#   done/VERB
#   good/ADJ
#   good/ADJ
#   say/VERB
#   (NOUN_PHRASE god/ADJ bless/NOUN clerk/NOUN tank/NOUN)
#   becoming/VERB
#   immediately/ADV
#   (NOUN_PHRASE sensible/ADJ fire/NOUN)
#   last/ADJ
#   ever/ADV
#   let/VERB
#   hear/VERB
#   another/DET
#   (NOUN_PHRASE sound/NOUN)
#   said/VERB
#   scrooge/ADJ
#   keep/VERB
#   (NOUN_PHRASE christmas/NOUN situation/NOUN)
#   quite/ADV
#   (NOUN_PHRASE speaker/NOUN sir/NOUN)
#   added/VERB
#   turning/VERB
#   (NOUN_PHRASE nephew/ADJ wonder/NOUN)
#   go/VERB
#   (NOUN_PHRASE parliament/ADJ angry/ADJ uncle/NOUN)
#   come/VERB
#   (NOUN_PHRASE dine/NOUN)
#   us/PRON
#   (NOUN_PHRASE scrooge/NOUN)
#   said/VERB
#   would/VERB
#   see/VERB
#   yes/ADV
#   indeed/ADV
#   went/VERB
#   (NOUN_PHRASE whole/ADJ length/NOUN expression/NOUN)
#   said/VERB
#   would/VERB
#   see/VERB
#   first/ADV
#   cried/VERB
#   (NOUN_PHRASE scrooge/NOUN nephew/NOUN get/NOUN)
#   married/VERB
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   fell/VERB
#   love/ADV
#   fell/VERB
#   love/VERB
#   growled/VERB
#   scrooge/ADV
#   one/NUM
#   (NOUN_PHRASE thing/NOUN world/NOUN)
#   (NOUN_PHRASE ridiculous/ADJ merry/NOUN)
#   christmas/ADV
#   (NOUN_PHRASE good/ADJ afternoon/NOUN uncle/NOUN)
#   never/ADV
#   came/VERB
#   (NOUN_PHRASE see/NOUN)
#   happened/VERB
#   (NOUN_PHRASE give/ADJ reason/NOUN)
#   coming/VERB
#   (NOUN_PHRASE good/ADJ afternoon/NOUN)
#   said/VERB
#   scrooge/ADJ
#   want/VERB
#   (NOUN_PHRASE nothing/NOUN ask/NOUN nothing/NOUN friends/NOUN)
#   (NOUN_PHRASE good/ADJ afternoon/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ sorry/ADJ heart/NOUN)
#   find/VERB
#   never/ADV
#   (NOUN_PHRASE quarrel/NOUN party/NOUN)
#   made/VERB
#   christmas/ADJ
#   keep/VERB
#   (NOUN_PHRASE christmas/NOUN humour/NOUN)
#   (NOUN_PHRASE last/ADJ merry/NOUN)
#   christmas/VERB
#   uncle/ADV
#   (NOUN_PHRASE good/ADJ afternoon/NOUN)
#   said/VERB
#   scrooge/ADV
#   (NOUN_PHRASE happy/ADJ new/ADJ year/NOUN)
#   (NOUN_PHRASE good/ADJ afternoon/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ nephew/NOUN)
#   left/VERB
#   (NOUN_PHRASE room/NOUN)
#   without/ADP
#   (NOUN_PHRASE angry/ADJ word/NOUN notwithstanding/NOUN)
#   stopped/VERB
#   (NOUN_PHRASE
#     outer/ADJ
#     door/NOUN
#     bestow/NOUN
#     season/NOUN
#     clerk/NOUN)
#   cold/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   returned/VERB
#   another/DET
#   (NOUN_PHRASE fellow/NOUN)
#   muttered/VERB
#   (NOUN_PHRASE scrooge/ADJ clerk/NOUN)
#   (NOUN_PHRASE
#     fifteen/ADJ
#     shillings/NOUN
#     wife/NOUN
#     family/NOUN
#     merry/NOUN
#     christmas/NOUN
#     retire/NOUN
#     scrooge/NOUN)
#   nephew/ADJ
#   let/VERB
#   two/NUM
#   (NOUN_PHRASE people/NOUN)
#   portly/ADV
#   gentlemen/VERB
#   (NOUN_PHRASE pleasant/ADJ behold/NOUN)
#   stood/VERB
#   (NOUN_PHRASE scrooge/ADJ office/NOUN books/NOUN)
#   hands/VERB
#   (NOUN_PHRASE scrooge/ADJ marley/NOUN)
#   believe/VERB
#   said/VERB
#   one/NUM
#   (NOUN_PHRASE gentlemen/NOUN pleasure/NOUN)
#   scrooge/VERB
#   (NOUN_PHRASE mr/NOUN marley/NOUN marley/NOUN)
#   dead/ADJ
#   seven/NUM
#   (NOUN_PHRASE years/NOUN)
#   scrooge/ADV
#   replied/VERB
#   died/ADJ
#   seven/NUM
#   (NOUN_PHRASE years/NOUN)
#   ago/ADV
#   (NOUN_PHRASE night/NOUN doubt/NOUN liberality/NOUN)
#   well/ADV
#   (NOUN_PHRASE partner/NOUN)
#   said/VERB
#   (NOUN_PHRASE gentleman/ADJ credentials/NOUN)
#   certainly/ADV
#   two/NUM
#   (NOUN_PHRASE spirits/NOUN word/NOUN liberality/NOUN)
#   scrooge/VERB
#   (NOUN_PHRASE shook/NOUN head/NOUN credentials/NOUN)
#   back/PRT
#   (NOUN_PHRASE season/NOUN year/NOUN scrooge/NOUN)
#   said/VERB
#   gentleman/ADJ
#   taking/VERB
#   pen/ADJ
#   usually/ADV
#   make/VERB
#   (NOUN_PHRASE slight/ADJ poor/ADJ suffer/NOUN)
#   greatly/ADV
#   (NOUN_PHRASE present/ADJ time/NOUN)
#   (NOUN_PHRASE many/ADJ thousands/NOUN)
#   want/VERB
#   (NOUN_PHRASE common/ADJ hundreds/NOUN thousands/NOUN)
#   want/VERB
#   (NOUN_PHRASE common/ADJ sir/NOUN prisons/NOUN)
#   asked/VERB
#   (NOUN_PHRASE scrooge/ADJ plenty/NOUN prisons/NOUN)
#   said/VERB
#   gentleman/ADJ
#   laying/VERB
#   (NOUN_PHRASE pen/ADJ workhouses/NOUN)
#   demanded/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   still/ADV
#   still/ADV
#   returned/VERB
#   (NOUN_PHRASE gentleman/ADJ wish/NOUN)
#   could/VERB
#   say/VERB
#   (NOUN_PHRASE poor/ADJ full/ADJ vigour/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ busy/ADJ sir/NOUN oh/NOUN afraid/NOUN)
#   said/VERB
#   (NOUN_PHRASE first/ADJ something/NOUN)
#   (NOUN_PHRASE stop/ADJ course/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ glad/ADJ hear/NOUN)
#   scarcely/ADV
#   (NOUN_PHRASE christian/ADJ cheer/NOUN mind/NOUN body/NOUN)
#   returned/VERB
#   gentleman/ADJ
#   us/PRON
#   endeavouring/VERB
#   raise/VERB
#   (NOUN_PHRASE buy/NOUN)
#   (NOUN_PHRASE poor/ADJ meat/NOUN drink/NOUN)
#   means/VERB
#   warmth/ADP
#   (NOUN_PHRASE choose/ADJ time/NOUN time/NOUN)
#   want/VERB
#   keenly/ADV
#   felt/VERB
#   shall/VERB
#   put/VERB
#   (NOUN_PHRASE nothing/NOUN scrooge/NOUN)
#   replied/VERB
#   wish/ADJ
#   wish/ADJ
#   left/VERB
#   alone/ADV
#   said/VERB
#   scrooge/ADJ
#   since/ADP
#   (NOUN_PHRASE ask/NOUN)
#   (NOUN_PHRASE wish/ADJ gentlemen/NOUN)
#   answer/VERB
#   make/VERB
#   (NOUN_PHRASE merry/NOUN christmas/NOUN)
#   ca/VERB
#   make/VERB
#   (NOUN_PHRASE idle/ADJ people/NOUN)
#   merry/VERB
#   (NOUN_PHRASE help/NOUN)
#   mentioned/VERB
#   (NOUN_PHRASE cost/NOUN enough/NOUN)
#   must/VERB
#   go/VERB
#   many/ADJ
#   ca/VERB
#   go/VERB
#   many/ADJ
#   would/VERB
#   rather/ADV
#   die/VERB
#   would/VERB
#   rather/ADV
#   die/VERB
#   said/VERB
#   (NOUN_PHRASE
#     scrooge/ADJ
#     better/ADJ
#     decrease/NOUN
#     surplus/NOUN
#     population/NOUN
#     excuse/NOUN)
#   know/VERB
#   might/VERB
#   know/VERB
#   (NOUN_PHRASE
#     observed/ADJ
#     gentleman/NOUN
#     business/NOUN
#     scrooge/NOUN)
#   returned/VERB
#   (NOUN_PHRASE enough/ADJ man/NOUN understand/NOUN business/NOUN)
#   interfere/ADV
#   (NOUN_PHRASE people/NOUN)
#   mine/VERB
#   (NOUN_PHRASE good/ADJ afternoon/NOUN gentlemen/NOUN)
#   seeing/VERB
#   clearly/ADV
#   would/VERB
#   point/VERB
#   (NOUN_PHRASE gentlemen/NOUN)
#   scrooge/VERB
#   resumed/VERB
#   (NOUN_PHRASE opinion/NOUN)
#   (NOUN_PHRASE
#     facetious/ADJ
#     temper/ADJ
#     usual/ADJ
#     fog/NOUN
#     darkness/NOUN
#     people/NOUN)
#   ran/VERB
#   flaring/VERB
#   go/VERB
#   (NOUN_PHRASE conduct/ADJ way/NOUN)
#   (NOUN_PHRASE ancient/ADJ church/NOUN)
#   whose/PRON
#   (NOUN_PHRASE old/ADJ bell/NOUN)
#   always/ADV
#   peeping/VERB
#   (NOUN_PHRASE scrooge/NOUN window/NOUN wall/NOUN)
#   became/VERB
#   (NOUN_PHRASE invisible/ADJ struck/ADJ hours/NOUN quarters/NOUN)
#   clouds/VERB
#   (NOUN_PHRASE tremulous/ADJ afterwards/NOUN)
#   teeth/ADP
#   chattering/VERB
#   (NOUN_PHRASE frozen/ADJ head/NOUN cold/NOUN)
#   became/VERB
#   (NOUN_PHRASE street/ADJ corner/ADJ court/NOUN)
#   lighted/VERB
#   (NOUN_PHRASE great/ADJ fire/NOUN round/NOUN party/NOUN)
#   ragged/VERB
#   (NOUN_PHRASE men/NOUN)
#   boys/VERB
#   (NOUN_PHRASE hands/NOUN)
#   winking/VERB
#   (NOUN_PHRASE eyes/NOUN blaze/NOUN)
#   left/VERB
#   (NOUN_PHRASE turned/ADJ brightness/ADJ shops/NOUN)
#   holly/ADV
#   (NOUN_PHRASE berries/NOUN)
#   crackled/VERB
#   (NOUN_PHRASE windows/NOUN)
#   made/VERB
#   pale/ADJ
#   faces/VERB
#   (NOUN_PHRASE ruddy/NOUN)
#   passed/VERB
#   (NOUN_PHRASE poulterers/NOUN grocers/NOUN)
#   became/VERB
#   (NOUN_PHRASE splendid/ADJ joke/NOUN)
#   glorious/ADJ
#   next/ADJ
#   impossible/ADJ
#   believe/VERB
#   (NOUN_PHRASE dull/NOUN bargain/NOUN anything/NOUN)
#   (NOUN_PHRASE lord/ADJ mighty/NOUN mansion/NOUN house/NOUN)
#   gave/VERB
#   (NOUN_PHRASE fifty/ADJ keep/NOUN christmas/NOUN)
#   lord/VERB
#   even/ADV
#   little/ADJ
#   five/NUM
#   (NOUN_PHRASE shillings/NOUN streets/NOUN)
#   stirred/VERB
#   pudding/VERB
#   (NOUN_PHRASE wife/NOUN baby/NOUN)
#   buy/VERB
#   (NOUN_PHRASE beef/NOUN)
#   yet/ADV
#   biting/VERB
#   (NOUN_PHRASE cold/ADJ good/ADJ saint/NOUN)
#   nipped/VERB
#   (NOUN_PHRASE evil/ADJ spirit/NOUN)
#   nose/ADV
#   (NOUN_PHRASE touch/ADJ weather/NOUN)
#   instead/ADV
#   using/VERB
#   familiar/ADJ
#   indeed/ADV
#   would/VERB
#   roared/VERB
#   (NOUN_PHRASE purpose/ADJ owner/NOUN)
#   one/NUM
#   young/ADJ
#   nose/ADV
#   gnawed/VERB
#   (NOUN_PHRASE hungry/ADJ cold/ADJ bones/NOUN)
#   gnawed/VERB
#   (NOUN_PHRASE dogs/NOUN)
#   (NOUN_PHRASE scrooge/ADJ keyhole/ADJ christmas/NOUN carol/NOUN)
#   first/ADV
#   (NOUN_PHRASE sound/ADJ god/NOUN bless/NOUN)
#   merry/VERB
#   (NOUN_PHRASE gentleman/NOUN)
#   may/VERB
#   (NOUN_PHRASE nothing/NOUN)
#   scrooge/VERB
#   seized/VERB
#   (NOUN_PHRASE ruler/NOUN action/NOUN terror/NOUN)
#   leaving/VERB
#   (NOUN_PHRASE keyhole/ADJ fog/NOUN)
#   even/ADV
#   frost/VERB
#   (NOUN_PHRASE length/ADJ hour/NOUN)
#   shutting/VERB
#   (NOUN_PHRASE scrooge/ADJ stool/NOUN fact/NOUN clerk/NOUN tank/NOUN)
#   instantly/ADV
#   candle/ADJ
#   put/VERB
#   hat/PRON
#   want/VERB
#   (NOUN_PHRASE day/NOUN)
#   suppose/VERB
#   said/VERB
#   scrooge/ADJ
#   quite/ADV
#   (NOUN_PHRASE convenient/ADJ sir/NOUN convenient/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ fair/ADJ stop/NOUN think/NOUN ill/NOUN)
#   used/VERB
#   bound/ADP
#   (NOUN_PHRASE clerk/NOUN)
#   smiled/VERB
#   faintly/ADV
#   yet/ADV
#   said/VERB
#   (NOUN_PHRASE
#     scrooge/ADJ
#     think/ADJ
#     pay/NOUN
#     day/NOUN
#     work/NOUN
#     clerk/NOUN)
#   observed/VERB
#   (NOUN_PHRASE year/NOUN)
#   (NOUN_PHRASE poor/ADJ excuse/NOUN man/NOUN pocket/NOUN)
#   every/DET
#   (NOUN_PHRASE december/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN chin/NOUN suppose/NOUN)
#   must/VERB
#   whole/VERB
#   (NOUN_PHRASE day/NOUN)
#   next/ADP
#   (NOUN_PHRASE morning/NOUN clerk/NOUN)
#   promised/VERB
#   would/VERB
#   scrooge/VERB
#   (NOUN_PHRASE walked/ADJ growl/NOUN office/NOUN)
#   closed/VERB
#   (NOUN_PHRASE clerk/NOUN)
#   long/ADV
#   ends/VERB
#   (NOUN_PHRASE white/ADJ comforter/NOUN waist/NOUN)
#   went/VERB
#   (NOUN_PHRASE end/ADJ lane/NOUN boys/NOUN)
#   (NOUN_PHRASE twenty/ADJ times/NOUN)
#   honour/VERB
#   ran/VERB
#   home/ADV
#   (NOUN_PHRASE camden/ADJ town/NOUN hard/NOUN)
#   could/VERB
#   play/VERB
#   scrooge/ADJ
#   took/VERB
#   (NOUN_PHRASE melancholy/NOUN dinner/NOUN)
#   (NOUN_PHRASE usual/ADJ melancholy/NOUN)
#   read/VERB
#   (NOUN_PHRASE rest/NOUN)
#   evening/VERB
#   went/VERB
#   (NOUN_PHRASE home/NOUN bed/NOUN)
#   lived/VERB
#   (NOUN_PHRASE chambers/NOUN partner/NOUN)
#   (NOUN_PHRASE gloomy/ADJ rooms/NOUN)
#   building/VERB
#   yard/ADV
#   (NOUN_PHRASE little/ADJ business/NOUN)
#   one/NUM
#   could/VERB
#   scarcely/ADV
#   help/VERB
#   must/VERB
#   (NOUN_PHRASE young/ADJ house/NOUN houses/NOUN)
#   forgotten/VERB
#   (NOUN_PHRASE way/NOUN)
#   old/ADJ
#   enough/ADV
#   dreary/ADJ
#   enough/ADV
#   (NOUN_PHRASE nobody/NOUN)
#   lived/VERB
#   (NOUN_PHRASE scrooge/ADJ rooms/NOUN)
#   let/VERB
#   (NOUN_PHRASE offices/NOUN)
#   yard/VERB
#   dark/ADJ
#   even/ADV
#   scrooge/VERB
#   (NOUN_PHRASE knew/NOUN)
#   every/DET
#   (NOUN_PHRASE stone/NOUN)
#   hands/VERB
#   (NOUN_PHRASE fog/ADJ frost/NOUN hung/NOUN)
#   (NOUN_PHRASE black/ADJ old/ADJ house/NOUN)
#   seemed/VERB
#   (NOUN_PHRASE
#     weather/ADJ
#     sat/ADJ
#     mournful/ADJ
#     threshold/ADJ
#     fact/NOUN
#     nothing/NOUN)
#   (NOUN_PHRASE particular/ADJ knocker/NOUN door/NOUN)
#   except/ADP
#   large/ADJ
#   also/ADV
#   (NOUN_PHRASE fact/NOUN scrooge/NOUN)
#   seen/VERB
#   (NOUN_PHRASE night/NOUN morning/NOUN)
#   (NOUN_PHRASE whole/ADJ place/NOUN)
#   also/ADV
#   scrooge/VERB
#   (NOUN_PHRASE little/ADJ called/ADJ man/NOUN city/NOUN)
#   london/VERB
#   even/ADV
#   (NOUN_PHRASE bold/ADJ word/NOUN let/NOUN)
#   also/ADV
#   borne/VERB
#   (NOUN_PHRASE mind/NOUN scrooge/NOUN)
#   one/NUM
#   (NOUN_PHRASE thought/NOUN marley/NOUN)
#   since/ADP
#   (NOUN_PHRASE last/ADJ mention/NOUN)
#   (NOUN_PHRASE
#     dead/ADJ
#     partner/NOUN
#     afternoon/NOUN
#     let/NOUN
#     man/NOUN)
#   happened/VERB
#   (NOUN_PHRASE scrooge/ADJ key/ADJ lock/NOUN door/NOUN)
#   saw/VERB
#   (NOUN_PHRASE knocker/NOUN)
#   without/ADP
#   (NOUN_PHRASE
#     change/NOUN
#     knocker/NOUN
#     marley/NOUN
#     face/NOUN
#     marley/NOUN
#     face/NOUN)
#   shadow/VERB
#   yard/ADV
#   (NOUN_PHRASE dismal/ADJ light/NOUN)
#   like/ADP
#   (NOUN_PHRASE bad/ADJ dark/ADJ cellar/NOUN)
#   angry/ADJ
#   ferocious/ADJ
#   looked/VERB
#   (NOUN_PHRASE scrooge/ADJ marley/NOUN)
#   used/VERB
#   (NOUN_PHRASE look/NOUN)
#   ghostly/ADV
#   turned/VERB
#   upon/PRT
#   ghostly/ADV
#   (NOUN_PHRASE forehead/ADJ hair/NOUN)
#   curiously/ADV
#   stirred/VERB
#   (NOUN_PHRASE breath/NOUN)
#   though/ADP
#   (NOUN_PHRASE eyes/NOUN)
#   wide/ADJ
#   open/ADJ
#   perfectly/ADV
#   (NOUN_PHRASE motionless/ADJ livid/ADJ colour/NOUN)
#   made/VERB
#   (NOUN_PHRASE horrible/ADJ horror/NOUN)
#   seemed/VERB
#   (NOUN_PHRASE spite/ADJ face/NOUN)
#   beyond/ADP
#   rather/ADV
#   (NOUN_PHRASE part/NOUN expression/NOUN scrooge/NOUN)
#   looked/VERB
#   (NOUN_PHRASE phenomenon/ADJ knocker/NOUN)
#   say/VERB
#   startled/VERB
#   (NOUN_PHRASE blood/NOUN)
#   (NOUN_PHRASE conscious/ADJ terrible/ADJ sensation/NOUN)
#   would/VERB
#   put/VERB
#   (NOUN_PHRASE hand/NOUN)
#   upon/ADP
#   key/ADJ
#   turned/VERB
#   (NOUN_PHRASE
#     walked/ADJ
#     lighted/ADJ
#     candle/NOUN
#     pause/NOUN
#     moment/NOUN)
#   shut/VERB
#   (NOUN_PHRASE door/ADJ look/NOUN)
#   behind/ADP
#   (NOUN_PHRASE
#     first/ADJ
#     sight/ADJ
#     marley/NOUN
#     pigtail/NOUN
#     hall/NOUN
#     nothing/NOUN)
#   back/ADV
#   (NOUN_PHRASE door/NOUN)
#   except/ADP
#   (NOUN_PHRASE nuts/NOUN)
#   held/VERB
#   (NOUN_PHRASE knocker/NOUN)
#   said/VERB
#   (NOUN_PHRASE pooh/NOUN pooh/NOUN)
#   closed/VERB
#   (NOUN_PHRASE sound/ADJ house/NOUN)
#   like/ADP
#   every/DET
#   (NOUN_PHRASE room/NOUN)
#   every/DET
#   appeared/VERB
#   (NOUN_PHRASE separate/ADJ echoes/NOUN)
#   (NOUN_PHRASE scrooge/ADJ man/NOUN)
#   frightened/VERB
#   (NOUN_PHRASE echoes/NOUN)
#   fastened/VERB
#   (NOUN_PHRASE door/NOUN)
#   walked/VERB
#   across/ADP
#   (NOUN_PHRASE hall/NOUN stairs/NOUN)
#   slowly/ADV
#   candle/ADJ
#   went/VERB
#   may/VERB
#   talk/VERB
#   driving/VERB
#   (NOUN_PHRASE good/ADJ old/ADJ stairs/NOUN)
#   (NOUN_PHRASE bad/ADJ young/ADJ act/NOUN)
#   (NOUN_PHRASE parliament/ADJ mean/NOUN)
#   say/VERB
#   might/VERB
#   got/VERB
#   hearse/ADJ
#   taken/VERB
#   (NOUN_PHRASE towards/NOUN)
#   (NOUN_PHRASE wall/ADJ door/NOUN towards/NOUN)
#   done/VERB
#   (NOUN_PHRASE easy/ADJ plenty/NOUN room/NOUN)
#   perhaps/ADV
#   (NOUN_PHRASE reason/NOUN)
#   (NOUN_PHRASE scrooge/ADJ thought/NOUN)
#   saw/VERB
#   hearse/ADJ
#   going/VERB
#   (NOUN_PHRASE gloom/NOUN half/NOUN dozen/NOUN street/NOUN)
#   would/VERB
#   lighted/VERB
#   well/ADV
#   may/VERB
#   suppose/VERB
#   pretty/ADV
#   (NOUN_PHRASE dark/ADJ scrooge/NOUN scrooge/NOUN)
#   went/VERB
#   caring/VERB
#   (NOUN_PHRASE darkness/NOUN)
#   (NOUN_PHRASE cheap/ADJ scrooge/NOUN)
#   liked/VERB
#   (NOUN_PHRASE shut/ADJ heavy/ADJ door/NOUN)
#   walked/VERB
#   (NOUN_PHRASE rooms/NOUN)
#   see/VERB
#   right/ADV
#   (NOUN_PHRASE enough/ADJ recollection/NOUN face/NOUN desire/NOUN)
#   sitting/VERB
#   (NOUN_PHRASE room/NOUN nobody/NOUN)
#   (NOUN_PHRASE table/ADJ nobody/NOUN)
#   sofa/VERB
#   (NOUN_PHRASE small/ADJ fire/NOUN)
#   (NOUN_PHRASE
#     ready/ADJ
#     little/ADJ
#     saucepan/ADJ
#     gruel/NOUN
#     scrooge/NOUN)
#   (NOUN_PHRASE cold/ADJ head/NOUN)
#   upon/ADP
#   (NOUN_PHRASE hob/NOUN nobody/NOUN)
#   bed/VERB
#   (NOUN_PHRASE nobody/ADJ closet/NOUN nobody/NOUN)
#   hanging/VERB
#   (NOUN_PHRASE attitude/NOUN wall/NOUN)
#   (NOUN_PHRASE usual/ADJ old/ADJ old/ADJ shoes/NOUN)
#   two/NUM
#   three/NUM
#   (NOUN_PHRASE legs/NOUN)
#   quite/ADV
#   satisfied/VERB
#   (NOUN_PHRASE closed/ADJ door/NOUN)
#   locked/VERB
#   thus/ADV
#   (NOUN_PHRASE surprise/NOUN)
#   took/VERB
#   (NOUN_PHRASE cravat/NOUN put/NOUN slippers/NOUN)
#   sat/VERB
#   (NOUN_PHRASE fire/NOUN)
#   take/VERB
#   (NOUN_PHRASE gruel/NOUN)
#   (NOUN_PHRASE low/ADJ fire/NOUN)
#   indeed/ADV
#   (NOUN_PHRASE nothing/NOUN night/NOUN)
#   obliged/VERB
#   (NOUN_PHRASE sit/NOUN)
#   (NOUN_PHRASE close/ADJ brood/NOUN)
#   could/VERB
#   least/VERB
#   (NOUN_PHRASE sensation/ADJ warmth/NOUN fuel/NOUN)
#   old/ADJ
#   one/NUM
#   built/VERB
#   (NOUN_PHRASE dutch/NOUN)
#   long/ADV
#   ago/ADV
#   (NOUN_PHRASE round/NOUN dutch/NOUN daughters/NOUN)
#   descending/VERB
#   (NOUN_PHRASE air/NOUN clouds/NOUN)
#   like/ADP
#   putting/VERB
#   (NOUN_PHRASE sea/NOUN hundreds/NOUN)
#   figures/VERB
#   (NOUN_PHRASE thoughts/NOUN)
#   yet/ADV
#   face/VERB
#   marley/ADJ
#   seven/NUM
#   (NOUN_PHRASE years/NOUN)
#   dead/ADJ
#   came/VERB
#   (NOUN_PHRASE like/ADJ ancient/NOUN)
#   swallowed/VERB
#   (NOUN_PHRASE whole/ADJ smooth/NOUN)
#   blank/VERB
#   (NOUN_PHRASE
#     first/ADJ
#     power/NOUN
#     shape/NOUN
#     fragments/NOUN
#     thoughts/NOUN)
#   would/VERB
#   (NOUN_PHRASE old/ADJ marley/NOUN head/NOUN)
#   every/DET
#   one/NUM
#   (NOUN_PHRASE humbug/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   walked/VERB
#   across/ADP
#   (NOUN_PHRASE room/NOUN)
#   several/ADJ
#   turns/VERB
#   sat/ADJ
#   threw/ADP
#   (NOUN_PHRASE head/NOUN)
#   back/ADV
#   (NOUN_PHRASE chair/ADJ glance/NOUN)
#   happened/VERB
#   (NOUN_PHRASE
#     rest/ADJ
#     upon/NOUN
#     bell/NOUN
#     bell/NOUN
#     hung/NOUN
#     room/NOUN)
#   purpose/ADV
#   forgotten/ADJ
#   chamber/VERB
#   (NOUN_PHRASE story/NOUN building/NOUN)
#   (NOUN_PHRASE great/ADJ astonishment/ADJ strange/ADJ dread/NOUN)
#   looked/VERB
#   (NOUN_PHRASE saw/NOUN bell/NOUN)
#   begin/VERB
#   softly/ADV
#   outset/VERB
#   scarcely/ADV
#   made/VERB
#   (NOUN_PHRASE sound/NOUN)
#   soon/ADV
#   loudly/ADV
#   every/DET
#   (NOUN_PHRASE bell/NOUN house/NOUN)
#   might/VERB
#   half/VERB
#   (NOUN_PHRASE minute/ADJ minute/NOUN)
#   seemed/VERB
#   (NOUN_PHRASE hour/NOUN bells/NOUN)
#   ceased/VERB
#   begun/VERB
#   together/ADV
#   succeeded/VERB
#   noise/ADV
#   (NOUN_PHRASE deep/ADJ person/NOUN)
#   dragging/VERB
#   (NOUN_PHRASE heavy/ADJ chain/NOUN)
#   (NOUN_PHRASE cellar/ADJ scrooge/NOUN)
#   remembered/VERB
#   (NOUN_PHRASE heard/ADJ ghosts/NOUN)
#   haunted/VERB
#   (NOUN_PHRASE houses/NOUN)
#   dragging/VERB
#   (NOUN_PHRASE chains/NOUN)
#   flew/VERB
#   (NOUN_PHRASE open/ADJ sound/NOUN)
#   heard/VERB
#   noise/ADV
#   much/ADJ
#   coming/VERB
#   (NOUN_PHRASE stairs/NOUN)
#   coming/VERB
#   straight/ADV
#   (NOUN_PHRASE towards/NOUN door/NOUN humbug/NOUN)
#   still/ADV
#   said/VERB
#   scrooge/ADJ
#   wo/VERB
#   believe/VERB
#   (NOUN_PHRASE colour/NOUN)
#   changed/VERB
#   though/ADP
#   without/ADP
#   (NOUN_PHRASE pause/NOUN)
#   came/VERB
#   (NOUN_PHRASE heavy/ADJ door/NOUN)
#   passed/VERB
#   (NOUN_PHRASE room/NOUN eyes/NOUN)
#   upon/ADP
#   coming/VERB
#   dying/VERB
#   though/ADP
#   cried/VERB
#   know/VERB
#   (NOUN_PHRASE marley/ADJ ghost/NOUN)
#   fell/VERB
#   (NOUN_PHRASE face/NOUN marley/NOUN)
#   (NOUN_PHRASE usual/ADJ waistcoat/NOUN boots/NOUN)
#   tassels/VERB
#   latter/ADV
#   like/ADP
#   (NOUN_PHRASE pigtail/NOUN hair/NOUN)
#   upon/ADP
#   (NOUN_PHRASE head/NOUN chain/NOUN)
#   drew/VERB
#   clasped/ADJ
#   middle/VERB
#   long/ADV
#   wound/ADP
#   like/ADP
#   (NOUN_PHRASE tail/NOUN)
#   made/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   observed/VERB
#   closely/ADV
#   (NOUN_PHRASE keys/ADJ deeds/NOUN)
#   (NOUN_PHRASE heavy/ADJ steel/NOUN body/NOUN)
#   (NOUN_PHRASE transparent/ADJ scrooge/NOUN)
#   observing/VERB
#   looking/VERB
#   (NOUN_PHRASE waistcoat/NOUN)
#   could/VERB
#   see/VERB
#   two/NUM
#   behind/ADP
#   (NOUN_PHRASE scrooge/NOUN)
#   often/ADV
#   heard/VERB
#   said/VERB
#   (NOUN_PHRASE marley/NOUN bowels/NOUN)
#   never/ADV
#   believed/VERB
#   believe/VERB
#   even/ADV
#   though/ADP
#   (NOUN_PHRASE looked/ADJ phantom/NOUN)
#   saw/VERB
#   standing/VERB
#   though/ADP
#   (NOUN_PHRASE felt/ADJ influence/NOUN eyes/NOUN)
#   bound/ADP
#   (NOUN_PHRASE head/NOUN)
#   chin/VERB
#   (NOUN_PHRASE wrapper/NOUN)
#   observed/VERB
#   still/ADV
#   (NOUN_PHRASE senses/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   cold/ADJ
#   ever/ADV
#   want/VERB
#   (NOUN_PHRASE much/ADJ marley/NOUN voice/NOUN doubt/NOUN ask/NOUN)
#   said/VERB
#   scrooge/ADJ
#   raising/VERB
#   (NOUN_PHRASE voice/NOUN)
#   (NOUN_PHRASE particular/ADJ shade/NOUN)
#   going/VERB
#   say/VERB
#   (NOUN_PHRASE
#     shade/ADJ
#     life/NOUN
#     partner/NOUN
#     jacob/NOUN
#     marley/NOUN
#     sit/NOUN)
#   asked/VERB
#   scrooge/ADJ
#   looking/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   asked/VERB
#   (NOUN_PHRASE question/NOUN)
#   know/VERB
#   whether/ADP
#   (NOUN_PHRASE ghost/NOUN transparent/NOUN)
#   might/VERB
#   find/VERB
#   (NOUN_PHRASE condition/NOUN)
#   take/VERB
#   (NOUN_PHRASE chair/NOUN)
#   felt/VERB
#   (NOUN_PHRASE event/NOUN)
#   impossible/ADJ
#   might/VERB
#   explanation/VERB
#   (NOUN_PHRASE ghost/NOUN)
#   (NOUN_PHRASE sat/ADJ opposite/ADJ side/NOUN)
#   quite/ADV
#   used/VERB
#   (NOUN_PHRASE believe/NOUN)
#   observed/VERB
#   (NOUN_PHRASE ghost/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   would/VERB
#   beyond/ADP
#   (NOUN_PHRASE senses/NOUN)
#   know/VERB
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ doubt/NOUN senses/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ little/ADJ thing/NOUN)
#   slight/ADJ
#   makes/VERB
#   may/VERB
#   bit/VERB
#   (NOUN_PHRASE beef/ADJ gravy/NOUN)
#   grave/VERB
#   whatever/DET
#   scrooge/ADV
#   (NOUN_PHRASE much/ADJ habit/NOUN)
#   feel/VERB
#   (NOUN_PHRASE heart/NOUN)
#   means/VERB
#   (NOUN_PHRASE truth/ADJ tried/ADJ smart/NOUN)
#   means/VERB
#   (NOUN_PHRASE attention/NOUN)
#   keeping/VERB
#   (NOUN_PHRASE terror/ADJ spectre/ADJ voice/NOUN)
#   disturbed/VERB
#   (NOUN_PHRASE bones/NOUN sit/NOUN)
#   staring/VERB
#   fixed/VERB
#   (NOUN_PHRASE eyes/NOUN silence/NOUN moment/NOUN)
#   would/VERB
#   play/VERB
#   scrooge/VERB
#   (NOUN_PHRASE felt/ADJ something/NOUN)
#   (NOUN_PHRASE awful/ADJ spectre/NOUN)
#   provided/VERB
#   atmosphere/ADV
#   scrooge/VERB
#   could/VERB
#   feel/VERB
#   clearly/ADV
#   (NOUN_PHRASE case/NOUN)
#   though/ADP
#   (NOUN_PHRASE ghost/NOUN)
#   sat/VERB
#   perfectly/ADV
#   (NOUN_PHRASE motionless/ADJ hair/NOUN skirts/NOUN tassels/NOUN)
#   still/ADV
#   agitated/VERB
#   hot/ADJ
#   oven/ADV
#   see/VERB
#   said/VERB
#   scrooge/ADJ
#   quickly/ADV
#   (NOUN_PHRASE charge/NOUN reason/NOUN)
#   though/ADP
#   second/ADJ
#   replied/VERB
#   (NOUN_PHRASE ghost/NOUN)
#   looking/VERB
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ see/NOUN)
#   said/VERB
#   (NOUN_PHRASE ghost/NOUN notwithstanding/NOUN)
#   well/ADV
#   returned/VERB
#   (NOUN_PHRASE scrooge/ADJ rest/NOUN days/NOUN)
#   creation/VERB
#   (NOUN_PHRASE humbug/NOUN tell/NOUN humbug/NOUN spirit/NOUN)
#   raised/VERB
#   (NOUN_PHRASE frightful/ADJ cry/NOUN shook/NOUN chain/NOUN)
#   (NOUN_PHRASE dismal/ADJ noise/NOUN scrooge/NOUN)
#   held/VERB
#   (NOUN_PHRASE tight/ADJ chair/NOUN)
#   save/VERB
#   falling/VERB
#   (NOUN_PHRASE much/ADJ greater/ADJ horror/NOUN phantom/NOUN)
#   taking/VERB
#   (NOUN_PHRASE bandage/NOUN round/NOUN head/NOUN warm/NOUN wear/NOUN)
#   lower/ADV
#   dropped/VERB
#   upon/ADP
#   (NOUN_PHRASE breast/NOUN scrooge/NOUN)
#   fell/VERB
#   upon/ADP
#   (NOUN_PHRASE knees/NOUN)
#   clasped/VERB
#   (NOUN_PHRASE hands/NOUN)
#   face/VERB
#   (NOUN_PHRASE mercy/NOUN)
#   said/VERB
#   (NOUN_PHRASE dreadful/ADJ apparition/NOUN trouble/NOUN man/NOUN)
#   worldly/ADV
#   mind/VERB
#   (NOUN_PHRASE replied/ADJ ghost/NOUN)
#   believe/VERB
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   must/VERB
#   spirits/VERB
#   walk/VERB
#   earth/ADJ
#   come/VERB
#   every/DET
#   (NOUN_PHRASE man/NOUN ghost/NOUN)
#   returned/VERB
#   spirit/ADV
#   within/ADP
#   (NOUN_PHRASE walk/NOUN)
#   abroad/ADV
#   among/ADP
#   (NOUN_PHRASE travel/NOUN)
#   far/ADV
#   (NOUN_PHRASE wide/ADJ spirit/NOUN)
#   goes/VERB
#   (NOUN_PHRASE forth/ADJ life/NOUN death/NOUN world/NOUN oh/NOUN)
#   might/VERB
#   shared/VERB
#   (NOUN_PHRASE earth/NOUN)
#   turned/VERB
#   (NOUN_PHRASE happiness/ADJ spectre/NOUN)
#   raised/VERB
#   (NOUN_PHRASE
#     cry/NOUN
#     shook/NOUN
#     chain/NOUN
#     shadowy/NOUN
#     hands/NOUN)
#   said/VERB
#   scrooge/ADJ
#   trembling/VERB
#   (NOUN_PHRASE tell/NOUN wear/NOUN chain/NOUN life/NOUN)
#   replied/VERB
#   (NOUN_PHRASE ghost/NOUN)
#   made/VERB
#   (NOUN_PHRASE link/NOUN)
#   link/VERB
#   yard/ADV
#   yard/ADV
#   girded/VERB
#   (NOUN_PHRASE free/ADJ free/ADJ wore/NOUN)
#   (NOUN_PHRASE strange/ADJ scrooge/NOUN)
#   trembled/VERB
#   would/VERB
#   know/VERB
#   pursued/VERB
#   ghost/ADV
#   (NOUN_PHRASE weight/ADJ length/NOUN)
#   (NOUN_PHRASE strong/ADJ bear/NOUN)
#   full/ADJ
#   heavy/ADJ
#   long/ADV
#   seven/NUM
#   (NOUN_PHRASE christmas/NOUN)
#   ago/ADV
#   since/ADP
#   (NOUN_PHRASE chain/NOUN scrooge/NOUN)
#   glanced/VERB
#   (NOUN_PHRASE floor/NOUN expectation/NOUN)
#   finding/VERB
#   surrounded/VERB
#   (NOUN_PHRASE fifty/ADJ iron/NOUN)
#   could/VERB
#   see/VERB
#   (NOUN_PHRASE nothing/NOUN jacob/NOUN)
#   said/VERB
#   (NOUN_PHRASE old/ADJ jacob/NOUN marley/NOUN)
#   tell/VERB
#   speak/VERB
#   (NOUN_PHRASE comfort/NOUN jacob/NOUN none/NOUN)
#   give/VERB
#   (NOUN_PHRASE ghost/NOUN)
#   replied/VERB
#   comes/VERB
#   ebenezer/ADV
#   (NOUN_PHRASE scrooge/ADJ conveyed/ADJ kinds/NOUN men/NOUN)
#   tell/VERB
#   would/VERB
#   little/VERB
#   (NOUN_PHRASE rest/ADJ stay/NOUN)
#   spirit/ADV
#   never/ADV
#   walked/VERB
#   beyond/ADP
#   (NOUN_PHRASE mark/NOUN life/NOUN spirit/NOUN)
#   never/ADV
#   beyond/ADP
#   (NOUN_PHRASE narrow/ADJ hole/ADJ journeys/NOUN)
#   lie/VERB
#   (NOUN_PHRASE habit/NOUN)
#   scrooge/ADJ
#   whenever/ADV
#   became/VERB
#   (NOUN_PHRASE
#     thoughtful/ADJ
#     put/NOUN
#     hands/NOUN
#     pockets/NOUN
#     ghost/NOUN)
#   said/VERB
#   without/ADP
#   lifting/VERB
#   (NOUN_PHRASE eyes/NOUN)
#   getting/VERB
#   (NOUN_PHRASE knees/NOUN)
#   must/VERB
#   slow/VERB
#   (NOUN_PHRASE jacob/NOUN scrooge/NOUN)
#   observed/VERB
#   manner/ADV
#   though/ADP
#   (NOUN_PHRASE humility/NOUN)
#   slow/VERB
#   (NOUN_PHRASE ghost/NOUN)
#   repeated/VERB
#   seven/NUM
#   (NOUN_PHRASE years/NOUN)
#   dead/ADJ
#   scrooge/ADV
#   travelling/VERB
#   (NOUN_PHRASE time/NOUN)
#   (NOUN_PHRASE whole/ADJ time/NOUN)
#   said/VERB
#   (NOUN_PHRASE ghost/NOUN rest/NOUN)
#   (NOUN_PHRASE incessant/ADJ torture/NOUN travel/NOUN fast/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ wind/NOUN)
#   replied/VERB
#   (NOUN_PHRASE ghost/NOUN)
#   might/VERB
#   got/VERB
#   (NOUN_PHRASE great/ADJ quantity/NOUN ground/NOUN)
#   seven/NUM
#   (NOUN_PHRASE years/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ ghost/NOUN hearing/NOUN)
#   set/VERB
#   another/DET
#   (NOUN_PHRASE cry/NOUN chain/NOUN)
#   (NOUN_PHRASE dead/ADJ silence/NOUN night/NOUN)
#   would/VERB
#   justified/VERB
#   oh/X
#   (NOUN_PHRASE bound/NOUN)
#   cried/VERB
#   (NOUN_PHRASE phantom/NOUN)
#   know/VERB
#   (NOUN_PHRASE incessant/ADJ labour/ADJ immortal/NOUN creatures/NOUN)
#   earth/ADJ
#   must/VERB
#   good/VERB
#   know/VERB
#   (NOUN_PHRASE christian/ADJ spirit/NOUN)
#   working/VERB
#   kindly/ADV
#   little/ADJ
#   whatever/DET
#   may/VERB
#   find/VERB
#   (NOUN_PHRASE mortal/ADJ life/NOUN)
#   (NOUN_PHRASE short/ADJ vast/ADJ means/NOUN)
#   know/VERB
#   (NOUN_PHRASE space/NOUN regret/NOUN)
#   make/VERB
#   amends/VERB
#   one/NUM
#   (NOUN_PHRASE life/NOUN opportunities/NOUN)
#   yet/ADV
#   oh/ADJ
#   always/ADV
#   (NOUN_PHRASE good/ADJ man/NOUN business/NOUN jacob/NOUN)
#   faultered/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   began/VERB
#   apply/ADV
#   (NOUN_PHRASE business/NOUN)
#   cried/VERB
#   (NOUN_PHRASE ghost/NOUN hands/NOUN business/NOUN)
#   (NOUN_PHRASE
#     common/ADJ
#     welfare/NOUN
#     business/NOUN
#     mercy/NOUN
#     benevolence/NOUN
#     business/NOUN
#     trade/NOUN
#     drop/NOUN
#     water/NOUN)
#   (NOUN_PHRASE comprehensive/ADJ business/NOUN)
#   held/VERB
#   (NOUN_PHRASE chain/NOUN arm/NOUN length/NOUN cause/NOUN grief/NOUN)
#   heavily/ADV
#   upon/ADP
#   (NOUN_PHRASE ground/NOUN time/NOUN)
#   rolling/VERB
#   (NOUN_PHRASE year/NOUN spectre/NOUN)
#   said/VERB
#   (NOUN_PHRASE suffer/NOUN walk/NOUN eyes/NOUN)
#   turned/VERB
#   never/ADV
#   (NOUN_PHRASE raise/NOUN)
#   blessed/VERB
#   (NOUN_PHRASE led/ADJ wise/NOUN men/NOUN)
#   (NOUN_PHRASE poor/ADJ poor/ADJ homes/NOUN)
#   light/VERB
#   would/VERB
#   conducted/VERB
#   scrooge/ADV
#   (NOUN_PHRASE much/ADJ hear/NOUN spectre/NOUN)
#   going/VERB
#   (NOUN_PHRASE rate/NOUN)
#   began/VERB
#   exceedingly/ADV
#   hear/ADJ
#   cried/VERB
#   (NOUN_PHRASE ghost/NOUN time/NOUN)
#   nearly/ADV
#   gone/VERB
#   said/VERB
#   scrooge/ADJ
#   hard/ADJ
#   upon/ADP
#   (NOUN_PHRASE jacob/NOUN pray/NOUN shape/NOUN)
#   see/VERB
#   may/VERB
#   tell/VERB
#   sat/VERB
#   invisible/ADJ
#   beside/ADV
#   (NOUN_PHRASE
#     many/ADJ
#     many/ADJ
#     day/NOUN
#     idea/NOUN
#     scrooge/NOUN
#     brow/NOUN)
#   (NOUN_PHRASE light/ADJ part/NOUN)
#   pursued/VERB
#   (NOUN_PHRASE ghost/NOUN)
#   yet/ADV
#   (NOUN_PHRASE chance/NOUN hope/NOUN)
#   fate/VERB
#   (NOUN_PHRASE chance/NOUN hope/NOUN ebenezer/NOUN)
#   always/ADV
#   (NOUN_PHRASE good/ADJ friend/NOUN)
#   said/VERB
#   scrooge/ADV
#   haunted/VERB
#   resumed/VERB
#   (NOUN_PHRASE ghost/NOUN)
#   three/NUM
#   (NOUN_PHRASE spirits/NOUN)
#   scrooge/VERB
#   fell/VERB
#   almost/ADV
#   (NOUN_PHRASE low/ADJ ghost/NOUN)
#   done/VERB
#   (NOUN_PHRASE chance/NOUN hope/NOUN)
#   mentioned/VERB
#   (NOUN_PHRASE jacob/NOUN)
#   demanded/VERB
#   (NOUN_PHRASE voice/NOUN think/NOUN)
#   rather/ADV
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   without/ADP
#   said/VERB
#   (NOUN_PHRASE ghost/NOUN)
#   hope/VERB
#   (NOUN_PHRASE path/NOUN)
#   expect/VERB
#   first/ADV
#   bell/VERB
#   one/NUM
#   could/VERB
#   take/VERB
#   (NOUN_PHRASE jacob/NOUN)
#   hinted/VERB
#   scrooge/ADJ
#   expect/VERB
#   (NOUN_PHRASE second/ADJ next/ADJ night/NOUN hour/NOUN)
#   third/ADJ
#   upon/ADP
#   (NOUN_PHRASE next/ADJ night/NOUN)
#   (NOUN_PHRASE last/ADJ stroke/NOUN twelve/NOUN)
#   ceased/VERB
#   (NOUN_PHRASE vibrate/ADJ look/NOUN)
#   see/VERB
#   look/VERB
#   (NOUN_PHRASE sake/ADJ remember/NOUN)
#   passed/VERB
#   us/PRON
#   said/VERB
#   (NOUN_PHRASE words/NOUN)
#   spectre/ADJ
#   took/VERB
#   wrapper/ADV
#   (NOUN_PHRASE table/ADJ bound/NOUN round/NOUN head/NOUN)
#   scrooge/VERB
#   (NOUN_PHRASE knew/ADJ smart/ADJ sound/NOUN teeth/NOUN)
#   made/VERB
#   brought/PRT
#   together/ADV
#   (NOUN_PHRASE bandage/NOUN)
#   raise/VERB
#   (NOUN_PHRASE eyes/NOUN)
#   found/VERB
#   (NOUN_PHRASE
#     supernatural/ADJ
#     visitor/NOUN
#     attitude/NOUN
#     chain/NOUN)
#   wound/ADP
#   (NOUN_PHRASE arm/ADJ apparition/NOUN)
#   walked/VERB
#   every/DET
#   (NOUN_PHRASE step/NOUN)
#   took/VERB
#   window/PRON
#   raised/VERB
#   (NOUN_PHRASE little/ADJ spectre/NOUN)
#   reached/VERB
#   (NOUN_PHRASE wide/ADJ open/ADJ scrooge/NOUN approach/NOUN)
#   within/ADP
#   two/NUM
#   (NOUN_PHRASE marley/NOUN)
#   ghost/VERB
#   (NOUN_PHRASE held/ADJ hand/NOUN)
#   warning/VERB
#   (NOUN_PHRASE come/ADJ nearer/NOUN scrooge/NOUN)
#   stopped/VERB
#   (NOUN_PHRASE much/ADJ obedience/NOUN surprise/NOUN fear/NOUN)
#   raising/VERB
#   (NOUN_PHRASE hand/NOUN)
#   became/VERB
#   (NOUN_PHRASE sensible/ADJ air/NOUN)
#   sounds/VERB
#   regret/ADJ
#   inexpressibly/ADV
#   (NOUN_PHRASE sorrowful/ADJ spectre/NOUN)
#   listening/VERB
#   (NOUN_PHRASE moment/NOUN)
#   joined/VERB
#   mournful/ADJ
#   floated/VERB
#   upon/ADP
#   (NOUN_PHRASE bleak/ADJ dark/ADJ night/NOUN scrooge/NOUN)
#   followed/VERB
#   (NOUN_PHRASE window/NOUN)
#   looked/VERB
#   (NOUN_PHRASE air/NOUN)
#   filled/VERB
#   (NOUN_PHRASE phantoms/NOUN)
#   wandering/VERB
#   (NOUN_PHRASE restless/NOUN)
#   moaning/VERB
#   went/VERB
#   every/DET
#   one/NUM
#   (NOUN_PHRASE wore/NOUN chains/NOUN)
#   like/ADP
#   (NOUN_PHRASE marley/NOUN ghost/NOUN)
#   might/VERB
#   together/VERB
#   (NOUN_PHRASE none/NOUN)
#   free/ADJ
#   many/ADJ
#   known/VERB
#   (NOUN_PHRASE scrooge/ADJ lives/NOUN)
#   quite/ADV
#   familiar/ADJ
#   one/NUM
#   (NOUN_PHRASE old/ADJ ghost/NOUN)
#   (NOUN_PHRASE white/ADJ waistcoat/NOUN)
#   (NOUN_PHRASE monstrous/ADJ iron/NOUN)
#   attached/VERB
#   (NOUN_PHRASE cried/ADJ assist/NOUN)
#   wretched/VERB
#   (NOUN_PHRASE woman/NOUN)
#   saw/VERB
#   upon/ADP
#   (NOUN_PHRASE misery/NOUN)
#   clearly/ADV
#   sought/VERB
#   interfere/ADV
#   (NOUN_PHRASE good/ADJ human/NOUN matters/NOUN)
#   lost/VERB
#   (NOUN_PHRASE power/NOUN)
#   ever/ADV
#   whether/ADP
#   (NOUN_PHRASE creatures/NOUN)
#   faded/VERB
#   (NOUN_PHRASE mist/ADJ mist/NOUN)
#   could/VERB
#   tell/VERB
#   (NOUN_PHRASE spirit/ADJ voices/NOUN)
#   faded/VERB
#   together/ADV
#   (NOUN_PHRASE night/NOUN)
#   became/VERB
#   walked/VERB
#   (NOUN_PHRASE home/NOUN scrooge/NOUN)
#   closed/VERB
#   (NOUN_PHRASE window/NOUN)
#   examined/VERB
#   (NOUN_PHRASE door/NOUN ghost/NOUN)
#   entered/VERB
#   (NOUN_PHRASE locked/ADJ hands/NOUN)
#   undisturbed/ADJ
#   tried/VERB
#   (NOUN_PHRASE say/NOUN)
#   stopped/VERB
#   (NOUN_PHRASE first/ADJ emotion/NOUN)
#   (NOUN_PHRASE undergone/ADJ day/NOUN)
#   (NOUN_PHRASE invisible/ADJ world/NOUN dull/NOUN conversation/NOUN)
#   ghost/X
#   (NOUN_PHRASE hour/NOUN)
#   much/ADV
#   need/VERB
#   went/VERB
#   (NOUN_PHRASE straight/ADJ bed/NOUN)
#   without/ADP
#   fell/VERB
#   asleep/ADV
#   upon/ADP
#   (NOUN_PHRASE instant/NOUN stave/NOUN)
#   first/ADV
#   three/NUM
#   (NOUN_PHRASE spirits/NOUN)
#   scrooge/VERB
#   (NOUN_PHRASE awoke/NOUN dark/NOUN)
#   looking/VERB
#   (NOUN_PHRASE bed/NOUN)
#   could/VERB
#   scarcely/ADV
#   transparent/VERB
#   (NOUN_PHRASE window/NOUN walls/NOUN)
#   chamber/VERB
#   endeavouring/VERB
#   (NOUN_PHRASE darkness/NOUN eyes/NOUN chimes/NOUN)
#   neighbouring/VERB
#   (NOUN_PHRASE church/NOUN)
#   struck/VERB
#   four/NUM
#   (NOUN_PHRASE quarters/NOUN)
#   listened/VERB
#   (NOUN_PHRASE hour/NOUN)
#   (NOUN_PHRASE great/ADJ astonishment/ADJ heavy/NOUN bell/NOUN)
#   went/VERB
#   six/NUM
#   seven/NUM
#   seven/NUM
#   eight/NUM
#   (NOUN_PHRASE twelve/NOUN)
#   stopped/VERB
#   twelve/VERB
#   past/ADJ
#   two/NUM
#   went/VERB
#   (NOUN_PHRASE bed/NOUN clock/NOUN)
#   wrong/ADJ
#   must/VERB
#   got/VERB
#   twelve/ADV
#   touched/VERB
#   (NOUN_PHRASE spring/NOUN correct/NOUN clock/NOUN)
#   (NOUN_PHRASE rapid/ADJ little/ADJ pulse/ADJ beat/NOUN twelve/NOUN)
#   stopped/VERB
#   possible/ADJ
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ whole/ADJ day/NOUN)
#   far/ADV
#   another/DET
#   (NOUN_PHRASE night/NOUN)
#   (NOUN_PHRASE possible/ADJ anything/NOUN)
#   happened/VERB
#   (NOUN_PHRASE sun/ADJ twelve/NOUN idea/NOUN)
#   alarming/VERB
#   one/NUM
#   scrambled/VERB
#   (NOUN_PHRASE bed/NOUN way/NOUN window/NOUN)
#   obliged/VERB
#   (NOUN_PHRASE frost/NOUN)
#   could/VERB
#   see/VERB
#   (NOUN_PHRASE anything/NOUN)
#   could/VERB
#   see/VERB
#   little/ADJ
#   could/VERB
#   make/VERB
#   still/ADV
#   foggy/VERB
#   extremely/ADV
#   (NOUN_PHRASE cold/ADJ noise/NOUN people/NOUN)
#   running/VERB
#   fro/ADJ
#   making/VERB
#   great/ADJ
#   unquestionably/ADV
#   would/VERB
#   (NOUN_PHRASE night/NOUN)
#   (NOUN_PHRASE bright/ADJ day/NOUN)
#   taken/VERB
#   (NOUN_PHRASE possession/NOUN world/NOUN)
#   (NOUN_PHRASE great/ADJ relief/NOUN)
#   three/NUM
#   (NOUN_PHRASE days/NOUN)
#   sight/VERB
#   (NOUN_PHRASE first/ADJ pay/NOUN ebenezer/NOUN)
#   (NOUN_PHRASE scrooge/ADJ order/NOUN forth/NOUN)
#   would/VERB
#   become/VERB
#   (NOUN_PHRASE mere/ADJ days/NOUN count/NOUN)
#   scrooge/ADJ
#   went/VERB
#   (NOUN_PHRASE bed/ADJ thought/NOUN)
#   thought/VERB
#   thought/VERB
#   could/VERB
#   make/VERB
#   (NOUN_PHRASE nothing/NOUN thought/NOUN)
#   endeavoured/VERB
#   think/VERB
#   thought/VERB
#   marley/ADV
#   (NOUN_PHRASE ghost/NOUN)
#   exceedingly/ADV
#   every/DET
#   (NOUN_PHRASE time/NOUN)
#   resolved/VERB
#   within/ADP
#   (NOUN_PHRASE dream/NOUN mind/NOUN)
#   flew/VERB
#   back/ADV
#   like/ADP
#   (NOUN_PHRASE strong/ADJ spring/NOUN)
#   released/VERB
#   first/ADV
#   presented/VERB
#   (NOUN_PHRASE worked/ADJ dream/NOUN scrooge/NOUN)
#   lay/VERB
#   (NOUN_PHRASE state/NOUN chimes/NOUN)
#   gone/VERB
#   three/NUM
#   (NOUN_PHRASE quarters/NOUN)
#   remembered/VERB
#   (NOUN_PHRASE sudden/ADJ ghost/NOUN bell/NOUN)
#   one/NUM
#   resolved/VERB
#   lie/ADV
#   (NOUN_PHRASE hour/NOUN past/NOUN)
#   could/VERB
#   go/VERB
#   sleep/ADJ
#   go/VERB
#   heaven/ADV
#   perhaps/ADV
#   (NOUN_PHRASE power/NOUN quarter/NOUN)
#   long/ADV
#   convinced/ADJ
#   must/VERB
#   unconsciously/ADV
#   missed/VERB
#   (NOUN_PHRASE clock/NOUN length/NOUN)
#   broke/VERB
#   upon/ADP
#   listening/VERB
#   ear/ADJ
#   ding/VERB
#   (NOUN_PHRASE dong/ADJ quarter/NOUN past/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   ding/VERB
#   (NOUN_PHRASE dong/ADJ half/NOUN past/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   ding/VERB
#   (NOUN_PHRASE dong/ADJ quarter/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ ding/NOUN)
#   (NOUN_PHRASE dong/ADJ hour/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ nothing/NOUN)
#   else/ADV
#   spoke/VERB
#   (NOUN_PHRASE hour/NOUN bell/NOUN)
#   sounded/VERB
#   (NOUN_PHRASE deep/ADJ dull/NOUN hollow/NOUN)
#   melancholy/VERB
#   one/NUM
#   (NOUN_PHRASE light/NOUN room/NOUN)
#   upon/ADP
#   (NOUN_PHRASE instant/ADJ curtains/NOUN)
#   bed/VERB
#   (NOUN_PHRASE drawn/NOUN curtains/NOUN)
#   bed/VERB
#   drawn/ADJ
#   aside/ADV
#   tell/VERB
#   (NOUN_PHRASE hand/NOUN curtains/NOUN feet/NOUN curtains/NOUN)
#   back/ADV
#   face/VERB
#   (NOUN_PHRASE addressed/ADJ curtains/NOUN)
#   bed/VERB
#   drawn/VERB
#   aside/ADV
#   scrooge/ADJ
#   starting/VERB
#   (NOUN_PHRASE attitude/NOUN)
#   found/VERB
#   (NOUN_PHRASE face/NOUN face/NOUN visitor/NOUN)
#   drew/VERB
#   close/ADJ
#   standing/VERB
#   (NOUN_PHRASE spirit/NOUN)
#   (NOUN_PHRASE elbow/ADJ strange/ADJ figure/NOUN)
#   like/ADP
#   (NOUN_PHRASE child/NOUN)
#   yet/ADV
#   (NOUN_PHRASE like/ADJ child/NOUN)
#   like/ADP
#   (NOUN_PHRASE old/ADJ man/NOUN)
#   viewed/VERB
#   supernatural/ADJ
#   gave/VERB
#   (NOUN_PHRASE appearance/NOUN view/NOUN)
#   child/VERB
#   (NOUN_PHRASE hair/NOUN hung/NOUN neck/NOUN)
#   back/ADV
#   (NOUN_PHRASE white/ADJ age/NOUN)
#   yet/ADV
#   face/VERB
#   (NOUN_PHRASE wrinkle/ADJ arms/NOUN)
#   (NOUN_PHRASE long/ADJ hands/NOUN)
#   hold/VERB
#   (NOUN_PHRASE uncommon/ADJ legs/ADJ feet/NOUN)
#   like/ADP
#   (NOUN_PHRASE upper/ADJ members/NOUN)
#   bare/VERB
#   wore/ADP
#   (NOUN_PHRASE white/ADJ round/NOUN waist/NOUN)
#   bound/ADP
#   (NOUN_PHRASE belt/NOUN)
#   beautiful/ADJ
#   held/VERB
#   fresh/ADJ
#   green/ADJ
#   holly/ADV
#   (NOUN_PHRASE hand/NOUN wintry/NOUN dress/NOUN)
#   trimmed/VERB
#   (NOUN_PHRASE summer/NOUN)
#   (NOUN_PHRASE strangest/ADJ thing/NOUN head/NOUN)
#   bright/VERB
#   (NOUN_PHRASE clear/ADJ light/NOUN)
#   (NOUN_PHRASE visible/ADJ occasion/NOUN)
#   using/VERB
#   (NOUN_PHRASE moments/NOUN)
#   (NOUN_PHRASE great/ADJ extinguisher/ADJ cap/NOUN)
#   held/VERB
#   arm/ADJ
#   even/ADV
#   though/ADP
#   (NOUN_PHRASE scrooge/NOUN)
#   looked/VERB
#   (NOUN_PHRASE steadiness/ADJ strangest/ADJ quality/NOUN belt/NOUN)
#   sparkled/VERB
#   one/NUM
#   (NOUN_PHRASE part/NOUN)
#   another/DET
#   light/ADJ
#   one/NUM
#   (NOUN_PHRASE instant/NOUN)
#   another/DET
#   (NOUN_PHRASE time/NOUN)
#   (NOUN_PHRASE dark/ADJ figure/NOUN thing/NOUN)
#   one/NUM
#   (NOUN_PHRASE arm/NOUN)
#   one/NUM
#   (NOUN_PHRASE twenty/NOUN)
#   legs/VERB
#   (NOUN_PHRASE pair/NOUN legs/NOUN)
#   without/ADP
#   (NOUN_PHRASE head/NOUN head/NOUN)
#   without/ADP
#   (NOUN_PHRASE body/NOUN)
#   would/VERB
#   visible/VERB
#   (NOUN_PHRASE dense/ADJ gloom/NOUN)
#   melted/VERB
#   away/ADV
#   wonder/ADJ
#   would/VERB
#   distinct/VERB
#   clear/ADJ
#   ever/ADV
#   (NOUN_PHRASE spirit/ADJ sir/NOUN)
#   whose/PRON
#   coming/VERB
#   asked/VERB
#   (NOUN_PHRASE scrooge/ADJ voice/NOUN)
#   gentle/ADV
#   low/ADJ
#   instead/ADV
#   (NOUN_PHRASE close/ADJ beside/ADJ distance/NOUN scrooge/NOUN)
#   demanded/VERB
#   (NOUN_PHRASE ghost/NOUN christmas/NOUN)
#   past/ADP
#   (NOUN_PHRASE long/ADJ past/NOUN)
#   inquired/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   past/ADP
#   perhaps/ADV
#   (NOUN_PHRASE scrooge/NOUN)
#   could/VERB
#   told/VERB
#   (NOUN_PHRASE anybody/NOUN anybody/NOUN)
#   could/VERB
#   asked/VERB
#   (NOUN_PHRASE desire/NOUN see/NOUN)
#   (NOUN_PHRASE spirit/ADJ cap/NOUN)
#   begged/VERB
#   covered/VERB
#   (NOUN_PHRASE exclaimed/ADJ ghost/NOUN)
#   would/VERB
#   soon/ADV
#   put/VERB
#   worldly/ADV
#   (NOUN_PHRASE hands/NOUN)
#   light/ADJ
#   give/VERB
#   enough/ADJ
#   one/NUM
#   whose/PRON
#   made/VERB
#   (NOUN_PHRASE cap/NOUN force/NOUN)
#   (NOUN_PHRASE whole/ADJ years/NOUN)
#   wear/VERB
#   low/ADJ
#   upon/ADP
#   (NOUN_PHRASE brow/NOUN scrooge/NOUN)
#   reverently/ADV
#   knowledge/VERB
#   (NOUN_PHRASE spirit/NOUN period/NOUN life/NOUN)
#   made/VERB
#   (NOUN_PHRASE bold/ADJ business/NOUN)
#   brought/VERB
#   (NOUN_PHRASE welfare/NOUN)
#   said/VERB
#   (NOUN_PHRASE ghost/NOUN scrooge/NOUN)
#   expressed/VERB
#   much/ADV
#   obliged/VERB
#   could/VERB
#   help/VERB
#   thinking/VERB
# ...
#   three/NUM
#   shall/VERB
#   strive/VERB
#   within/ADP
#   (NOUN_PHRASE shut/ADJ teach/NOUN)
#   oh/PRON
#   tell/VERB
#   may/VERB
#   away/ADV
#   writing/VERB
#   (NOUN_PHRASE stone/NOUN)
#   caught/VERB
#   (NOUN_PHRASE spectral/ADJ hand/NOUN)
#   sought/VERB
#   (NOUN_PHRASE free/ADJ strong/ADJ entreaty/NOUN spirit/NOUN)
#   yet/ADV
#   holding/VERB
#   hands/VERB
#   one/NUM
#   (NOUN_PHRASE last/ADJ fate/NOUN)
#   saw/VERB
#   (NOUN_PHRASE
#     alteration/NOUN
#     phantom/NOUN
#     dress/NOUN
#     shrunk/NOUN
#     bedpost/NOUN)
#   (NOUN_PHRASE stave/ADJ end/NOUN)
#   yes/VERB
#   bedpost/ADV
#   (NOUN_PHRASE bed/ADJ room/NOUN)
#   (NOUN_PHRASE best/ADJ time/NOUN)
#   make/VERB
#   (NOUN_PHRASE amends/NOUN)
#   (NOUN_PHRASE
#     live/ADJ
#     past/ADJ
#     present/ADJ
#     future/NOUN
#     scrooge/NOUN)
#   repeated/VERB
#   (NOUN_PHRASE scrambled/ADJ bed/NOUN spirits/NOUN)
#   three/NUM
#   shall/VERB
#   strive/VERB
#   within/ADP
#   (NOUN_PHRASE oh/ADJ jacob/NOUN marley/NOUN)
#   heaven/ADV
#   (NOUN_PHRASE christmas/ADJ time/NOUN)
#   praised/VERB
#   say/VERB
#   (NOUN_PHRASE knees/NOUN)
#   (NOUN_PHRASE old/ADJ jacob/NOUN knees/NOUN)
#   glowing/VERB
#   (NOUN_PHRASE good/ADJ broken/ADJ voice/NOUN)
#   would/VERB
#   scarcely/ADV
#   answer/VERB
#   (NOUN_PHRASE call/NOUN spirit/NOUN face/NOUN)
#   wet/VERB
#   (NOUN_PHRASE tears/NOUN)
#   torn/ADJ
#   cried/VERB
#   scrooge/ADJ
#   one/NUM
#   (NOUN_PHRASE arms/NOUN)
#   (NOUN_PHRASE torn/ADJ rings/NOUN)
#   shadows/VERB
#   (NOUN_PHRASE things/NOUN)
#   would/VERB
#   may/VERB
#   dispelled/VERB
#   know/VERB
#   (NOUN_PHRASE hands/NOUN)
#   (NOUN_PHRASE busy/ADJ garments/NOUN time/NOUN)
#   turning/VERB
#   inside/ADV
#   putting/VERB
#   tearing/VERB
#   making/VERB
#   (NOUN_PHRASE parties/NOUN)
#   every/DET
#   (NOUN_PHRASE kind/NOUN)
#   know/VERB
#   cried/VERB
#   scrooge/ADJ
#   laughing/VERB
#   crying/VERB
#   (NOUN_PHRASE breath/NOUN)
#   making/VERB
#   (NOUN_PHRASE perfect/ADJ light/NOUN)
#   (NOUN_PHRASE happy/ADJ merry/NOUN)
#   drunken/VERB
#   (NOUN_PHRASE man/NOUN merry/NOUN)
#   christmas/VERB
#   (NOUN_PHRASE everybody/NOUN)
#   (NOUN_PHRASE
#     happy/ADJ
#     new/ADJ
#     year/NOUN
#     world/NOUN
#     hallo/NOUN
#     whoop/NOUN
#     hallo/NOUN)
#   standing/VERB
#   perfectly/ADV
#   saucepan/VERB
#   (NOUN_PHRASE gruel/NOUN)
#   cried/VERB
#   scrooge/ADJ
#   starting/VERB
#   (NOUN_PHRASE
#     round/NOUN
#     door/NOUN
#     ghost/NOUN
#     jacob/NOUN
#     marley/NOUN)
#   entered/VERB
#   (NOUN_PHRASE corner/ADJ ghost/NOUN)
#   (NOUN_PHRASE christmas/ADJ present/ADJ sat/NOUN window/NOUN)
#   saw/VERB
#   wandering/VERB
#   (NOUN_PHRASE spirits/NOUN)
#   right/ADV
#   true/ADJ
#   happened/VERB
#   (NOUN_PHRASE ha/ADJ ha/NOUN ha/NOUN)
#   really/ADV
#   (NOUN_PHRASE man/NOUN)
#   (NOUN_PHRASE many/ADJ years/NOUN)
#   splendid/VERB
#   laugh/ADP
#   laugh/ADP
#   (NOUN_PHRASE father/NOUN)
#   long/ADV
#   long/ADV
#   (NOUN_PHRASE line/NOUN)
#   know/VERB
#   (NOUN_PHRASE day/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   know/VERB
#   long/ADV
#   among/ADP
#   (NOUN_PHRASE spirits/NOUN)
#   know/VERB
#   (NOUN_PHRASE anything/NOUN)
#   quite/ADV
#   baby/ADJ
#   never/ADV
#   mind/VERB
#   (NOUN_PHRASE care/NOUN)
#   rather/ADV
#   (NOUN_PHRASE baby/NOUN)
#   hallo/VERB
#   (NOUN_PHRASE whoop/ADJ hallo/NOUN)
#   ringing/VERB
#   ever/ADV
#   heard/VERB
#   (NOUN_PHRASE clash/NOUN clang/NOUN hammer/NOUN)
#   ding/VERB
#   dong/ADV
#   bell/ADV
#   bell/VERB
#   dong/ADV
#   ding/VERB
#   (NOUN_PHRASE hammer/NOUN clang/NOUN clash/NOUN)
#   oh/ADV
#   glorious/ADJ
#   glorious/ADJ
#   running/VERB
#   (NOUN_PHRASE window/NOUN)
#   opened/VERB
#   put/VERB
#   (NOUN_PHRASE head/NOUN fog/NOUN mist/NOUN)
#   (NOUN_PHRASE clear/ADJ bright/ADJ jovial/NOUN cold/NOUN)
#   (NOUN_PHRASE cold/ADJ blood/NOUN dance/NOUN)
#   (NOUN_PHRASE golden/ADJ sky/NOUN)
#   (NOUN_PHRASE fresh/ADJ air/NOUN merry/NOUN)
#   bells/VERB
#   oh/ADV
#   glorious/ADJ
#   glorious/ADJ
#   cried/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   calling/VERB
#   (NOUN_PHRASE downward/ADJ boy/NOUN sunday/NOUN clothes/NOUN)
#   perhaps/ADV
#   look/VERB
#   eh/ADJ
#   returned/VERB
#   (NOUN_PHRASE boy/NOUN)
#   might/VERB
#   wonder/VERB
#   (NOUN_PHRASE fine/ADJ fellow/NOUN)
#   said/VERB
#   scrooge/ADJ
#   replied/VERB
#   (NOUN_PHRASE boy/ADJ christmas/NOUN day/NOUN)
#   christmas/VERB
#   (NOUN_PHRASE day/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   missed/VERB
#   (NOUN_PHRASE spirits/NOUN)
#   done/VERB
#   one/NUM
#   (NOUN_PHRASE night/NOUN anything/NOUN)
#   like/ADP
#   (NOUN_PHRASE course/NOUN course/NOUN)
#   (NOUN_PHRASE hallo/ADJ fine/ADJ fellow/NOUN hallo/NOUN)
#   returned/VERB
#   boy/ADV
#   (NOUN_PHRASE know/ADJ poulterer/NOUN)
#   (NOUN_PHRASE next/ADJ street/NOUN)
#   one/NUM
#   (NOUN_PHRASE corner/NOUN scrooge/NOUN)
#   inquired/VERB
#   (NOUN_PHRASE hope/NOUN)
#   replied/VERB
#   (NOUN_PHRASE boy/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ remarkable/ADJ boy/NOUN)
#   know/VERB
#   whether/ADP
#   (NOUN_PHRASE prize/NOUN turkey/NOUN)
#   hanging/VERB
#   (NOUN_PHRASE little/ADJ prize/ADJ turkey/NOUN)
#   big/ADJ
#   one/NUM
#   one/NUM
#   big/ADJ
#   returned/VERB
#   (NOUN_PHRASE boy/ADJ delightful/ADJ boy/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ pleasure/NOUN)
#   talk/VERB
#   yes/ADP
#   hanging/VERB
#   replied/VERB
#   (NOUN_PHRASE boy/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   go/VERB
#   (NOUN_PHRASE buy/NOUN)
#   exclaimed/VERB
#   (NOUN_PHRASE boy/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ earnest/NOUN)
#   go/VERB
#   buy/VERB
#   tell/ADP
#   (NOUN_PHRASE bring/NOUN)
#   may/VERB
#   give/VERB
#   (NOUN_PHRASE direction/NOUN)
#   take/VERB
#   come/VERB
#   back/ADV
#   (NOUN_PHRASE man/NOUN)
#   give/VERB
#   come/VERB
#   back/ADV
#   less/ADV
#   five/NUM
#   (NOUN_PHRASE minutes/NOUN)
#   give/VERB
#   (NOUN_PHRASE boy/NOUN)
#   like/ADP
#   (NOUN_PHRASE shot/NOUN)
#   must/VERB
#   steady/VERB
#   (NOUN_PHRASE hand/NOUN)
#   could/VERB
#   got/VERB
#   (NOUN_PHRASE shot/ADJ half/NOUN)
#   (NOUN_PHRASE fast/ADJ bob/NOUN cratchit/NOUN)
#   whispered/VERB
#   (NOUN_PHRASE scrooge/ADJ hands/NOUN)
#   splitting/VERB
#   (NOUN_PHRASE laugh/NOUN)
#   know/VERB
#   twice/ADV
#   (NOUN_PHRASE size/NOUN)
#   (NOUN_PHRASE tiny/ADJ tim/NOUN joe/NOUN)
#   never/ADV
#   made/VERB
#   (NOUN_PHRASE joke/NOUN)
#   sending/VERB
#   (NOUN_PHRASE bob/ADJ hand/NOUN)
#   steady/ADJ
#   one/NUM
#   (NOUN_PHRASE somehow/NOUN)
#   went/VERB
#   (NOUN_PHRASE stairs/NOUN)
#   (NOUN_PHRASE open/ADJ street/NOUN)
#   door/ADJ
#   ready/ADJ
#   coming/VERB
#   (NOUN_PHRASE poulterer/NOUN man/NOUN)
#   stood/VERB
#   (NOUN_PHRASE knocker/ADJ caught/NOUN eye/NOUN)
#   shall/VERB
#   love/VERB
#   long/ADV
#   live/ADJ
#   cried/VERB
#   (NOUN_PHRASE scrooge/ADJ hand/NOUN)
#   scarcely/ADV
#   ever/ADV
#   looked/VERB
#   (NOUN_PHRASE honest/ADJ expression/NOUN face/NOUN)
#   (NOUN_PHRASE
#     wonderful/ADJ
#     knocker/NOUN
#     turkey/NOUN
#     hallo/NOUN
#     whoop/NOUN
#     merry/NOUN
#     christmas/NOUN
#     turkey/NOUN)
#   never/ADV
#   could/VERB
#   stood/VERB
#   upon/ADP
#   (NOUN_PHRASE legs/NOUN)
#   would/VERB
#   short/VERB
#   (NOUN_PHRASE minute/NOUN)
#   like/ADP
#   (NOUN_PHRASE sticks/NOUN)
#   impossible/ADJ
#   carry/VERB
#   (NOUN_PHRASE camden/ADJ town/NOUN)
#   said/VERB
#   scrooge/ADJ
#   must/VERB
#   cab/VERB
#   (NOUN_PHRASE chuckle/NOUN)
#   said/VERB
#   (NOUN_PHRASE chuckle/NOUN)
#   paid/VERB
#   (NOUN_PHRASE turkey/NOUN chuckle/NOUN)
#   paid/VERB
#   (NOUN_PHRASE cab/NOUN chuckle/NOUN boy/NOUN chuckle/NOUN)
#   sat/VERB
#   (NOUN_PHRASE breathless/ADJ chair/NOUN till/NOUN)
#   cried/VERB
#   shaving/VERB
#   (NOUN_PHRASE easy/ADJ hand/NOUN)
#   continued/VERB
#   shake/ADV
#   much/ADJ
#   shaving/VERB
#   (NOUN_PHRASE attention/NOUN)
#   even/ADV
#   dance/VERB
#   (NOUN_PHRASE cut/ADJ end/NOUN)
#   nose/ADV
#   would/VERB
#   put/VERB
#   piece/VERB
#   quite/ADV
#   satisfied/ADJ
#   dressed/VERB
#   best/ADJ
#   last/ADJ
#   got/VERB
#   (NOUN_PHRASE streets/NOUN people/NOUN time/NOUN)
#   pouring/VERB
#   (NOUN_PHRASE forth/NOUN)
#   seen/VERB
#   (NOUN_PHRASE ghost/NOUN christmas/NOUN)
#   (NOUN_PHRASE present/ADJ walking/NOUN hands/NOUN)
#   behind/ADP
#   (NOUN_PHRASE scrooge/NOUN)
#   regarded/VERB
#   every/DET
#   one/NUM
#   delighted/VERB
#   (NOUN_PHRASE smile/NOUN)
#   looked/VERB
#   irresistibly/ADV
#   (NOUN_PHRASE pleasant/ADJ word/NOUN)
#   three/NUM
#   four/NUM
#   (NOUN_PHRASE fellows/NOUN)
#   said/VERB
#   (NOUN_PHRASE
#     good/ADJ
#     morning/NOUN
#     sir/NOUN
#     merry/NOUN
#     christmas/NOUN
#     scrooge/NOUN)
#   said/VERB
#   often/ADV
#   afterwards/VERB
#   (NOUN_PHRASE blithe/ADJ sounds/NOUN)
#   ever/ADV
#   heard/VERB
#   (NOUN_PHRASE ears/NOUN)
#   gone/VERB
#   far/ADV
#   coming/VERB
#   (NOUN_PHRASE towards/NOUN)
#   beheld/VERB
#   portly/ADV
#   gentleman/ADJ
#   walked/VERB
#   (NOUN_PHRASE day/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ marley/NOUN)
#   believe/VERB
#   sent/VERB
#   across/ADP
#   (NOUN_PHRASE heart/NOUN)
#   think/VERB
#   (NOUN_PHRASE old/ADJ gentleman/NOUN)
#   would/VERB
#   look/VERB
#   upon/ADP
#   met/X
#   knew/X
#   (NOUN_PHRASE path/NOUN)
#   lay/VERB
#   straight/ADJ
#   took/VERB
#   (NOUN_PHRASE dear/ADJ sir/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   taking/VERB
#   old/ADJ
#   gentleman/ADJ
#   hands/VERB
#   (NOUN_PHRASE hope/NOUN)
#   succeeded/VERB
#   (NOUN_PHRASE
#     yesterday/NOUN
#     kind/NOUN
#     merry/NOUN
#     christmas/NOUN
#     sir/NOUN
#     mr/NOUN)
#   (NOUN_PHRASE scrooge/ADJ yes/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ name/NOUN fear/NOUN)
#   may/VERB
#   pleasant/VERB
#   allow/VERB
#   (NOUN_PHRASE ask/ADJ scrooge/NOUN)
#   whispered/VERB
#   (NOUN_PHRASE ear/ADJ lord/NOUN bless/NOUN)
#   cried/VERB
#   (NOUN_PHRASE gentleman/ADJ breath/NOUN)
#   gone/VERB
#   dear/ADJ
#   scrooge/ADV
#   (NOUN_PHRASE serious/ADJ please/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   less/CONJ
#   (NOUN_PHRASE great/ADJ many/ADJ assure/NOUN)
#   favour/VERB
#   (NOUN_PHRASE dear/NOUN sir/NOUN)
#   said/VERB
#   (NOUN_PHRASE shaking/ADJ hands/NOUN)
#   know/VERB
#   say/VERB
#   say/VERB
#   (NOUN_PHRASE anything/NOUN please/NOUN)
#   retorted/VERB
#   (NOUN_PHRASE scrooge/ADJ come/ADJ see/NOUN)
#   come/VERB
#   see/VERB
#   (NOUN_PHRASE cried/ADJ old/ADJ gentleman/NOUN)
#   (NOUN_PHRASE clear/ADJ meant/NOUN)
#   said/VERB
#   scrooge/ADV
#   much/ADJ
#   obliged/VERB
#   (NOUN_PHRASE fifty/ADJ times/NOUN)
#   bless/ADJ
#   went/VERB
#   (NOUN_PHRASE church/NOUN)
#   walked/VERB
#   (NOUN_PHRASE streets/NOUN)
#   (NOUN_PHRASE watched/ADJ people/NOUN)
#   fro/VERB
#   (NOUN_PHRASE children/NOUN)
#   head/VERB
#   (NOUN_PHRASE questioned/ADJ beggars/NOUN)
#   looked/VERB
#   (NOUN_PHRASE kitchens/NOUN houses/NOUN)
#   windows/VERB
#   found/VERB
#   (NOUN_PHRASE everything/NOUN)
#   could/VERB
#   yield/VERB
#   (NOUN_PHRASE pleasure/NOUN)
#   never/ADV
#   dreamed/VERB
#   (NOUN_PHRASE walk/NOUN anything/NOUN)
#   could/VERB
#   give/VERB
#   (NOUN_PHRASE much/ADJ happiness/NOUN afternoon/NOUN)
#   turned/VERB
#   (NOUN_PHRASE towards/NOUN)
#   (NOUN_PHRASE nephew/ADJ house/NOUN)
#   passed/VERB
#   (NOUN_PHRASE door/NOUN dozen/NOUN times/NOUN)
#   go/VERB
#   (NOUN_PHRASE knock/NOUN)
#   made/VERB
#   (NOUN_PHRASE master/NOUN home/NOUN dear/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ girl/ADJ girl/NOUN yes/NOUN)
#   sir/VERB
#   (NOUN_PHRASE love/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ sir/NOUN)
#   along/ADP
#   (NOUN_PHRASE mistress/NOUN show/NOUN)
#   stairs/VERB
#   (NOUN_PHRASE please/NOUN knows/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ hand/NOUN)
#   already/ADV
#   lock/ADV
#   go/VERB
#   dear/ADJ
#   turned/VERB
#   gently/ADV
#   (NOUN_PHRASE sidled/ADJ face/NOUN round/NOUN door/NOUN)
#   looking/VERB
#   (NOUN_PHRASE table/ADJ spread/NOUN)
#   (NOUN_PHRASE great/ADJ young/ADJ housekeepers/NOUN)
#   always/ADV
#   nervous/ADJ
#   like/ADP
#   see/VERB
#   (NOUN_PHRASE everything/NOUN)
#   right/ADV
#   fred/VERB
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ dear/ADJ heart/NOUN)
#   (NOUN_PHRASE alive/ADJ niece/ADJ marriage/NOUN)
#   started/VERB
#   scrooge/ADV
#   forgotten/VERB
#   (NOUN_PHRASE moment/NOUN)
#   sitting/VERB
#   (NOUN_PHRASE corner/NOUN footstool/NOUN)
#   would/VERB
#   done/VERB
#   (NOUN_PHRASE account/NOUN bless/NOUN soul/NOUN)
#   cried/VERB
#   (NOUN_PHRASE fred/ADJ uncle/NOUN)
#   scrooge/VERB
#   (NOUN_PHRASE come/ADJ dinner/NOUN let/NOUN)
#   fred/VERB
#   let/VERB
#   mercy/ADJ
#   shake/VERB
#   (NOUN_PHRASE arm/NOUN home/NOUN)
#   five/NUM
#   (NOUN_PHRASE minutes/NOUN nothing/NOUN)
#   could/VERB
#   niece/VERB
#   looked/VERB
#   (NOUN_PHRASE topper/NOUN)
#   came/VERB
#   (NOUN_PHRASE plump/ADJ sister/NOUN)
#   came/VERB
#   every/DET
#   one/NUM
#   came/VERB
#   (NOUN_PHRASE wonderful/ADJ party/NOUN)
#   (NOUN_PHRASE wonderful/ADJ wonderful/ADJ happiness/NOUN)
#   (NOUN_PHRASE early/ADJ office/NOUN)
#   next/ADP
#   (NOUN_PHRASE morning/NOUN oh/NOUN)
#   early/ADV
#   could/VERB
#   first/VERB
#   catch/VERB
#   (NOUN_PHRASE bob/NOUN cratchit/NOUN)
#   coming/VERB
#   (NOUN_PHRASE late/ADJ thing/NOUN)
#   set/VERB
#   (NOUN_PHRASE heart/NOUN)
#   upon/ADP
#   yes/X
#   (NOUN_PHRASE clock/NOUN)
#   struck/VERB
#   nine/NUM
#   (NOUN_PHRASE bob/ADJ quarter/NOUN)
#   past/ADP
#   (NOUN_PHRASE bob/NOUN)
#   (NOUN_PHRASE full/ADJ eighteen/NOUN minutes/NOUN)
#   half/DET
#   behind/ADP
#   (NOUN_PHRASE time/NOUN)
#   (NOUN_PHRASE scrooge/ADJ sat/ADJ door/NOUN)
#   wide/ADJ
#   open/ADJ
#   might/VERB
#   see/VERB
#   (NOUN_PHRASE come/ADJ tank/NOUN hat/NOUN)
#   opened/VERB
#   (NOUN_PHRASE door/ADJ comforter/NOUN stool/NOUN)
#   driving/VERB
#   away/ADV
#   pen/ADJ
#   trying/VERB
#   nine/NUM
#   (NOUN_PHRASE hallo/NOUN)
#   growled/VERB
#   (NOUN_PHRASE scrooge/NOUN)
#   (NOUN_PHRASE accustomed/ADJ voice/NOUN)
#   near/ADP
#   could/VERB
#   mean/VERB
#   (NOUN_PHRASE coming/ADJ time/NOUN day/NOUN)
#   sorry/VERB
#   (NOUN_PHRASE sir/NOUN)
#   said/VERB
#   (NOUN_PHRASE bob/NOUN)
#   behind/ADP
#   (NOUN_PHRASE time/NOUN)
#   repeated/VERB
#   (NOUN_PHRASE scrooge/ADJ yes/NOUN)
#   think/VERB
#   step/VERB
#   (NOUN_PHRASE way/NOUN)
#   please/ADP
#   (NOUN_PHRASE year/NOUN sir/NOUN)
#   pleaded/VERB
#   (NOUN_PHRASE bob/NOUN)
#   appearing/VERB
#   (NOUN_PHRASE tank/NOUN)
#   shall/VERB
#   repeated/VERB
#   making/VERB
#   rather/ADV
#   (NOUN_PHRASE merry/NOUN yesterday/NOUN)
#   sir/VERB
#   (NOUN_PHRASE tell/NOUN friend/NOUN)
#   said/VERB
#   scrooge/ADJ
#   going/VERB
#   (NOUN_PHRASE stand/NOUN sort/NOUN thing/NOUN longer/NOUN)
#   therefore/VERB
#   (NOUN_PHRASE continued/ADJ stool/NOUN)
#   giving/VERB
#   (NOUN_PHRASE bob/NOUN waistcoat/NOUN)
#   back/ADV
#   (NOUN_PHRASE tank/NOUN therefore/NOUN raise/NOUN)
#   (NOUN_PHRASE salary/ADJ bob/NOUN)
#   trembled/VERB
#   got/VERB
#   (NOUN_PHRASE little/ADJ nearer/ADJ ruler/NOUN idea/NOUN)
#   knocking/VERB
#   scrooge/ADJ
#   holding/VERB
#   calling/VERB
#   (NOUN_PHRASE people/NOUN court/NOUN help/NOUN)
#   merry/VERB
#   (NOUN_PHRASE christmas/NOUN bob/NOUN)
#   said/VERB
#   (NOUN_PHRASE scrooge/ADJ earnestness/NOUN)
#   could/VERB
#   clapped/VERB
#   back/ADV
#   (NOUN_PHRASE merrier/ADJ christmas/NOUN bob/NOUN)
#   (NOUN_PHRASE good/ADJ fellow/NOUN)
#   given/VERB
#   (NOUN_PHRASE many/ADJ year/NOUN raise/NOUN)
#   (NOUN_PHRASE salary/ADJ assist/NOUN)
#   struggling/VERB
#   (NOUN_PHRASE
#     family/NOUN
#     afternoon/NOUN
#     christmas/NOUN
#     bowl/NOUN
#     bob/NOUN)
#   make/VERB
#   (NOUN_PHRASE fires/NOUN)
#   buy/VERB
#   another/DET
#   another/DET
#   (NOUN_PHRASE bob/NOUN cratchit/NOUN scrooge/NOUN)
#   better/ADV
#   (NOUN_PHRASE word/NOUN)
#   (NOUN_PHRASE tiny/ADJ tim/NOUN)
#   (NOUN_PHRASE die/ADJ second/ADJ father/NOUN)
#   became/VERB
#   (NOUN_PHRASE good/ADJ friend/NOUN)
#   (NOUN_PHRASE good/ADJ master/NOUN)
#   (NOUN_PHRASE good/ADJ man/NOUN)
#   (NOUN_PHRASE good/ADJ old/ADJ city/NOUN)
#   knew/VERB
#   (NOUN_PHRASE good/ADJ old/ADJ city/NOUN town/NOUN)
#   (NOUN_PHRASE good/ADJ old/ADJ world/NOUN people/NOUN)
#   laughed/VERB
#   (NOUN_PHRASE see/ADJ alteration/NOUN)
#   let/VERB
#   (NOUN_PHRASE laugh/ADJ little/ADJ wise/NOUN)
#   enough/ADV
#   know/VERB
#   (NOUN_PHRASE nothing/NOUN)
#   ever/ADV
#   happened/VERB
#   (NOUN_PHRASE globe/NOUN)
#   (NOUN_PHRASE good/ADJ people/NOUN)
#   laughter/VERB
#   outset/VERB
#   (NOUN_PHRASE knowing/NOUN)
#   would/VERB
#   blind/VERB
#   thought/ADJ
#   quite/ADV
#   well/ADV
#   (NOUN_PHRASE wrinkle/ADJ eyes/NOUN)
#   less/ADV
#   (NOUN_PHRASE forms/ADJ heart/NOUN)
#   laughed/VERB
#   quite/ADV
#   (NOUN_PHRASE enough/ADJ intercourse/ADJ spirits/NOUN)
#   lived/VERB
#   upon/ADP
#   (NOUN_PHRASE total/ADJ principle/NOUN)
#   ever/ADV
#   (NOUN_PHRASE afterwards/NOUN)
#   always/ADV
#   said/VERB
#   (NOUN_PHRASE knew/ADJ keep/NOUN christmas/NOUN)
#   well/ADV
#   (NOUN_PHRASE man/NOUN)
#   (NOUN_PHRASE alive/ADJ knowledge/NOUN)
#   may/VERB
#   truly/VERB
#   said/VERB
#   us/PRON
#   us/PRON
#   (NOUN_PHRASE tiny/ADJ tim/NOUN)
#   observed/VERB
#   (NOUN_PHRASE god/ADJ bless/NOUN)
#   us/PRON
#   every/DET
#   one/NUM
#   (NOUN_PHRASE end/NOUN))

# %% [markdown]
# #### Simple example of Chunking

# %%
text = 'Alice likes to travel to New York City'
words = nltk.word_tokenize(text)
tags = nltk.pos_tag(words, tagset='universal')
chunks = parser.parse(tags)
print(chunks)
# Out:
# (S
#   (NOUN_PHRASE Alice/NOUN)
#   likes/VERB
#   to/PRT
#   travel/VERB
#   to/PRT
#   (NOUN_PHRASE New/NOUN York/NOUN City/NOUN))

# %% [markdown]
# #### Example of Named Entity Recognition

# %%
text = 'Alice is the CEO of Acme International and has been tasked with building a Space Ship for Mars'
words = nltk.word_tokenize(text)
tags = nltk.pos_tag(words)
ner = nltk.ne_chunk(tags)
print(ner)
# Out:
# (S
#   (GPE Alice/NNP)
#   is/VBZ
#   the/DT
#   (ORGANIZATION CEO/NN of/IN Acme/NNP International/NNP)
#   and/CC
#   has/VBZ
#   been/VBN
#   tasked/VBN
#   with/IN
#   building/VBG
#   a/DT
#   Space/NNP
#   Ship/NNP
#   for/IN
#   (PERSON Mars/NNP))

# %% [markdown]
# #### NLTK has built-in function for bigrams and trigrams - nltk.bigram() and nltk.trigrams()

# %%
all_bigrams = list(ngrams(all_words, 2))
all_bigrams
# Out:
# [('title', 'christmas'),
#  ('christmas', 'carol'),
#  ('carol', 'author'),
#  ('author', 'charles'),
#  ('charles', 'dickens'),
#  ('dickens', 'illustrator'),
#  ('illustrator', 'john'),
#  ('john', 'leech'),
#  ('leech', 'release'),
#  ('release', 'date'),
#  ('date', 'october'),
#  ('october', 'language'),
#  ('language', 'english'),
#  ('english', 'christmas'),
#  ('christmas', 'carol'),
#  ('carol', 'charles'),
#  ('charles', 'dickens'),
#  ('dickens', 'ghost'),
#  ('ghost', 'story'),
#  ('story', 'christmas'),
#  ('christmas', 'preface'),
#  ('preface', 'endeavoured'),
#  ('endeavoured', 'ghostly'),
#  ('ghostly', 'little'),
#  ('little', 'book'),
#  ('book', 'raise'),
#  ('raise', 'ghost'),
#  ('ghost', 'idea'),
#  ('idea', 'shall'),
#  ('shall', 'put'),
#  ('put', 'readers'),
#  ('readers', 'humour'),
#  ('humour', 'season'),
#  ('season', 'may'),
#  ('may', 'haunt'),
#  ('haunt', 'houses'),
#  ('houses', 'pleasantly'),
#  ('pleasantly', 'one'),
#  ('one', 'wish'),
#  ('wish', 'lay'),
#  ('lay', 'faithful'),
#  ('faithful', 'friend'),
#  ('friend', 'servant'),
#  ('servant', 'december'),
#  ('december', 'stave'),
#  ('stave', 'marley'),
#  ('marley', 'ghost'),
#  ('ghost', 'marley'),
#  ('marley', 'dead'),
#  ('dead', 'begin'),
#  ('begin', 'doubt'),
#  ('doubt', 'whatever'),
#  ('whatever', 'register'),
#  ('register', 'burial'),
#  ('burial', 'signed'),
#  ('signed', 'clergyman'),
#  ('clergyman', 'clerk'),
#  ('clerk', 'undertaker'),
#  ('undertaker', 'chief'),
#  ('chief', 'mourner'),
#  ('mourner', 'scrooge'),
#  ('scrooge', 'signed'),
#  ('signed', 'name'),
#  ('name', 'good'),
#  ('good', 'upon'),
#  ('upon', 'anything'),
#  ('anything', 'chose'),
#  ('chose', 'put'),
#  ('put', 'hand'),
#  ('hand', 'old'),
#  ('old', 'marley'),
#  ('marley', 'dead'),
#  ('dead', 'mind'),
#  ('mind', 'mean'),
#  ('mean', 'say'),
#  ('say', 'know'),
#  ('know', 'knowledge'),
#  ('knowledge', 'particularly'),
#  ('particularly', 'dead'),
#  ('dead', 'might'),
#  ('might', 'inclined'),
#  ('inclined', 'regard'),
#  ('regard', 'deadest'),
#  ('deadest', 'piece'),
#  ('piece', 'ironmongery'),
#  ('ironmongery', 'trade'),
#  ('trade', 'wisdom'),
#  ('wisdom', 'ancestors'),
#  ('ancestors', 'simile'),
#  ('simile', 'unhallowed'),
#  ('unhallowed', 'hands'),
#  ('hands', 'shall'),
#  ('shall', 'disturb'),
#  ('disturb', 'country'),
#  ('country', 'done'),
#  ('done', 'therefore'),
#  ('therefore', 'permit'),
#  ('permit', 'repeat'),
#  ('repeat', 'emphatically'),
#  ('emphatically', 'marley'),
#  ('marley', 'dead'),
#  ('dead', 'scrooge'),
#  ('scrooge', 'knew'),
#  ('knew', 'dead'),
#  ('dead', 'course'),
#  ('course', 'could'),
#  ('could', 'otherwise'),
#  ('otherwise', 'scrooge'),
#  ('scrooge', 'partners'),
#  ('partners', 'know'),
#  ('know', 'many'),
#  ('many', 'years'),
#  ('years', 'scrooge'),
#  ('scrooge', 'sole'),
#  ('sole', 'executor'),
#  ('executor', 'sole'),
#  ('sole', 'administrator'),
#  ('administrator', 'sole'),
#  ('sole', 'assign'),
#  ('assign', 'sole'),
#  ('sole', 'residuary'),
#  ('residuary', 'legatee'),
#  ('legatee', 'sole'),
#  ('sole', 'friend'),
#  ('friend', 'sole'),
#  ('sole', 'mourner'),
#  ('mourner', 'even'),
#  ('even', 'scrooge'),
#  ('scrooge', 'dreadfully'),
#  ('dreadfully', 'cut'),
#  ('cut', 'sad'),
#  ('sad', 'event'),
#  ('event', 'excellent'),
#  ('excellent', 'man'),
#  ('man', 'business'),
#  ('business', 'day'),
#  ('day', 'funeral'),
#  ('funeral', 'solemnised'),
#  ('solemnised', 'undoubted'),
#  ('undoubted', 'bargain'),
#  ('bargain', 'mention'),
#  ('mention', 'marley'),
#  ('marley', 'funeral'),
#  ('funeral', 'brings'),
#  ('brings', 'back'),
#  ('back', 'point'),
#  ('point', 'started'),
#  ('started', 'doubt'),
#  ('doubt', 'marley'),
#  ('marley', 'dead'),
#  ('dead', 'must'),
#  ('must', 'distinctly'),
#  ('distinctly', 'understood'),
#  ('understood', 'nothing'),
#  ('nothing', 'wonderful'),
#  ('wonderful', 'come'),
#  ('come', 'story'),
#  ('story', 'going'),
#  ('going', 'relate'),
#  ('relate', 'perfectly'),
#  ('perfectly', 'convinced'),
#  ('convinced', 'hamlet'),
#  ('hamlet', 'father'),
#  ('father', 'died'),
#  ('died', 'play'),
#  ('play', 'began'),
#  ('began', 'would'),
#  ('would', 'nothing'),
#  ('nothing', 'remarkable'),
#  ('remarkable', 'taking'),
#  ('taking', 'stroll'),
#  ('stroll', 'night'),
#  ('night', 'easterly'),
#  ('easterly', 'wind'),
#  ('wind', 'upon'),
#  ('upon', 'ramparts'),
#  ('ramparts', 'would'),
#  ('would', 'gentleman'),
#  ('gentleman', 'rashly'),
#  ('rashly', 'turning'),
#  ('turning', 'dark'),
#  ('dark', 'breezy'),
#  ('breezy', 'spot'),
#  ('spot', 'say'),
#  ('say', 'saint'),
#  ('saint', 'paul'),
#  ('paul', 'churchyard'),
#  ('churchyard', 'instance'),
#  ('instance', 'literally'),
#  ('literally', 'astonish'),
#  ('astonish', 'son'),
#  ('son', 'weak'),
#  ('weak', 'mind'),
#  ('mind', 'scrooge'),
#  ('scrooge', 'never'),
#  ('never', 'painted'),
#  ('painted', 'old'),
#  ('old', 'marley'),
#  ('marley', 'name'),
#  ('name', 'stood'),
#  ('stood', 'years'),
#  ('years', 'afterwards'),
#  ('afterwards', 'warehouse'),
#  ('warehouse', 'door'),
#  ('door', 'scrooge'),
#  ('scrooge', 'marley'),
#  ('marley', 'firm'),
#  ('firm', 'known'),
#  ('known', 'scrooge'),
#  ('scrooge', 'marley'),
#  ('marley', 'sometimes'),
#  ('sometimes', 'people'),
#  ('people', 'new'),
#  ('new', 'business'),
#  ('business', 'called'),
#  ('called', 'scrooge'),
#  ('scrooge', 'scrooge'),
#  ('scrooge', 'sometimes'),
#  ('sometimes', 'marley'),
#  ('marley', 'answered'),
#  ('answered', 'names'),
#  ('names', 'oh'),
#  ('oh', 'hand'),
#  ('hand', 'grindstone'),
#  ('grindstone', 'scrooge'),
#  ('scrooge', 'squeezing'),
#  ('squeezing', 'wrenching'),
#  ('wrenching', 'grasping'),
#  ('grasping', 'scraping'),
#  ('scraping', 'clutching'),
#  ('clutching', 'covetous'),
#  ('covetous', 'old'),
#  ('old', 'sinner'),
#  ('sinner', 'hard'),
#  ('hard', 'sharp'),
#  ('sharp', 'flint'),
#  ('flint', 'steel'),
#  ('steel', 'ever'),
#  ('ever', 'struck'),
#  ('struck', 'generous'),
#  ('generous', 'fire'),
#  ('fire', 'secret'),
#  ('secret', 'solitary'),
#  ('solitary', 'oyster'),
#  ('oyster', 'cold'),
#  ('cold', 'within'),
#  ('within', 'froze'),
#  ('froze', 'old'),
#  ('old', 'features'),
#  ('features', 'nipped'),
#  ('nipped', 'pointed'),
#  ('pointed', 'nose'),
#  ('nose', 'shrivelled'),
#  ('shrivelled', 'cheek'),
#  ('cheek', 'stiffened'),
#  ('stiffened', 'gait'),
#  ('gait', 'made'),
#  ('made', 'eyes'),
#  ('eyes', 'red'),
#  ('red', 'thin'),
#  ('thin', 'lips'),
#  ('lips', 'blue'),
#  ('blue', 'spoke'),
#  ('spoke', 'shrewdly'),
#  ('shrewdly', 'grating'),
#  ('grating', 'voice'),
#  ('voice', 'frosty'),
#  ('frosty', 'rime'),
#  ('rime', 'head'),
#  ('head', 'eyebrows'),
#  ('eyebrows', 'wiry'),
#  ('wiry', 'chin'),
#  ('chin', 'carried'),
#  ('carried', 'low'),
#  ('low', 'temperature'),
#  ('temperature', 'always'),
#  ('always', 'iced'),
#  ('iced', 'office'),
#  ('office', 'thaw'),
#  ('thaw', 'one'),
#  ('one', 'degree'),
#  ('degree', 'christmas'),
#  ('christmas', 'external'),
#  ('external', 'heat'),
#  ('heat', 'cold'),
#  ('cold', 'little'),
#  ('little', 'influence'),
#  ('influence', 'scrooge'),
#  ('scrooge', 'warmth'),
#  ('warmth', 'could'),
#  ('could', 'warm'),
#  ('warm', 'wintry'),
#  ('wintry', 'weather'),
#  ('weather', 'chill'),
#  ('chill', 'wind'),
#  ('wind', 'blew'),
#  ('blew', 'bitterer'),
#  ('bitterer', 'falling'),
#  ('falling', 'snow'),
#  ('snow', 'intent'),
#  ('intent', 'upon'),
#  ('upon', 'purpose'),
#  ('purpose', 'pelting'),
#  ('pelting', 'rain'),
#  ('rain', 'less'),
#  ('less', 'open'),
#  ('open', 'entreaty'),
#  ('entreaty', 'foul'),
#  ('foul', 'weather'),
#  ('weather', 'know'),
#  ('know', 'heaviest'),
#  ('heaviest', 'rain'),
#  ('rain', 'snow'),
#  ('snow', 'hail'),
#  ('hail', 'sleet'),
#  ('sleet', 'could'),
#  ('could', 'boast'),
#  ('boast', 'advantage'),
#  ('advantage', 'one'),
#  ('one', 'respect'),
#  ('respect', 'often'),
#  ('often', 'came'),
#  ('came', 'handsomely'),
#  ('handsomely', 'scrooge'),
#  ('scrooge', 'never'),
#  ('never', 'nobody'),
#  ('nobody', 'ever'),
#  ('ever', 'stopped'),
#  ('stopped', 'street'),
#  ('street', 'say'),
#  ('say', 'gladsome'),
#  ('gladsome', 'looks'),
#  ('looks', 'dear'),
#  ('dear', 'scrooge'),
#  ('scrooge', 'come'),
#  ('come', 'see'),
#  ('see', 'beggars'),
#  ('beggars', 'implored'),
#  ('implored', 'bestow'),
#  ('bestow', 'trifle'),
#  ('trifle', 'children'),
#  ('children', 'asked'),
#  ('asked', 'man'),
#  ('man', 'woman'),
#  ('woman', 'ever'),
#  ('ever', 'life'),
#  ('life', 'inquired'),
#  ('inquired', 'way'),
#  ('way', 'place'),
#  ('place', 'scrooge'),
#  ('scrooge', 'even'),
#  ('even', 'blindmen'),
#  ('blindmen', 'dogs'),
#  ('dogs', 'appeared'),
#  ('appeared', 'know'),
#  ('know', 'saw'),
#  ('saw', 'coming'),
#  ('coming', 'would'),
#  ('would', 'tug'),
#  ('tug', 'owners'),
#  ('owners', 'doorways'),
#  ('doorways', 'courts'),
#  ('courts', 'would'),
#  ('would', 'wag'),
#  ('wag', 'tails'),
#  ('tails', 'though'),
#  ('though', 'said'),
#  ('said', 'eye'),
#  ('eye', 'better'),
#  ('better', 'evil'),
#  ('evil', 'eye'),
#  ('eye', 'dark'),
#  ('dark', 'master'),
#  ('master', 'scrooge'),
#  ('scrooge', 'care'),
#  ('care', 'thing'),
#  ('thing', 'liked'),
#  ('liked', 'edge'),
#  ('edge', 'way'),
#  ('way', 'along'),
#  ('along', 'crowded'),
#  ('crowded', 'paths'),
#  ('paths', 'life'),
#  ('life', 'warning'),
#  ('warning', 'human'),
#  ('human', 'sympathy'),
#  ('sympathy', 'keep'),
#  ('keep', 'distance'),
#  ('distance', 'knowing'),
#  ('knowing', 'ones'),
#  ('ones', 'call'),
#  ('call', 'nuts'),
#  ('nuts', 'scrooge'),
#  ('scrooge', 'upon'),
#  ('upon', 'time'),
#  ('time', 'good'),
#  ('good', 'days'),
#  ('days', 'year'),
#  ('year', 'christmas'),
#  ('christmas', 'eve'),
#  ('eve', 'old'),
#  ('old', 'scrooge'),
#  ('scrooge', 'sat'),
#  ('sat', 'busy'),
#  ('busy', 'cold'),
#  ('cold', 'bleak'),
#  ('bleak', 'biting'),
#  ('biting', 'weather'),
#  ('weather', 'foggy'),
#  ('foggy', 'withal'),
#  ('withal', 'could'),
#  ('could', 'hear'),
#  ('hear', 'people'),
#  ('people', 'court'),
#  ('court', 'outside'),
#  ('outside', 'go'),
#  ('go', 'wheezing'),
#  ('wheezing', 'beating'),
#  ('beating', 'hands'),
#  ('hands', 'upon'),
#  ('upon', 'breasts'),
#  ('breasts', 'stamping'),
#  ('stamping', 'feet'),
#  ('feet', 'upon'),
#  ('upon', 'warm'),
#  ('warm', 'city'),
#  ('city', 'clocks'),
#  ('clocks', 'gone'),
#  ('gone', 'three'),
#  ('three', 'quite'),
#  ('quite', 'dark'),
#  ('dark', 'already'),
#  ('already', 'light'),
#  ('light', 'day'),
#  ('day', 'candles'),
#  ('candles', 'flaring'),
#  ('flaring', 'windows'),
#  ('windows', 'neighbouring'),
#  ('neighbouring', 'offices'),
#  ('offices', 'like'),
#  ('like', 'ruddy'),
#  ('ruddy', 'smears'),
#  ('smears', 'upon'),
#  ('upon', 'palpable'),
#  ('palpable', 'brown'),
#  ('brown', 'air'),
#  ('air', 'fog'),
#  ('fog', 'came'),
#  ('came', 'pouring'),
#  ('pouring', 'every'),
#  ('every', 'chink'),
#  ('chink', 'keyhole'),
#  ('keyhole', 'dense'),
#  ('dense', 'without'),
#  ('without', 'although'),
#  ('although', 'court'),
#  ('court', 'narrowest'),
#  ('narrowest', 'houses'),
#  ('houses', 'opposite'),
#  ('opposite', 'mere'),
#  ('mere', 'phantoms'),
#  ('phantoms', 'see'),
#  ('see', 'dingy'),
#  ('dingy', 'cloud'),
#  ('cloud', 'come'),
#  ('come', 'drooping'),
#  ('drooping', 'obscuring'),
#  ('obscuring', 'everything'),
#  ('everything', 'one'),
#  ('one', 'might'),
#  ('might', 'thought'),
#  ('thought', 'nature'),
#  ('nature', 'lived'),
#  ('lived', 'hard'),
#  ('hard', 'brewing'),
#  ('brewing', 'large'),
#  ('large', 'scale'),
#  ('scale', 'door'),
#  ('door', 'scrooge'),
#  ('scrooge', 'open'),
#  ('open', 'might'),
#  ('might', 'keep'),
#  ('keep', 'eye'),
#  ('eye', 'upon'),
#  ('upon', 'clerk'),
#  ('clerk', 'dismal'),
#  ('dismal', 'little'),
#  ('little', 'cell'),
#  ('cell', 'beyond'),
#  ('beyond', 'sort'),
#  ('sort', 'tank'),
#  ('tank', 'copying'),
#  ('copying', 'letters'),
#  ('letters', 'scrooge'),
#  ('scrooge', 'small'),
#  ('small', 'fire'),
#  ('fire', 'clerk'),
#  ('clerk', 'fire'),
#  ('fire', 'much'),
#  ('much', 'smaller'),
#  ('smaller', 'looked'),
#  ('looked', 'like'),
#  ('like', 'one'),
#  ('one', 'coal'),
#  ('coal', 'could'),
#  ('could', 'replenish'),
#  ('replenish', 'scrooge'),
#  ('scrooge', 'kept'),
#  ('kept', 'room'),
#  ('room', 'surely'),
#  ('surely', 'clerk'),
#  ('clerk', 'came'),
#  ('came', 'shovel'),
#  ('shovel', 'master'),
#  ('master', 'predicted'),
#  ('predicted', 'would'),
#  ('would', 'necessary'),
#  ('necessary', 'part'),
#  ('part', 'wherefore'),
#  ('wherefore', 'clerk'),
#  ('clerk', 'put'),
#  ('put', 'white'),
#  ('white', 'comforter'),
#  ('comforter', 'tried'),
#  ('tried', 'warm'),
#  ('warm', 'candle'),
#  ('candle', 'effort'),
#  ('effort', 'man'),
#  ('man', 'strong'),
#  ('strong', 'imagination'),
#  ('imagination', 'failed'),
#  ('failed', 'merry'),
#  ('merry', 'christmas'),
#  ('christmas', 'uncle'),
#  ('uncle', 'god'),
#  ('god', 'save'),
#  ('save', 'cried'),
#  ('cried', 'cheerful'),
#  ('cheerful', 'voice'),
#  ('voice', 'voice'),
#  ('voice', 'scrooge'),
#  ('scrooge', 'nephew'),
#  ('nephew', 'came'),
#  ('came', 'upon'),
#  ('upon', 'quickly'),
#  ('quickly', 'first'),
#  ('first', 'intimation'),
#  ('intimation', 'approach'),
#  ('approach', 'bah'),
#  ('bah', 'said'),
#  ('said', 'scrooge'),
#  ('scrooge', 'humbug'),
#  ('humbug', 'heated'),
#  ('heated', 'rapid'),
#  ('rapid', 'walking'),
#  ('walking', 'fog'),
#  ('fog', 'frost'),
#  ('frost', 'nephew'),
#  ('nephew', 'scrooge'),
#  ('scrooge', 'glow'),
#  ('glow', 'face'),
#  ('face', 'ruddy'),
#  ('ruddy', 'handsome'),
#  ('handsome', 'eyes'),
#  ('eyes', 'sparkled'),
#  ('sparkled', 'breath'),
#  ('breath', 'smoked'),
#  ('smoked', 'christmas'),
#  ('christmas', 'humbug'),
#  ('humbug', 'uncle'),
#  ('uncle', 'said'),
#  ('said', 'scrooge'),
#  ('scrooge', 'nephew'),
#  ('nephew', 'mean'),
#  ('mean', 'sure'),
#  ('sure', 'said'),
#  ('said', 'scrooge'),
#  ('scrooge', 'merry'),
#  ('merry', 'christmas'),
#  ('christmas', 'right'),
#  ('right', 'merry'),
#  ('merry', 'reason'),
#  ('reason', 'merry'),
#  ('merry', 'poor'),
#  ('poor', 'enough'),
#  ('enough', 'come'),
#  ('come', 'returned'),
#  ('returned', 'nephew'),
#  ('nephew', 'gaily'),
#  ('gaily', 'right'),
#  ('right', 'dismal'),
#  ('dismal', 'reason'),
#  ('reason', 'morose'),
#  ('morose', 'rich'),
#  ('rich', 'enough'),
#  ('enough', 'scrooge'),
#  ('scrooge', 'better'),
#  ('better', 'answer'),
#  ('answer', 'ready'),
#  ('ready', 'spur'),
#  ('spur', 'moment'),
#  ('moment', 'said'),
#  ('said', 'bah'),
#  ('bah', 'followed'),
#  ('followed', 'humbug'),
#  ('humbug', 'cross'),
#  ('cross', 'uncle'),
#  ('uncle', 'said'),
#  ('said', 'nephew'),
#  ('nephew', 'else'),
#  ('else', 'returned'),
#  ('returned', 'uncle'),
#  ('uncle', 'live'),
#  ('live', 'world'),
#  ('world', 'fools'),
#  ('fools', 'merry'),
#  ('merry', 'christmas'),
#  ('christmas', 'upon'),
#  ('upon', 'merry'),
#  ('merry', 'christmas'),
#  ('christmas', 'christmas'),
#  ('christmas', 'time'),
#  ('time', 'time'),
#  ('time', 'paying'),
#  ('paying', 'bills'),
#  ('bills', 'without'),
#  ('without', 'money'),
#  ('money', 'time'),
#  ('time', 'finding'),
#  ('finding', 'year'),
#  ('year', 'older'),
#  ('older', 'hour'),
#  ('hour', 'richer'),
#  ('richer', 'time'),
#  ('time', 'balancing'),
#  ('balancing', 'books'),
#  ('books', 'every'),
#  ('every', 'item'),
#  ('item', 'round'),
#  ('round', 'dozen'),
#  ('dozen', 'months'),
#  ('months', 'presented'),
#  ('presented', 'dead'),
#  ('dead', 'could'),
#  ('could', 'work'),
#  ('work', 'said'),
#  ('said', 'scrooge'),
#  ('scrooge', 'indignantly'),
#  ('indignantly', 'every'),
#  ('every', 'idiot'),
#  ('idiot', 'goes'),
#  ('goes', 'christmas'),
#  ('christmas', 'lips'),
#  ('lips', 'boiled'),
#  ('boiled', 'pudding'),
#  ('pudding', 'buried'),
#  ('buried', 'stake'),
#  ('stake', 'holly'),
#  ('holly', 'heart'),
#  ('heart', 'uncle'),
#  ('uncle', 'pleaded'),
#  ('pleaded', 'nephew'),
#  ('nephew', 'nephew'),
#  ('nephew', 'returned'),
#  ('returned', 'uncle'),
#  ('uncle', 'sternly'),
#  ('sternly', 'keep'),
#  ('keep', 'christmas'),
#  ('christmas', 'way'),
#  ('way', 'let'),
#  ('let', 'keep'),
#  ('keep', 'mine'),
#  ('mine', 'keep'),
#  ('keep', 'repeated'),
#  ('repeated', 'scrooge'),
#  ('scrooge', 'nephew'),
#  ('nephew', 'keep'),
#  ('keep', 'let'),
#  ('let', 'leave'),
#  ('leave', 'alone'),
#  ('alone', 'said'),
#  ('said', 'scrooge'),
#  ('scrooge', 'much'),
#  ('much', 'good'),
#  ('good', 'may'),
#  ('may', 'much'),
#  ('much', 'good'),
#  ('good', 'ever'),
#  ('ever', 'done'),
#  ('done', 'many'),
#  ('many', 'things'),
#  ('things', 'might'),
#  ('might', 'derived'),
#  ('derived', 'good'),
#  ('good', 'profited'),
#  ('profited', 'dare'),
#  ('dare', 'say'),
#  ('say', 'returned'),
#  ('returned', 'nephew'),
#  ('nephew', 'christmas'),
#  ('christmas', 'among'),
#  ('among', 'rest'),
#  ('rest', 'sure'),
#  ('sure', 'always'),
#  ('always', 'thought'),
#  ('thought', 'christmas'),
#  ('christmas', 'time'),
#  ('time', 'come'),
#  ('come', 'round'),
#  ('round', 'apart'),
#  ('apart', 'veneration'),
#  ('veneration', 'due'),
#  ('due', 'sacred'),
#  ('sacred', 'name'),
#  ('name', 'origin'),
#  ('origin', 'anything'),
#  ('anything', 'belonging'),
#  ('belonging', 'apart'),
#  ('apart', 'good'),
#  ('good', 'time'),
#  ('time', 'kind'),
#  ('kind', 'forgiving'),
#  ('forgiving', 'charitable'),
#  ('charitable', 'pleasant'),
#  ('pleasant', 'time'),
#  ('time', 'time'),
#  ('time', 'know'),
#  ('know', 'long'),
#  ('long', 'calendar'),
#  ('calendar', 'year'),
#  ('year', 'men'),
#  ('men', 'women'),
#  ('women', 'seem'),
#  ('seem', 'one'),
#  ('one', 'consent'),
#  ('consent', 'open'),
#  ('open', 'hearts'),
#  ('hearts', 'freely'),
#  ('freely', 'think'),
#  ('think', 'people'),
#  ('people', 'really'),
#  ('really', 'grave'),
#  ('grave', 'another'),
#  ('another', 'race'),
#  ('race', 'creatures'),
#  ('creatures', 'bound'),
#  ('bound', 'journeys'),
#  ('journeys', 'therefore'),
#  ('therefore', 'uncle'),
#  ('uncle', 'though'),
#  ('though', 'never'),
#  ('never', 'put'),
#  ('put', 'scrap'),
#  ('scrap', 'gold'),
#  ('gold', 'silver'),
#  ('silver', 'pocket'),
#  ('pocket', 'believe'),
#  ('believe', 'done'),
#  ('done', 'good'),
#  ('good', 'good'),
#  ('good', 'say'),
#  ('say', 'god'),
#  ('god', 'bless'),
#  ('bless', 'clerk'),
#  ('clerk', 'tank'),
#  ('tank', 'involuntarily'),
#  ('involuntarily', 'applauded'),
#  ('applauded', 'becoming'),
#  ('becoming', 'immediately'),
#  ('immediately', 'sensible'),
#  ('sensible', 'impropriety'),
#  ('impropriety', 'poked'),
#  ('poked', 'fire'),
#  ('fire', 'extinguished'),
#  ('extinguished', 'last'),
#  ('last', 'frail'),
#  ('frail', 'spark'),
#  ('spark', 'ever'),
#  ('ever', 'let'),
#  ('let', 'hear'),
#  ('hear', 'another'),
#  ('another', 'sound'),
#  ('sound', 'said'),
#  ('said', 'scrooge'),
#  ('scrooge', 'keep'),
#  ('keep', 'christmas'),
#  ('christmas', 'losing'),
#  ('losing', 'situation'),
#  ('situation', 'quite'),
#  ('quite', 'powerful'),
#  ('powerful', 'speaker'),
#  ('speaker', 'sir'),
#  ('sir', 'added'),
#  ('added', 'turning'),
#  ('turning', 'nephew'),
#  ('nephew', 'wonder'),
#  ('wonder', 'go'),
#  ('go', 'parliament'),
#  ('parliament', 'angry'),
#  ('angry', 'uncle'),
#  ('uncle', 'come'),
#  ('come', 'dine'),
#  ('dine', 'us'),
#  ('us', 'scrooge'),
#  ('scrooge', 'said'),
#  ('said', 'would'),
#  ('would', 'see'),
#  ('see', 'yes'),
#  ('yes', 'indeed'),
#  ('indeed', 'went'),
#  ('went', 'whole'),
#  ('whole', 'length'),
#  ('length', 'expression'),
#  ('expression', 'said'),
#  ('said', 'would'),
#  ('would', 'see'),
#  ('see', 'extremity'),
#  ('extremity', 'first'),
#  ('first', 'cried'),
#  ('cried', 'scrooge'),
#  ('scrooge', 'nephew'),
#  ('nephew', 'get'),
#  ('get', 'married'),
#  ('married', 'said'),
#  ('said', 'scrooge'),
#  ('scrooge', 'fell'),
#  ('fell', 'love'),
#  ('love', 'fell'),
#  ('fell', 'love'),
#  ('love', 'growled'),
#  ('growled', 'scrooge'),
#  ('scrooge', 'one'),
#  ('one', 'thing'),
#  ('thing', 'world'),
#  ('world', 'ridiculous'),
#  ('ridiculous', 'merry'),
#  ('merry', 'christmas'),
#  ('christmas', 'good'),
#  ('good', 'afternoon'),
#  ('afternoon', 'nay'),
#  ('nay', 'uncle'),
#  ('uncle', 'never'),
#  ('never', 'came'),
#  ('came', 'see'),
#  ('see', 'happened'),
#  ('happened', 'give'),
#  ('give', 'reason'),
#  ('reason', 'coming'),
#  ('coming', 'good'),
#  ('good', 'afternoon'),
#  ('afternoon', 'said'),
#  ('said', 'scrooge'),
#  ('scrooge', 'want'),
#  ('want', 'nothing'),
#  ('nothing', 'ask'),
#  ('ask', 'nothing'),
#  ('nothing', 'friends'),
#  ('friends', 'good'),
#  ('good', 'afternoon'),
#  ('afternoon', 'said'),
#  ('said', 'scrooge'),
#  ('scrooge', 'sorry'),
#  ('sorry', 'heart'),
#  ('heart', 'find'),
#  ('find', 'resolute'),
#  ('resolute', 'never'),
#  ('never', 'quarrel'),
#  ('quarrel', 'party'),
#  ('party', 'made'),
#  ('made', 'trial'),
#  ('trial', 'homage'),
#  ('homage', 'christmas'),
#  ('christmas', 'keep'),
#  ('keep', 'christmas'),
#  ('christmas', 'humour'),
#  ('humour', 'last'),
#  ('last', 'merry'),
#  ('merry', 'christmas'),
#  ('christmas', 'uncle'),
#  ('uncle', 'good'),
#  ('good', 'afternoon'),
#  ('afternoon', 'said'),
#  ('said', 'scrooge'),
#  ('scrooge', 'happy'),
#  ('happy', 'new'),
#  ('new', 'year'),
#  ('year', 'good'),
#  ('good', 'afternoon'),
#  ('afternoon', 'said'),
#  ('said', 'scrooge'),
#  ('scrooge', 'nephew'),
#  ('nephew', 'left'),
#  ('left', 'room'),
#  ('room', 'without'),
#  ('without', 'angry'),
#  ('angry', 'word'),
#  ('word', 'notwithstanding'),
#  ('notwithstanding', 'stopped'),
#  ('stopped', 'outer'),
#  ('outer', 'door'),
#  ('door', 'bestow'),
#  ('bestow', 'greetings'),
#  ('greetings', 'season'),
#  ('season', 'clerk'),
#  ('clerk', 'cold'),
#  ('cold', 'warmer'),
#  ('warmer', 'scrooge'),
#  ('scrooge', 'returned'),
#  ('returned', 'cordially'),
#  ('cordially', 'another'),
#  ('another', 'fellow'),
#  ('fellow', 'muttered'),
#  ('muttered', 'scrooge'),
#  ('scrooge', 'overheard'),
#  ('overheard', 'clerk'),
#  ('clerk', 'fifteen'),
#  ('fifteen', 'shillings'),
#  ('shillings', 'wife'),
#  ('wife', 'family'),
#  ('family', 'talking'),
#  ('talking', 'merry'),
#  ('merry', 'christmas'),
#  ('christmas', 'retire'),
#  ('retire', 'bedlam'),
#  ('bedlam', 'lunatic'),
#  ('lunatic', 'letting'),
#  ('letting', 'scrooge'),
#  ('scrooge', 'nephew'),
#  ('nephew', 'let'),
#  ('let', 'two'),
#  ('two', 'people'),
#  ('people', 'portly'),
#  ('portly', 'gentlemen'),
#  ('gentlemen', 'pleasant'),
#  ('pleasant', 'behold'),
#  ('behold', 'stood'),
#  ('stood', 'hats'),
#  ('hats', 'scrooge'),
#  ('scrooge', 'office'),
#  ('office', 'books'),
#  ('books', 'papers'),
#  ('papers', 'hands'),
#  ('hands', 'bowed'),
#  ('bowed', 'scrooge'),
#  ('scrooge', 'marley'),
#  ('marley', 'believe'),
#  ('believe', 'said'),
#  ('said', 'one'),
#  ('one', 'gentlemen'),
#  ('gentlemen', 'referring'),
#  ('referring', 'list'),
#  ('list', 'pleasure'),
#  ('pleasure', 'addressing'),
#  ('addressing', 'scrooge'),
#  ('scrooge', 'mr'),
#  ('mr', 'marley'),
#  ('marley', 'marley'),
#  ('marley', 'dead'),
#  ('dead', 'seven'),
#  ('seven', 'years'),
#  ('years', 'scrooge'),
#  ('scrooge', 'replied'),
#  ('replied', 'died'),
#  ('died', 'seven'),
#  ('seven', 'years'),
#  ('years', 'ago'),
#  ('ago', 'night'),
#  ('night', 'doubt'),
#  ('doubt', 'liberality'),
#  ('liberality', 'well'),
#  ('well', 'represented'),
#  ('represented', 'surviving'),
#  ('surviving', 'partner'),
#  ('partner', 'said'),
#  ('said', 'gentleman'),
#  ('gentleman', 'presenting'),
#  ('presenting', 'credentials'),
#  ('credentials', 'certainly'),
#  ('certainly', 'two'),
#  ('two', 'kindred'),
#  ('kindred', 'spirits'),
#  ('spirits', 'ominous'),
#  ('ominous', 'word'),
#  ('word', 'liberality'),
#  ('liberality', 'scrooge'),
#  ('scrooge', 'frowned'),
#  ('frowned', 'shook'),
#  ('shook', 'head'),
#  ('head', 'handed'),
#  ('handed', 'credentials'),
#  ('credentials', 'back'),
#  ('back', 'festive'),
#  ('festive', 'season'),
#  ('season', 'year'),
#  ('year', 'scrooge'),
#  ('scrooge', 'said'),
#  ('said', 'gentleman'),
#  ('gentleman', 'taking'),
#  ('taking', 'pen'),
#  ('pen', 'usually'),
#  ...]
